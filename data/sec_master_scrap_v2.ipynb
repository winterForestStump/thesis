# %% [markdown]
# <a href="https://colab.research.google.com/github/winterForestStump/thesis/blob/main/data/sec_master_scrap_v2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import time
import pandas as pd

# %%
# !cd content/drive/MyDrive
# Out:
# /bin/bash: line 1: cd: content/drive/MyDrive: No such file or directory

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'}

# %%
# Function to generate dates from 1999 to 2023
def generate_dates():
    for year in range(1999, 2024):
        for month in range(1, 10):
            for day in range(1, 32):
                # Ensure valid dates are used
                if month in [4, 6, 9, 11] and day == 31:
                    continue
                elif month == 2 and day > 29:
                    continue
                elif month == 2 and day == 29 and not (year % 4 == 0 and (year % 100 != 0 or year % 400 == 0)):
                    continue
                yield f"{year:04d}{month:02d}{day:02d}"

# %%
# let's first make a function that will make the process of building a url easy.
def make_url(base_url , comp):
    url = base_url
    # add each component to the base url
    for r in comp:
        url = '{}/{}'.format(url, r)
    return url

# %% [markdown]
# 10-K (Annual report) provides audited annual financial statements, a discussion of material risk factors for the company and its business, and a management’s discussion and analysis of the company’s results of operations for the prior fiscal year.

# %%
# Base URL for the master files
base_url = "https://www.sec.gov/Archives/edgar/daily-index/"

# Counter to keep track of downloaded and failed files
total_downloaded_files = 0
total_failed_files = 0

master_datas = []
# Loop through all dates and download the content for each day
for date in generate_dates():
    file_url = f"{base_url}{date[:4]}/QTR{int(date[4:6]) // 4 + 1}/master.{date}.idx"
    response = requests.get(file_url, headers=headers)

    if response.status_code == 200:
        try:
          data = response.content.decode("utf-8").split('  ')
        except UnicodeDecodeError as e:
          print(f"UnicodeDecodeError: {e}")
        # We need to remove the headers, so look for the end of the header and grab it's index
        for index, item in enumerate(data):
          if "ftp://ftp.sec.gov/edgar/" in item:
            start_ind = index

        # define a new dataset with out the header info.
        data_format = data[start_ind:]

        master_data = []

        # now we need to break the data into sections, this way we can move to the final step of getting each row value.
        for index, item in enumerate(data_format):

          # if it's the first index, it won't be even so treat it differently
          if index == 0:
            clean_item_data = item.replace('\n','|').split('|')
            clean_item_data = clean_item_data[8:]
          else:
            clean_item_data = item.replace('\n','|').split('|')

          for index, row in enumerate(clean_item_data):

            # when you find the text file.
            if '.txt' in row:

              # grab the values that belong to that row. It's 4 values before and one after.
              mini_list = clean_item_data[(index - 4): index + 1]

              if len(mini_list) != 0:
                mini_list[4] = "https://www.sec.gov/Archives/" + mini_list[4]
                master_data.append(mini_list)

        # loop through each document in the master list.
        for index, document in enumerate(master_data):

          # create a dictionary for each document in the master list
          document_dict = {}
          document_dict['cik_number'] = document[0]
          document_dict['company_name'] = document[1]
          document_dict['form_id'] = document[2]
          document_dict['date'] = document[3]
          document_dict['file_url'] = document[4]

          master_data[index] = document_dict

        master_data = [item for item in master_data if item.get('form_id') == '10-K']

        master_datas.extend(master_data)
        print(f"File for {date} downloaded and saved successfully.")
        total_downloaded_files += 1

    else:
      print(f"Failed to download the file for {date}.")
      total_failed_files += 1

    # Introduce a delay to comply with the rate limit (10 requests per second)
    time.sleep(0.1)

print(f"All files downloaded. Total downloaded files: {total_downloaded_files}. Total failed to download files: {total_failed_files}")
# Out:
# Streaming output truncated to the last 5000 lines.
# Failed to download the file for 20050713.
# Failed to download the file for 20050714.
# Failed to download the file for 20050715.
# Failed to download the file for 20050716.
# Failed to download the file for 20050717.
# Failed to download the file for 20050718.
# Failed to download the file for 20050719.
# Failed to download the file for 20050720.
# Failed to download the file for 20050721.
# Failed to download the file for 20050722.
# Failed to download the file for 20050723.
# Failed to download the file for 20050724.
# Failed to download the file for 20050725.
# Failed to download the file for 20050726.
# Failed to download the file for 20050727.
# Failed to download the file for 20050728.
# Failed to download the file for 20050729.
# Failed to download the file for 20050730.
# Failed to download the file for 20050731.
# File for 20050801 downloaded and saved successfully.
# File for 20050802 downloaded and saved successfully.
# File for 20050803 downloaded and saved successfully.
# File for 20050804 downloaded and saved successfully.
# File for 20050805 downloaded and saved successfully.
# Failed to download the file for 20050806.
# Failed to download the file for 20050807.
# File for 20050808 downloaded and saved successfully.
# File for 20050809 downloaded and saved successfully.
# File for 20050810 downloaded and saved successfully.
# File for 20050811 downloaded and saved successfully.
# File for 20050812 downloaded and saved successfully.
# Failed to download the file for 20050813.
# Failed to download the file for 20050814.
# File for 20050815 downloaded and saved successfully.
# File for 20050816 downloaded and saved successfully.
# File for 20050817 downloaded and saved successfully.
# File for 20050818 downloaded and saved successfully.
# File for 20050819 downloaded and saved successfully.
# Failed to download the file for 20050820.
# Failed to download the file for 20050821.
# File for 20050822 downloaded and saved successfully.
# File for 20050823 downloaded and saved successfully.
# File for 20050824 downloaded and saved successfully.
# File for 20050825 downloaded and saved successfully.
# File for 20050826 downloaded and saved successfully.
# Failed to download the file for 20050827.
# Failed to download the file for 20050828.
# File for 20050829 downloaded and saved successfully.
# File for 20050830 downloaded and saved successfully.
# File for 20050831 downloaded and saved successfully.
# File for 20050901 downloaded and saved successfully.
# File for 20050902 downloaded and saved successfully.
# Failed to download the file for 20050903.
# Failed to download the file for 20050904.
# Failed to download the file for 20050905.
# File for 20050906 downloaded and saved successfully.
# File for 20050907 downloaded and saved successfully.
# File for 20050908 downloaded and saved successfully.
# File for 20050909 downloaded and saved successfully.
# Failed to download the file for 20050910.
# Failed to download the file for 20050911.
# File for 20050912 downloaded and saved successfully.
# File for 20050913 downloaded and saved successfully.
# File for 20050914 downloaded and saved successfully.
# File for 20050915 downloaded and saved successfully.
# File for 20050916 downloaded and saved successfully.
# Failed to download the file for 20050917.
# Failed to download the file for 20050918.
# File for 20050919 downloaded and saved successfully.
# File for 20050920 downloaded and saved successfully.
# File for 20050921 downloaded and saved successfully.
# File for 20050922 downloaded and saved successfully.
# File for 20050923 downloaded and saved successfully.
# Failed to download the file for 20050924.
# Failed to download the file for 20050925.
# File for 20050926 downloaded and saved successfully.
# File for 20050927 downloaded and saved successfully.
# File for 20050928 downloaded and saved successfully.
# File for 20050929 downloaded and saved successfully.
# File for 20050930 downloaded and saved successfully.
# Failed to download the file for 20060101.
# Failed to download the file for 20060102.
# File for 20060103 downloaded and saved successfully.
# File for 20060104 downloaded and saved successfully.
# File for 20060105 downloaded and saved successfully.
# File for 20060106 downloaded and saved successfully.
# Failed to download the file for 20060107.
# Failed to download the file for 20060108.
# File for 20060109 downloaded and saved successfully.
# File for 20060110 downloaded and saved successfully.
# File for 20060111 downloaded and saved successfully.
# File for 20060112 downloaded and saved successfully.
# File for 20060113 downloaded and saved successfully.
# Failed to download the file for 20060114.
# Failed to download the file for 20060115.
# Failed to download the file for 20060116.
# File for 20060117 downloaded and saved successfully.
# File for 20060118 downloaded and saved successfully.
# File for 20060119 downloaded and saved successfully.
# File for 20060120 downloaded and saved successfully.
# Failed to download the file for 20060121.
# Failed to download the file for 20060122.
# File for 20060123 downloaded and saved successfully.
# File for 20060124 downloaded and saved successfully.
# File for 20060125 downloaded and saved successfully.
# File for 20060126 downloaded and saved successfully.
# File for 20060127 downloaded and saved successfully.
# Failed to download the file for 20060128.
# Failed to download the file for 20060129.
# File for 20060130 downloaded and saved successfully.
# File for 20060131 downloaded and saved successfully.
# File for 20060201 downloaded and saved successfully.
# File for 20060202 downloaded and saved successfully.
# File for 20060203 downloaded and saved successfully.
# Failed to download the file for 20060204.
# Failed to download the file for 20060205.
# File for 20060206 downloaded and saved successfully.
# File for 20060207 downloaded and saved successfully.
# File for 20060208 downloaded and saved successfully.
# File for 20060209 downloaded and saved successfully.
# File for 20060210 downloaded and saved successfully.
# Failed to download the file for 20060211.
# Failed to download the file for 20060212.
# File for 20060213 downloaded and saved successfully.
# File for 20060214 downloaded and saved successfully.
# File for 20060215 downloaded and saved successfully.
# File for 20060216 downloaded and saved successfully.
# File for 20060217 downloaded and saved successfully.
# Failed to download the file for 20060218.
# Failed to download the file for 20060219.
# Failed to download the file for 20060220.
# File for 20060221 downloaded and saved successfully.
# File for 20060222 downloaded and saved successfully.
# File for 20060223 downloaded and saved successfully.
# File for 20060224 downloaded and saved successfully.
# Failed to download the file for 20060225.
# Failed to download the file for 20060226.
# File for 20060227 downloaded and saved successfully.
# File for 20060228 downloaded and saved successfully.
# File for 20060301 downloaded and saved successfully.
# File for 20060302 downloaded and saved successfully.
# File for 20060303 downloaded and saved successfully.
# Failed to download the file for 20060304.
# Failed to download the file for 20060305.
# File for 20060306 downloaded and saved successfully.
# File for 20060307 downloaded and saved successfully.
# File for 20060308 downloaded and saved successfully.
# File for 20060309 downloaded and saved successfully.
# File for 20060310 downloaded and saved successfully.
# Failed to download the file for 20060311.
# Failed to download the file for 20060312.
# File for 20060313 downloaded and saved successfully.
# File for 20060314 downloaded and saved successfully.
# File for 20060315 downloaded and saved successfully.
# File for 20060316 downloaded and saved successfully.
# File for 20060317 downloaded and saved successfully.
# Failed to download the file for 20060318.
# Failed to download the file for 20060319.
# File for 20060320 downloaded and saved successfully.
# File for 20060321 downloaded and saved successfully.
# File for 20060322 downloaded and saved successfully.
# File for 20060323 downloaded and saved successfully.
# File for 20060324 downloaded and saved successfully.
# Failed to download the file for 20060325.
# Failed to download the file for 20060326.
# File for 20060327 downloaded and saved successfully.
# File for 20060328 downloaded and saved successfully.
# File for 20060329 downloaded and saved successfully.
# File for 20060330 downloaded and saved successfully.
# File for 20060331 downloaded and saved successfully.
# Failed to download the file for 20060401.
# Failed to download the file for 20060402.
# File for 20060403 downloaded and saved successfully.
# File for 20060404 downloaded and saved successfully.
# File for 20060405 downloaded and saved successfully.
# File for 20060406 downloaded and saved successfully.
# File for 20060407 downloaded and saved successfully.
# Failed to download the file for 20060408.
# Failed to download the file for 20060409.
# File for 20060410 downloaded and saved successfully.
# File for 20060411 downloaded and saved successfully.
# File for 20060412 downloaded and saved successfully.
# File for 20060413 downloaded and saved successfully.
# File for 20060414 downloaded and saved successfully.
# Failed to download the file for 20060415.
# Failed to download the file for 20060416.
# File for 20060417 downloaded and saved successfully.
# File for 20060418 downloaded and saved successfully.
# File for 20060419 downloaded and saved successfully.
# File for 20060420 downloaded and saved successfully.
# File for 20060421 downloaded and saved successfully.
# Failed to download the file for 20060422.
# Failed to download the file for 20060423.
# File for 20060424 downloaded and saved successfully.
# File for 20060425 downloaded and saved successfully.
# File for 20060426 downloaded and saved successfully.
# File for 20060427 downloaded and saved successfully.
# File for 20060428 downloaded and saved successfully.
# Failed to download the file for 20060429.
# Failed to download the file for 20060430.
# File for 20060501 downloaded and saved successfully.
# File for 20060502 downloaded and saved successfully.
# File for 20060503 downloaded and saved successfully.
# File for 20060504 downloaded and saved successfully.
# File for 20060505 downloaded and saved successfully.
# Failed to download the file for 20060506.
# Failed to download the file for 20060507.
# File for 20060508 downloaded and saved successfully.
# File for 20060509 downloaded and saved successfully.
# File for 20060510 downloaded and saved successfully.
# File for 20060511 downloaded and saved successfully.
# File for 20060512 downloaded and saved successfully.
# Failed to download the file for 20060513.
# Failed to download the file for 20060514.
# File for 20060515 downloaded and saved successfully.
# File for 20060516 downloaded and saved successfully.
# File for 20060517 downloaded and saved successfully.
# File for 20060518 downloaded and saved successfully.
# File for 20060519 downloaded and saved successfully.
# Failed to download the file for 20060520.
# Failed to download the file for 20060521.
# File for 20060522 downloaded and saved successfully.
# File for 20060523 downloaded and saved successfully.
# File for 20060524 downloaded and saved successfully.
# File for 20060525 downloaded and saved successfully.
# File for 20060526 downloaded and saved successfully.
# Failed to download the file for 20060527.
# Failed to download the file for 20060528.
# Failed to download the file for 20060529.
# File for 20060530 downloaded and saved successfully.
# File for 20060531 downloaded and saved successfully.
# File for 20060601 downloaded and saved successfully.
# File for 20060602 downloaded and saved successfully.
# Failed to download the file for 20060603.
# Failed to download the file for 20060604.
# File for 20060605 downloaded and saved successfully.
# File for 20060606 downloaded and saved successfully.
# File for 20060607 downloaded and saved successfully.
# File for 20060608 downloaded and saved successfully.
# File for 20060609 downloaded and saved successfully.
# Failed to download the file for 20060610.
# Failed to download the file for 20060611.
# File for 20060612 downloaded and saved successfully.
# File for 20060613 downloaded and saved successfully.
# File for 20060614 downloaded and saved successfully.
# File for 20060615 downloaded and saved successfully.
# File for 20060616 downloaded and saved successfully.
# Failed to download the file for 20060617.
# Failed to download the file for 20060618.
# File for 20060619 downloaded and saved successfully.
# File for 20060620 downloaded and saved successfully.
# File for 20060621 downloaded and saved successfully.
# File for 20060622 downloaded and saved successfully.
# File for 20060623 downloaded and saved successfully.
# Failed to download the file for 20060624.
# Failed to download the file for 20060625.
# File for 20060626 downloaded and saved successfully.
# File for 20060627 downloaded and saved successfully.
# File for 20060628 downloaded and saved successfully.
# File for 20060629 downloaded and saved successfully.
# File for 20060630 downloaded and saved successfully.
# Failed to download the file for 20060701.
# Failed to download the file for 20060702.
# Failed to download the file for 20060703.
# Failed to download the file for 20060704.
# Failed to download the file for 20060705.
# Failed to download the file for 20060706.
# Failed to download the file for 20060707.
# Failed to download the file for 20060708.
# Failed to download the file for 20060709.
# Failed to download the file for 20060710.
# Failed to download the file for 20060711.
# Failed to download the file for 20060712.
# Failed to download the file for 20060713.
# Failed to download the file for 20060714.
# Failed to download the file for 20060715.
# Failed to download the file for 20060716.
# Failed to download the file for 20060717.
# Failed to download the file for 20060718.
# Failed to download the file for 20060719.
# Failed to download the file for 20060720.
# Failed to download the file for 20060721.
# Failed to download the file for 20060722.
# Failed to download the file for 20060723.
# Failed to download the file for 20060724.
# Failed to download the file for 20060725.
# Failed to download the file for 20060726.
# Failed to download the file for 20060727.
# Failed to download the file for 20060728.
# Failed to download the file for 20060729.
# Failed to download the file for 20060730.
# Failed to download the file for 20060731.
# File for 20060801 downloaded and saved successfully.
# File for 20060802 downloaded and saved successfully.
# File for 20060803 downloaded and saved successfully.
# File for 20060804 downloaded and saved successfully.
# Failed to download the file for 20060805.
# Failed to download the file for 20060806.
# File for 20060807 downloaded and saved successfully.
# File for 20060808 downloaded and saved successfully.
# File for 20060809 downloaded and saved successfully.
# File for 20060810 downloaded and saved successfully.
# File for 20060811 downloaded and saved successfully.
# Failed to download the file for 20060812.
# Failed to download the file for 20060813.
# File for 20060814 downloaded and saved successfully.
# File for 20060815 downloaded and saved successfully.
# File for 20060816 downloaded and saved successfully.
# File for 20060817 downloaded and saved successfully.
# File for 20060818 downloaded and saved successfully.
# Failed to download the file for 20060819.
# Failed to download the file for 20060820.
# File for 20060821 downloaded and saved successfully.
# File for 20060822 downloaded and saved successfully.
# File for 20060823 downloaded and saved successfully.
# File for 20060824 downloaded and saved successfully.
# File for 20060825 downloaded and saved successfully.
# Failed to download the file for 20060826.
# Failed to download the file for 20060827.
# File for 20060828 downloaded and saved successfully.
# File for 20060829 downloaded and saved successfully.
# File for 20060830 downloaded and saved successfully.
# File for 20060831 downloaded and saved successfully.
# File for 20060901 downloaded and saved successfully.
# Failed to download the file for 20060902.
# Failed to download the file for 20060903.
# Failed to download the file for 20060904.
# File for 20060905 downloaded and saved successfully.
# File for 20060906 downloaded and saved successfully.
# File for 20060907 downloaded and saved successfully.
# File for 20060908 downloaded and saved successfully.
# Failed to download the file for 20060909.
# Failed to download the file for 20060910.
# File for 20060911 downloaded and saved successfully.
# File for 20060912 downloaded and saved successfully.
# File for 20060913 downloaded and saved successfully.
# File for 20060914 downloaded and saved successfully.
# File for 20060915 downloaded and saved successfully.
# Failed to download the file for 20060916.
# Failed to download the file for 20060917.
# File for 20060918 downloaded and saved successfully.
# File for 20060919 downloaded and saved successfully.
# File for 20060920 downloaded and saved successfully.
# File for 20060921 downloaded and saved successfully.
# File for 20060922 downloaded and saved successfully.
# Failed to download the file for 20060923.
# Failed to download the file for 20060924.
# File for 20060925 downloaded and saved successfully.
# File for 20060926 downloaded and saved successfully.
# File for 20060927 downloaded and saved successfully.
# File for 20060928 downloaded and saved successfully.
# File for 20060929 downloaded and saved successfully.
# Failed to download the file for 20060930.
# Failed to download the file for 20070101.
# Failed to download the file for 20070102.
# File for 20070103 downloaded and saved successfully.
# File for 20070104 downloaded and saved successfully.
# File for 20070105 downloaded and saved successfully.
# Failed to download the file for 20070106.
# Failed to download the file for 20070107.
# File for 20070108 downloaded and saved successfully.
# File for 20070109 downloaded and saved successfully.
# File for 20070110 downloaded and saved successfully.
# File for 20070111 downloaded and saved successfully.
# File for 20070112 downloaded and saved successfully.
# Failed to download the file for 20070113.
# Failed to download the file for 20070114.
# Failed to download the file for 20070115.
# File for 20070116 downloaded and saved successfully.
# File for 20070117 downloaded and saved successfully.
# File for 20070118 downloaded and saved successfully.
# File for 20070119 downloaded and saved successfully.
# Failed to download the file for 20070120.
# Failed to download the file for 20070121.
# File for 20070122 downloaded and saved successfully.
# File for 20070123 downloaded and saved successfully.
# File for 20070124 downloaded and saved successfully.
# File for 20070125 downloaded and saved successfully.
# File for 20070126 downloaded and saved successfully.
# Failed to download the file for 20070127.
# Failed to download the file for 20070128.
# File for 20070129 downloaded and saved successfully.
# File for 20070130 downloaded and saved successfully.
# File for 20070131 downloaded and saved successfully.
# File for 20070201 downloaded and saved successfully.
# File for 20070202 downloaded and saved successfully.
# Failed to download the file for 20070203.
# Failed to download the file for 20070204.
# File for 20070205 downloaded and saved successfully.
# File for 20070206 downloaded and saved successfully.
# File for 20070207 downloaded and saved successfully.
# File for 20070208 downloaded and saved successfully.
# File for 20070209 downloaded and saved successfully.
# Failed to download the file for 20070210.
# Failed to download the file for 20070211.
# File for 20070212 downloaded and saved successfully.
# File for 20070213 downloaded and saved successfully.
# File for 20070214 downloaded and saved successfully.
# File for 20070215 downloaded and saved successfully.
# File for 20070216 downloaded and saved successfully.
# Failed to download the file for 20070217.
# Failed to download the file for 20070218.
# Failed to download the file for 20070219.
# File for 20070220 downloaded and saved successfully.
# File for 20070221 downloaded and saved successfully.
# File for 20070222 downloaded and saved successfully.
# File for 20070223 downloaded and saved successfully.
# Failed to download the file for 20070224.
# Failed to download the file for 20070225.
# File for 20070226 downloaded and saved successfully.
# File for 20070227 downloaded and saved successfully.
# File for 20070228 downloaded and saved successfully.
# File for 20070301 downloaded and saved successfully.
# File for 20070302 downloaded and saved successfully.
# Failed to download the file for 20070303.
# Failed to download the file for 20070304.
# File for 20070305 downloaded and saved successfully.
# File for 20070306 downloaded and saved successfully.
# File for 20070307 downloaded and saved successfully.
# File for 20070308 downloaded and saved successfully.
# File for 20070309 downloaded and saved successfully.
# Failed to download the file for 20070310.
# Failed to download the file for 20070311.
# File for 20070312 downloaded and saved successfully.
# File for 20070313 downloaded and saved successfully.
# File for 20070314 downloaded and saved successfully.
# File for 20070315 downloaded and saved successfully.
# File for 20070316 downloaded and saved successfully.
# Failed to download the file for 20070317.
# Failed to download the file for 20070318.
# File for 20070319 downloaded and saved successfully.
# File for 20070320 downloaded and saved successfully.
# File for 20070321 downloaded and saved successfully.
# File for 20070322 downloaded and saved successfully.
# File for 20070323 downloaded and saved successfully.
# Failed to download the file for 20070324.
# Failed to download the file for 20070325.
# File for 20070326 downloaded and saved successfully.
# File for 20070327 downloaded and saved successfully.
# File for 20070328 downloaded and saved successfully.
# File for 20070329 downloaded and saved successfully.
# File for 20070330 downloaded and saved successfully.
# Failed to download the file for 20070331.
# Failed to download the file for 20070401.
# File for 20070402 downloaded and saved successfully.
# File for 20070403 downloaded and saved successfully.
# File for 20070404 downloaded and saved successfully.
# File for 20070405 downloaded and saved successfully.
# File for 20070406 downloaded and saved successfully.
# Failed to download the file for 20070407.
# Failed to download the file for 20070408.
# File for 20070409 downloaded and saved successfully.
# File for 20070410 downloaded and saved successfully.
# File for 20070411 downloaded and saved successfully.
# File for 20070412 downloaded and saved successfully.
# File for 20070413 downloaded and saved successfully.
# Failed to download the file for 20070414.
# Failed to download the file for 20070415.
# File for 20070416 downloaded and saved successfully.
# File for 20070417 downloaded and saved successfully.
# File for 20070418 downloaded and saved successfully.
# File for 20070419 downloaded and saved successfully.
# File for 20070420 downloaded and saved successfully.
# Failed to download the file for 20070421.
# Failed to download the file for 20070422.
# File for 20070423 downloaded and saved successfully.
# File for 20070424 downloaded and saved successfully.
# File for 20070425 downloaded and saved successfully.
# File for 20070426 downloaded and saved successfully.
# File for 20070427 downloaded and saved successfully.
# Failed to download the file for 20070428.
# Failed to download the file for 20070429.
# File for 20070430 downloaded and saved successfully.
# File for 20070501 downloaded and saved successfully.
# File for 20070502 downloaded and saved successfully.
# File for 20070503 downloaded and saved successfully.
# File for 20070504 downloaded and saved successfully.
# Failed to download the file for 20070505.
# Failed to download the file for 20070506.
# File for 20070507 downloaded and saved successfully.
# File for 20070508 downloaded and saved successfully.
# File for 20070509 downloaded and saved successfully.
# File for 20070510 downloaded and saved successfully.
# File for 20070511 downloaded and saved successfully.
# Failed to download the file for 20070512.
# Failed to download the file for 20070513.
# File for 20070514 downloaded and saved successfully.
# File for 20070515 downloaded and saved successfully.
# File for 20070516 downloaded and saved successfully.
# File for 20070517 downloaded and saved successfully.
# File for 20070518 downloaded and saved successfully.
# Failed to download the file for 20070519.
# Failed to download the file for 20070520.
# File for 20070521 downloaded and saved successfully.
# File for 20070522 downloaded and saved successfully.
# File for 20070523 downloaded and saved successfully.
# File for 20070524 downloaded and saved successfully.
# File for 20070525 downloaded and saved successfully.
# Failed to download the file for 20070526.
# Failed to download the file for 20070527.
# Failed to download the file for 20070528.
# File for 20070529 downloaded and saved successfully.
# File for 20070530 downloaded and saved successfully.
# File for 20070531 downloaded and saved successfully.
# File for 20070601 downloaded and saved successfully.
# Failed to download the file for 20070602.
# Failed to download the file for 20070603.
# File for 20070604 downloaded and saved successfully.
# File for 20070605 downloaded and saved successfully.
# File for 20070606 downloaded and saved successfully.
# File for 20070607 downloaded and saved successfully.
# File for 20070608 downloaded and saved successfully.
# Failed to download the file for 20070609.
# Failed to download the file for 20070610.
# File for 20070611 downloaded and saved successfully.
# File for 20070612 downloaded and saved successfully.
# File for 20070613 downloaded and saved successfully.
# File for 20070614 downloaded and saved successfully.
# File for 20070615 downloaded and saved successfully.
# Failed to download the file for 20070616.
# Failed to download the file for 20070617.
# File for 20070618 downloaded and saved successfully.
# File for 20070619 downloaded and saved successfully.
# File for 20070620 downloaded and saved successfully.
# File for 20070621 downloaded and saved successfully.
# File for 20070622 downloaded and saved successfully.
# Failed to download the file for 20070623.
# Failed to download the file for 20070624.
# File for 20070625 downloaded and saved successfully.
# File for 20070626 downloaded and saved successfully.
# File for 20070627 downloaded and saved successfully.
# File for 20070628 downloaded and saved successfully.
# File for 20070629 downloaded and saved successfully.
# Failed to download the file for 20070630.
# Failed to download the file for 20070701.
# Failed to download the file for 20070702.
# Failed to download the file for 20070703.
# Failed to download the file for 20070704.
# Failed to download the file for 20070705.
# Failed to download the file for 20070706.
# Failed to download the file for 20070707.
# Failed to download the file for 20070708.
# Failed to download the file for 20070709.
# Failed to download the file for 20070710.
# Failed to download the file for 20070711.
# Failed to download the file for 20070712.
# Failed to download the file for 20070713.
# Failed to download the file for 20070714.
# Failed to download the file for 20070715.
# Failed to download the file for 20070716.
# Failed to download the file for 20070717.
# Failed to download the file for 20070718.
# Failed to download the file for 20070719.
# Failed to download the file for 20070720.
# Failed to download the file for 20070721.
# Failed to download the file for 20070722.
# Failed to download the file for 20070723.
# Failed to download the file for 20070724.
# Failed to download the file for 20070725.
# Failed to download the file for 20070726.
# Failed to download the file for 20070727.
# Failed to download the file for 20070728.
# Failed to download the file for 20070729.
# Failed to download the file for 20070730.
# Failed to download the file for 20070731.
# File for 20070801 downloaded and saved successfully.
# File for 20070802 downloaded and saved successfully.
# File for 20070803 downloaded and saved successfully.
# Failed to download the file for 20070804.
# Failed to download the file for 20070805.
# File for 20070806 downloaded and saved successfully.
# File for 20070807 downloaded and saved successfully.
# File for 20070808 downloaded and saved successfully.
# File for 20070809 downloaded and saved successfully.
# File for 20070810 downloaded and saved successfully.
# Failed to download the file for 20070811.
# Failed to download the file for 20070812.
# File for 20070813 downloaded and saved successfully.
# File for 20070814 downloaded and saved successfully.
# File for 20070815 downloaded and saved successfully.
# File for 20070816 downloaded and saved successfully.
# File for 20070817 downloaded and saved successfully.
# Failed to download the file for 20070818.
# Failed to download the file for 20070819.
# File for 20070820 downloaded and saved successfully.
# File for 20070821 downloaded and saved successfully.
# File for 20070822 downloaded and saved successfully.
# File for 20070823 downloaded and saved successfully.
# File for 20070824 downloaded and saved successfully.
# Failed to download the file for 20070825.
# Failed to download the file for 20070826.
# File for 20070827 downloaded and saved successfully.
# File for 20070828 downloaded and saved successfully.
# File for 20070829 downloaded and saved successfully.
# File for 20070830 downloaded and saved successfully.
# File for 20070831 downloaded and saved successfully.
# Failed to download the file for 20070901.
# Failed to download the file for 20070902.
# Failed to download the file for 20070903.
# File for 20070904 downloaded and saved successfully.
# File for 20070905 downloaded and saved successfully.
# File for 20070906 downloaded and saved successfully.
# File for 20070907 downloaded and saved successfully.
# Failed to download the file for 20070908.
# Failed to download the file for 20070909.
# File for 20070910 downloaded and saved successfully.
# File for 20070911 downloaded and saved successfully.
# File for 20070912 downloaded and saved successfully.
# File for 20070913 downloaded and saved successfully.
# File for 20070914 downloaded and saved successfully.
# Failed to download the file for 20070915.
# Failed to download the file for 20070916.
# File for 20070917 downloaded and saved successfully.
# File for 20070918 downloaded and saved successfully.
# File for 20070919 downloaded and saved successfully.
# File for 20070920 downloaded and saved successfully.
# File for 20070921 downloaded and saved successfully.
# Failed to download the file for 20070922.
# Failed to download the file for 20070923.
# File for 20070924 downloaded and saved successfully.
# File for 20070925 downloaded and saved successfully.
# File for 20070926 downloaded and saved successfully.
# File for 20070927 downloaded and saved successfully.
# File for 20070928 downloaded and saved successfully.
# Failed to download the file for 20070929.
# Failed to download the file for 20070930.
# Failed to download the file for 20080101.
# File for 20080102 downloaded and saved successfully.
# File for 20080103 downloaded and saved successfully.
# File for 20080104 downloaded and saved successfully.
# Failed to download the file for 20080105.
# Failed to download the file for 20080106.
# File for 20080107 downloaded and saved successfully.
# File for 20080108 downloaded and saved successfully.
# File for 20080109 downloaded and saved successfully.
# File for 20080110 downloaded and saved successfully.
# File for 20080111 downloaded and saved successfully.
# Failed to download the file for 20080112.
# Failed to download the file for 20080113.
# File for 20080114 downloaded and saved successfully.
# File for 20080115 downloaded and saved successfully.
# File for 20080116 downloaded and saved successfully.
# File for 20080117 downloaded and saved successfully.
# File for 20080118 downloaded and saved successfully.
# Failed to download the file for 20080119.
# Failed to download the file for 20080120.
# Failed to download the file for 20080121.
# File for 20080122 downloaded and saved successfully.
# File for 20080123 downloaded and saved successfully.
# File for 20080124 downloaded and saved successfully.
# File for 20080125 downloaded and saved successfully.
# Failed to download the file for 20080126.
# Failed to download the file for 20080127.
# File for 20080128 downloaded and saved successfully.
# File for 20080129 downloaded and saved successfully.
# File for 20080130 downloaded and saved successfully.
# File for 20080131 downloaded and saved successfully.
# File for 20080201 downloaded and saved successfully.
# Failed to download the file for 20080202.
# Failed to download the file for 20080203.
# File for 20080204 downloaded and saved successfully.
# File for 20080205 downloaded and saved successfully.
# File for 20080206 downloaded and saved successfully.
# File for 20080207 downloaded and saved successfully.
# File for 20080208 downloaded and saved successfully.
# Failed to download the file for 20080209.
# Failed to download the file for 20080210.
# File for 20080211 downloaded and saved successfully.
# File for 20080212 downloaded and saved successfully.
# File for 20080213 downloaded and saved successfully.
# File for 20080214 downloaded and saved successfully.
# File for 20080215 downloaded and saved successfully.
# Failed to download the file for 20080216.
# Failed to download the file for 20080217.
# Failed to download the file for 20080218.
# File for 20080219 downloaded and saved successfully.
# File for 20080220 downloaded and saved successfully.
# File for 20080221 downloaded and saved successfully.
# File for 20080222 downloaded and saved successfully.
# Failed to download the file for 20080223.
# Failed to download the file for 20080224.
# File for 20080225 downloaded and saved successfully.
# File for 20080226 downloaded and saved successfully.
# File for 20080227 downloaded and saved successfully.
# File for 20080228 downloaded and saved successfully.
# File for 20080229 downloaded and saved successfully.
# Failed to download the file for 20080301.
# Failed to download the file for 20080302.
# File for 20080303 downloaded and saved successfully.
# File for 20080304 downloaded and saved successfully.
# File for 20080305 downloaded and saved successfully.
# File for 20080306 downloaded and saved successfully.
# File for 20080307 downloaded and saved successfully.
# Failed to download the file for 20080308.
# Failed to download the file for 20080309.
# File for 20080310 downloaded and saved successfully.
# File for 20080311 downloaded and saved successfully.
# File for 20080312 downloaded and saved successfully.
# File for 20080313 downloaded and saved successfully.
# File for 20080314 downloaded and saved successfully.
# Failed to download the file for 20080315.
# Failed to download the file for 20080316.
# File for 20080317 downloaded and saved successfully.
# File for 20080318 downloaded and saved successfully.
# File for 20080319 downloaded and saved successfully.
# File for 20080320 downloaded and saved successfully.
# File for 20080321 downloaded and saved successfully.
# Failed to download the file for 20080322.
# Failed to download the file for 20080323.
# File for 20080324 downloaded and saved successfully.
# File for 20080325 downloaded and saved successfully.
# File for 20080326 downloaded and saved successfully.
# File for 20080327 downloaded and saved successfully.
# File for 20080328 downloaded and saved successfully.
# Failed to download the file for 20080329.
# Failed to download the file for 20080330.
# File for 20080331 downloaded and saved successfully.
# File for 20080401 downloaded and saved successfully.
# File for 20080402 downloaded and saved successfully.
# File for 20080403 downloaded and saved successfully.
# File for 20080404 downloaded and saved successfully.
# Failed to download the file for 20080405.
# Failed to download the file for 20080406.
# File for 20080407 downloaded and saved successfully.
# File for 20080408 downloaded and saved successfully.
# File for 20080409 downloaded and saved successfully.
# File for 20080410 downloaded and saved successfully.
# File for 20080411 downloaded and saved successfully.
# Failed to download the file for 20080412.
# Failed to download the file for 20080413.
# File for 20080414 downloaded and saved successfully.
# File for 20080415 downloaded and saved successfully.
# File for 20080416 downloaded and saved successfully.
# File for 20080417 downloaded and saved successfully.
# File for 20080418 downloaded and saved successfully.
# Failed to download the file for 20080419.
# Failed to download the file for 20080420.
# File for 20080421 downloaded and saved successfully.
# File for 20080422 downloaded and saved successfully.
# File for 20080423 downloaded and saved successfully.
# File for 20080424 downloaded and saved successfully.
# File for 20080425 downloaded and saved successfully.
# Failed to download the file for 20080426.
# Failed to download the file for 20080427.
# File for 20080428 downloaded and saved successfully.
# File for 20080429 downloaded and saved successfully.
# File for 20080430 downloaded and saved successfully.
# File for 20080501 downloaded and saved successfully.
# File for 20080502 downloaded and saved successfully.
# Failed to download the file for 20080503.
# Failed to download the file for 20080504.
# File for 20080505 downloaded and saved successfully.
# File for 20080506 downloaded and saved successfully.
# File for 20080507 downloaded and saved successfully.
# File for 20080508 downloaded and saved successfully.
# File for 20080509 downloaded and saved successfully.
# Failed to download the file for 20080510.
# Failed to download the file for 20080511.
# File for 20080512 downloaded and saved successfully.
# File for 20080513 downloaded and saved successfully.
# File for 20080514 downloaded and saved successfully.
# File for 20080515 downloaded and saved successfully.
# File for 20080516 downloaded and saved successfully.
# Failed to download the file for 20080517.
# Failed to download the file for 20080518.
# File for 20080519 downloaded and saved successfully.
# File for 20080520 downloaded and saved successfully.
# File for 20080521 downloaded and saved successfully.
# File for 20080522 downloaded and saved successfully.
# File for 20080523 downloaded and saved successfully.
# Failed to download the file for 20080524.
# Failed to download the file for 20080525.
# Failed to download the file for 20080526.
# File for 20080527 downloaded and saved successfully.
# File for 20080528 downloaded and saved successfully.
# File for 20080529 downloaded and saved successfully.
# File for 20080530 downloaded and saved successfully.
# Failed to download the file for 20080531.
# Failed to download the file for 20080601.
# File for 20080602 downloaded and saved successfully.
# File for 20080603 downloaded and saved successfully.
# File for 20080604 downloaded and saved successfully.
# File for 20080605 downloaded and saved successfully.
# File for 20080606 downloaded and saved successfully.
# Failed to download the file for 20080607.
# Failed to download the file for 20080608.
# File for 20080609 downloaded and saved successfully.
# File for 20080610 downloaded and saved successfully.
# File for 20080611 downloaded and saved successfully.
# File for 20080612 downloaded and saved successfully.
# File for 20080613 downloaded and saved successfully.
# Failed to download the file for 20080614.
# Failed to download the file for 20080615.
# File for 20080616 downloaded and saved successfully.
# File for 20080617 downloaded and saved successfully.
# File for 20080618 downloaded and saved successfully.
# File for 20080619 downloaded and saved successfully.
# File for 20080620 downloaded and saved successfully.
# Failed to download the file for 20080621.
# Failed to download the file for 20080622.
# File for 20080623 downloaded and saved successfully.
# File for 20080624 downloaded and saved successfully.
# File for 20080625 downloaded and saved successfully.
# File for 20080626 downloaded and saved successfully.
# File for 20080627 downloaded and saved successfully.
# Failed to download the file for 20080628.
# Failed to download the file for 20080629.
# File for 20080630 downloaded and saved successfully.
# Failed to download the file for 20080701.
# Failed to download the file for 20080702.
# Failed to download the file for 20080703.
# Failed to download the file for 20080704.
# Failed to download the file for 20080705.
# Failed to download the file for 20080706.
# Failed to download the file for 20080707.
# Failed to download the file for 20080708.
# Failed to download the file for 20080709.
# Failed to download the file for 20080710.
# Failed to download the file for 20080711.
# Failed to download the file for 20080712.
# Failed to download the file for 20080713.
# Failed to download the file for 20080714.
# Failed to download the file for 20080715.
# Failed to download the file for 20080716.
# Failed to download the file for 20080717.
# Failed to download the file for 20080718.
# Failed to download the file for 20080719.
# Failed to download the file for 20080720.
# Failed to download the file for 20080721.
# Failed to download the file for 20080722.
# Failed to download the file for 20080723.
# Failed to download the file for 20080724.
# Failed to download the file for 20080725.
# Failed to download the file for 20080726.
# Failed to download the file for 20080727.
# Failed to download the file for 20080728.
# Failed to download the file for 20080729.
# Failed to download the file for 20080730.
# Failed to download the file for 20080731.
# File for 20080801 downloaded and saved successfully.
# Failed to download the file for 20080802.
# Failed to download the file for 20080803.
# File for 20080804 downloaded and saved successfully.
# File for 20080805 downloaded and saved successfully.
# File for 20080806 downloaded and saved successfully.
# File for 20080807 downloaded and saved successfully.
# File for 20080808 downloaded and saved successfully.
# Failed to download the file for 20080809.
# Failed to download the file for 20080810.
# File for 20080811 downloaded and saved successfully.
# File for 20080812 downloaded and saved successfully.
# File for 20080813 downloaded and saved successfully.
# File for 20080814 downloaded and saved successfully.
# File for 20080815 downloaded and saved successfully.
# Failed to download the file for 20080816.
# Failed to download the file for 20080817.
# File for 20080818 downloaded and saved successfully.
# File for 20080819 downloaded and saved successfully.
# File for 20080820 downloaded and saved successfully.
# File for 20080821 downloaded and saved successfully.
# File for 20080822 downloaded and saved successfully.
# Failed to download the file for 20080823.
# Failed to download the file for 20080824.
# File for 20080825 downloaded and saved successfully.
# File for 20080826 downloaded and saved successfully.
# File for 20080827 downloaded and saved successfully.
# File for 20080828 downloaded and saved successfully.
# File for 20080829 downloaded and saved successfully.
# Failed to download the file for 20080830.
# Failed to download the file for 20080831.
# Failed to download the file for 20080901.
# File for 20080902 downloaded and saved successfully.
# File for 20080903 downloaded and saved successfully.
# File for 20080904 downloaded and saved successfully.
# File for 20080905 downloaded and saved successfully.
# Failed to download the file for 20080906.
# Failed to download the file for 20080907.
# File for 20080908 downloaded and saved successfully.
# File for 20080909 downloaded and saved successfully.
# File for 20080910 downloaded and saved successfully.
# File for 20080911 downloaded and saved successfully.
# File for 20080912 downloaded and saved successfully.
# Failed to download the file for 20080913.
# Failed to download the file for 20080914.
# File for 20080915 downloaded and saved successfully.
# File for 20080916 downloaded and saved successfully.
# File for 20080917 downloaded and saved successfully.
# File for 20080918 downloaded and saved successfully.
# File for 20080919 downloaded and saved successfully.
# Failed to download the file for 20080920.
# Failed to download the file for 20080921.
# File for 20080922 downloaded and saved successfully.
# File for 20080923 downloaded and saved successfully.
# File for 20080924 downloaded and saved successfully.
# File for 20080925 downloaded and saved successfully.
# File for 20080926 downloaded and saved successfully.
# Failed to download the file for 20080927.
# Failed to download the file for 20080928.
# File for 20080929 downloaded and saved successfully.
# File for 20080930 downloaded and saved successfully.
# Failed to download the file for 20090101.
# File for 20090102 downloaded and saved successfully.
# Failed to download the file for 20090103.
# Failed to download the file for 20090104.
# File for 20090105 downloaded and saved successfully.
# File for 20090106 downloaded and saved successfully.
# File for 20090107 downloaded and saved successfully.
# File for 20090108 downloaded and saved successfully.
# File for 20090109 downloaded and saved successfully.
# Failed to download the file for 20090110.
# Failed to download the file for 20090111.
# File for 20090112 downloaded and saved successfully.
# File for 20090113 downloaded and saved successfully.
# File for 20090114 downloaded and saved successfully.
# File for 20090115 downloaded and saved successfully.
# File for 20090116 downloaded and saved successfully.
# Failed to download the file for 20090117.
# Failed to download the file for 20090118.
# Failed to download the file for 20090119.
# File for 20090120 downloaded and saved successfully.
# File for 20090121 downloaded and saved successfully.
# File for 20090122 downloaded and saved successfully.
# File for 20090123 downloaded and saved successfully.
# Failed to download the file for 20090124.
# Failed to download the file for 20090125.
# File for 20090126 downloaded and saved successfully.
# File for 20090127 downloaded and saved successfully.
# File for 20090128 downloaded and saved successfully.
# File for 20090129 downloaded and saved successfully.
# File for 20090130 downloaded and saved successfully.
# Failed to download the file for 20090131.
# Failed to download the file for 20090201.
# File for 20090202 downloaded and saved successfully.
# File for 20090203 downloaded and saved successfully.
# File for 20090204 downloaded and saved successfully.
# File for 20090205 downloaded and saved successfully.
# File for 20090206 downloaded and saved successfully.
# Failed to download the file for 20090207.
# Failed to download the file for 20090208.
# File for 20090209 downloaded and saved successfully.
# File for 20090210 downloaded and saved successfully.
# File for 20090211 downloaded and saved successfully.
# File for 20090212 downloaded and saved successfully.
# File for 20090213 downloaded and saved successfully.
# Failed to download the file for 20090214.
# Failed to download the file for 20090215.
# Failed to download the file for 20090216.
# File for 20090217 downloaded and saved successfully.
# File for 20090218 downloaded and saved successfully.
# File for 20090219 downloaded and saved successfully.
# File for 20090220 downloaded and saved successfully.
# Failed to download the file for 20090221.
# Failed to download the file for 20090222.
# File for 20090223 downloaded and saved successfully.
# File for 20090224 downloaded and saved successfully.
# File for 20090225 downloaded and saved successfully.
# File for 20090226 downloaded and saved successfully.
# File for 20090227 downloaded and saved successfully.
# Failed to download the file for 20090228.
# Failed to download the file for 20090301.
# File for 20090302 downloaded and saved successfully.
# File for 20090303 downloaded and saved successfully.
# File for 20090304 downloaded and saved successfully.
# File for 20090305 downloaded and saved successfully.
# File for 20090306 downloaded and saved successfully.
# Failed to download the file for 20090307.
# Failed to download the file for 20090308.
# File for 20090309 downloaded and saved successfully.
# File for 20090310 downloaded and saved successfully.
# File for 20090311 downloaded and saved successfully.
# File for 20090312 downloaded and saved successfully.
# File for 20090313 downloaded and saved successfully.
# Failed to download the file for 20090314.
# Failed to download the file for 20090315.
# File for 20090316 downloaded and saved successfully.
# File for 20090317 downloaded and saved successfully.
# File for 20090318 downloaded and saved successfully.
# File for 20090319 downloaded and saved successfully.
# File for 20090320 downloaded and saved successfully.
# Failed to download the file for 20090321.
# Failed to download the file for 20090322.
# File for 20090323 downloaded and saved successfully.
# File for 20090324 downloaded and saved successfully.
# ...
# File for 20220809 downloaded and saved successfully.
# File for 20220810 downloaded and saved successfully.
# File for 20220811 downloaded and saved successfully.
# File for 20220812 downloaded and saved successfully.
# Failed to download the file for 20220813.
# Failed to download the file for 20220814.
# File for 20220815 downloaded and saved successfully.
# File for 20220816 downloaded and saved successfully.
# File for 20220817 downloaded and saved successfully.
# File for 20220818 downloaded and saved successfully.
# File for 20220819 downloaded and saved successfully.
# Failed to download the file for 20220820.
# Failed to download the file for 20220821.
# File for 20220822 downloaded and saved successfully.
# File for 20220823 downloaded and saved successfully.
# File for 20220824 downloaded and saved successfully.
# File for 20220825 downloaded and saved successfully.
# File for 20220826 downloaded and saved successfully.
# Failed to download the file for 20220827.
# Failed to download the file for 20220828.
# File for 20220829 downloaded and saved successfully.
# File for 20220830 downloaded and saved successfully.
# File for 20220831 downloaded and saved successfully.
# File for 20220901 downloaded and saved successfully.
# File for 20220902 downloaded and saved successfully.
# Failed to download the file for 20220903.
# Failed to download the file for 20220904.
# Failed to download the file for 20220905.
# File for 20220906 downloaded and saved successfully.
# File for 20220907 downloaded and saved successfully.
# File for 20220908 downloaded and saved successfully.
# File for 20220909 downloaded and saved successfully.
# Failed to download the file for 20220910.
# Failed to download the file for 20220911.
# File for 20220912 downloaded and saved successfully.
# File for 20220913 downloaded and saved successfully.
# File for 20220914 downloaded and saved successfully.
# File for 20220915 downloaded and saved successfully.
# File for 20220916 downloaded and saved successfully.
# Failed to download the file for 20220917.
# Failed to download the file for 20220918.
# File for 20220919 downloaded and saved successfully.
# File for 20220920 downloaded and saved successfully.
# File for 20220921 downloaded and saved successfully.
# File for 20220922 downloaded and saved successfully.
# File for 20220923 downloaded and saved successfully.
# Failed to download the file for 20220924.
# Failed to download the file for 20220925.
# File for 20220926 downloaded and saved successfully.
# File for 20220927 downloaded and saved successfully.
# File for 20220928 downloaded and saved successfully.
# File for 20220929 downloaded and saved successfully.
# File for 20220930 downloaded and saved successfully.
# Failed to download the file for 20230101.
# Failed to download the file for 20230102.
# File for 20230103 downloaded and saved successfully.
# File for 20230104 downloaded and saved successfully.
# File for 20230105 downloaded and saved successfully.
# File for 20230106 downloaded and saved successfully.
# Failed to download the file for 20230107.
# Failed to download the file for 20230108.
# File for 20230109 downloaded and saved successfully.
# File for 20230110 downloaded and saved successfully.
# File for 20230111 downloaded and saved successfully.
# File for 20230112 downloaded and saved successfully.
# File for 20230113 downloaded and saved successfully.
# Failed to download the file for 20230114.
# Failed to download the file for 20230115.
# Failed to download the file for 20230116.
# File for 20230117 downloaded and saved successfully.
# File for 20230118 downloaded and saved successfully.
# File for 20230119 downloaded and saved successfully.
# File for 20230120 downloaded and saved successfully.
# Failed to download the file for 20230121.
# Failed to download the file for 20230122.
# File for 20230123 downloaded and saved successfully.
# File for 20230124 downloaded and saved successfully.
# File for 20230125 downloaded and saved successfully.
# File for 20230126 downloaded and saved successfully.
# File for 20230127 downloaded and saved successfully.
# Failed to download the file for 20230128.
# Failed to download the file for 20230129.
# File for 20230130 downloaded and saved successfully.
# File for 20230131 downloaded and saved successfully.
# File for 20230201 downloaded and saved successfully.
# File for 20230202 downloaded and saved successfully.
# File for 20230203 downloaded and saved successfully.
# Failed to download the file for 20230204.
# Failed to download the file for 20230205.
# File for 20230206 downloaded and saved successfully.
# File for 20230207 downloaded and saved successfully.
# File for 20230208 downloaded and saved successfully.
# File for 20230209 downloaded and saved successfully.
# File for 20230210 downloaded and saved successfully.
# Failed to download the file for 20230211.
# Failed to download the file for 20230212.
# File for 20230213 downloaded and saved successfully.
# File for 20230214 downloaded and saved successfully.
# File for 20230215 downloaded and saved successfully.
# File for 20230216 downloaded and saved successfully.
# File for 20230217 downloaded and saved successfully.
# Failed to download the file for 20230218.
# Failed to download the file for 20230219.
# Failed to download the file for 20230220.
# File for 20230221 downloaded and saved successfully.
# File for 20230222 downloaded and saved successfully.
# File for 20230223 downloaded and saved successfully.
# File for 20230224 downloaded and saved successfully.
# Failed to download the file for 20230225.
# Failed to download the file for 20230226.
# File for 20230227 downloaded and saved successfully.
# File for 20230228 downloaded and saved successfully.
# File for 20230301 downloaded and saved successfully.
# File for 20230302 downloaded and saved successfully.
# File for 20230303 downloaded and saved successfully.
# Failed to download the file for 20230304.
# Failed to download the file for 20230305.
# File for 20230306 downloaded and saved successfully.
# File for 20230307 downloaded and saved successfully.
# File for 20230308 downloaded and saved successfully.
# File for 20230309 downloaded and saved successfully.
# File for 20230310 downloaded and saved successfully.
# Failed to download the file for 20230311.
# Failed to download the file for 20230312.
# File for 20230313 downloaded and saved successfully.
# File for 20230314 downloaded and saved successfully.
# File for 20230315 downloaded and saved successfully.
# File for 20230316 downloaded and saved successfully.
# File for 20230317 downloaded and saved successfully.
# Failed to download the file for 20230318.
# Failed to download the file for 20230319.
# File for 20230320 downloaded and saved successfully.
# File for 20230321 downloaded and saved successfully.
# File for 20230322 downloaded and saved successfully.
# File for 20230323 downloaded and saved successfully.
# File for 20230324 downloaded and saved successfully.
# Failed to download the file for 20230325.
# Failed to download the file for 20230326.
# File for 20230327 downloaded and saved successfully.
# File for 20230328 downloaded and saved successfully.
# File for 20230329 downloaded and saved successfully.
# File for 20230330 downloaded and saved successfully.
# File for 20230331 downloaded and saved successfully.
# Failed to download the file for 20230401.
# Failed to download the file for 20230402.
# File for 20230403 downloaded and saved successfully.
# File for 20230404 downloaded and saved successfully.
# File for 20230405 downloaded and saved successfully.
# File for 20230406 downloaded and saved successfully.
# File for 20230407 downloaded and saved successfully.
# Failed to download the file for 20230408.
# Failed to download the file for 20230409.
# File for 20230410 downloaded and saved successfully.
# File for 20230411 downloaded and saved successfully.
# File for 20230412 downloaded and saved successfully.
# File for 20230413 downloaded and saved successfully.
# File for 20230414 downloaded and saved successfully.
# Failed to download the file for 20230415.
# Failed to download the file for 20230416.
# File for 20230417 downloaded and saved successfully.
# File for 20230418 downloaded and saved successfully.
# File for 20230419 downloaded and saved successfully.
# File for 20230420 downloaded and saved successfully.
# File for 20230421 downloaded and saved successfully.
# Failed to download the file for 20230422.
# Failed to download the file for 20230423.
# File for 20230424 downloaded and saved successfully.
# File for 20230425 downloaded and saved successfully.
# File for 20230426 downloaded and saved successfully.
# File for 20230427 downloaded and saved successfully.
# File for 20230428 downloaded and saved successfully.
# Failed to download the file for 20230429.
# Failed to download the file for 20230430.
# File for 20230501 downloaded and saved successfully.
# File for 20230502 downloaded and saved successfully.
# File for 20230503 downloaded and saved successfully.
# File for 20230504 downloaded and saved successfully.
# File for 20230505 downloaded and saved successfully.
# Failed to download the file for 20230506.
# Failed to download the file for 20230507.
# File for 20230508 downloaded and saved successfully.
# File for 20230509 downloaded and saved successfully.
# File for 20230510 downloaded and saved successfully.
# File for 20230511 downloaded and saved successfully.
# File for 20230512 downloaded and saved successfully.
# Failed to download the file for 20230513.
# Failed to download the file for 20230514.
# File for 20230515 downloaded and saved successfully.
# File for 20230516 downloaded and saved successfully.
# File for 20230517 downloaded and saved successfully.
# File for 20230518 downloaded and saved successfully.
# File for 20230519 downloaded and saved successfully.
# Failed to download the file for 20230520.
# Failed to download the file for 20230521.
# File for 20230522 downloaded and saved successfully.
# File for 20230523 downloaded and saved successfully.
# File for 20230524 downloaded and saved successfully.
# File for 20230525 downloaded and saved successfully.
# File for 20230526 downloaded and saved successfully.
# Failed to download the file for 20230527.
# Failed to download the file for 20230528.
# Failed to download the file for 20230529.
# File for 20230530 downloaded and saved successfully.
# File for 20230531 downloaded and saved successfully.
# File for 20230601 downloaded and saved successfully.
# File for 20230602 downloaded and saved successfully.
# Failed to download the file for 20230603.
# Failed to download the file for 20230604.
# File for 20230605 downloaded and saved successfully.
# File for 20230606 downloaded and saved successfully.
# File for 20230607 downloaded and saved successfully.
# File for 20230608 downloaded and saved successfully.
# File for 20230609 downloaded and saved successfully.
# Failed to download the file for 20230610.
# Failed to download the file for 20230611.
# File for 20230612 downloaded and saved successfully.
# File for 20230613 downloaded and saved successfully.
# File for 20230614 downloaded and saved successfully.
# File for 20230615 downloaded and saved successfully.
# File for 20230616 downloaded and saved successfully.
# Failed to download the file for 20230617.
# Failed to download the file for 20230618.
# Failed to download the file for 20230619.
# File for 20230620 downloaded and saved successfully.
# File for 20230621 downloaded and saved successfully.
# File for 20230622 downloaded and saved successfully.
# File for 20230623 downloaded and saved successfully.
# Failed to download the file for 20230624.
# Failed to download the file for 20230625.
# File for 20230626 downloaded and saved successfully.
# File for 20230627 downloaded and saved successfully.
# File for 20230628 downloaded and saved successfully.
# File for 20230629 downloaded and saved successfully.
# File for 20230630 downloaded and saved successfully.
# Failed to download the file for 20230701.
# Failed to download the file for 20230702.
# Failed to download the file for 20230703.
# Failed to download the file for 20230704.
# Failed to download the file for 20230705.
# Failed to download the file for 20230706.
# Failed to download the file for 20230707.
# Failed to download the file for 20230708.
# Failed to download the file for 20230709.
# Failed to download the file for 20230710.
# Failed to download the file for 20230711.
# Failed to download the file for 20230712.
# Failed to download the file for 20230713.
# Failed to download the file for 20230714.
# Failed to download the file for 20230715.
# Failed to download the file for 20230716.
# Failed to download the file for 20230717.
# Failed to download the file for 20230718.
# Failed to download the file for 20230719.
# Failed to download the file for 20230720.
# Failed to download the file for 20230721.
# Failed to download the file for 20230722.
# Failed to download the file for 20230723.
# Failed to download the file for 20230724.
# Failed to download the file for 20230725.
# Failed to download the file for 20230726.
# Failed to download the file for 20230727.
# Failed to download the file for 20230728.
# Failed to download the file for 20230729.
# Failed to download the file for 20230730.
# Failed to download the file for 20230731.
# File for 20230801 downloaded and saved successfully.
# File for 20230802 downloaded and saved successfully.
# File for 20230803 downloaded and saved successfully.
# File for 20230804 downloaded and saved successfully.
# Failed to download the file for 20230805.
# Failed to download the file for 20230806.
# File for 20230807 downloaded and saved successfully.
# File for 20230808 downloaded and saved successfully.
# File for 20230809 downloaded and saved successfully.
# File for 20230810 downloaded and saved successfully.
# File for 20230811 downloaded and saved successfully.
# Failed to download the file for 20230812.
# Failed to download the file for 20230813.
# File for 20230814 downloaded and saved successfully.
# File for 20230815 downloaded and saved successfully.
# File for 20230816 downloaded and saved successfully.
# File for 20230817 downloaded and saved successfully.
# File for 20230818 downloaded and saved successfully.
# Failed to download the file for 20230819.
# Failed to download the file for 20230820.
# File for 20230821 downloaded and saved successfully.
# File for 20230822 downloaded and saved successfully.
# File for 20230823 downloaded and saved successfully.
# File for 20230824 downloaded and saved successfully.
# File for 20230825 downloaded and saved successfully.
# Failed to download the file for 20230826.
# Failed to download the file for 20230827.
# File for 20230828 downloaded and saved successfully.
# File for 20230829 downloaded and saved successfully.
# File for 20230830 downloaded and saved successfully.
# File for 20230831 downloaded and saved successfully.
# File for 20230901 downloaded and saved successfully.
# Failed to download the file for 20230902.
# Failed to download the file for 20230903.
# Failed to download the file for 20230904.
# File for 20230905 downloaded and saved successfully.
# File for 20230906 downloaded and saved successfully.
# File for 20230907 downloaded and saved successfully.
# File for 20230908 downloaded and saved successfully.
# Failed to download the file for 20230909.
# Failed to download the file for 20230910.
# File for 20230911 downloaded and saved successfully.
# File for 20230912 downloaded and saved successfully.
# File for 20230913 downloaded and saved successfully.
# File for 20230914 downloaded and saved successfully.
# File for 20230915 downloaded and saved successfully.
# Failed to download the file for 20230916.
# Failed to download the file for 20230917.
# File for 20230918 downloaded and saved successfully.
# File for 20230919 downloaded and saved successfully.
# File for 20230920 downloaded and saved successfully.
# File for 20230921 downloaded and saved successfully.
# Failed to download the file for 20230922.
# Failed to download the file for 20230923.
# Failed to download the file for 20230924.
# Failed to download the file for 20230925.
# Failed to download the file for 20230926.
# Failed to download the file for 20230927.
# Failed to download the file for 20230928.
# Failed to download the file for 20230929.
# Failed to download the file for 20230930.
# All files downloaded. Total downloaded files: 4139. Total failed to download files: 2692

# %%
len(master_datas)
# Out:
# 178190

# %%
df = pd.DataFrame(master_datas)
df
# Out:
#        cik_number                                     company_name form_id  \
# 0         1044324           TROPICAL SPORTSWEAR INTERNATIONAL CORP    10-K
# 1          320303                                METAL ARTS CO INC    10-K
# 2          792130                                   DATAWATCH CORP    10-K
# 3          851478                  BEI MEDICAL SYSTEMS CO INC /DE/    10-K
# 4          884124                                 GALEY & LORD INC    10-K
# ...           ...                                              ...     ...
# 178185    1808898                           Benitec Biopharma Inc.    10-K
# 178186    1948565  Investcorp US Institutional Private Credit Fund    10-K
# 178187      33533                     ESPEY MFG & ELECTRONICS CORP    10-K
# 178188     718332                      RAVE RESTAURANT GROUP, INC.    10-K
# 178189     787253           NATURAL ALTERNATIVES INTERNATIONAL INC    10-K
#
#             date                                           file_url
# 0       19990104  https://www.sec.gov/Archives/edgar/data/104432...
# 1       19990104  https://www.sec.gov/Archives/edgar/data/320303...
# 2       19981229  https://www.sec.gov/Archives/edgar/data/792130...
# 3       19990104  https://www.sec.gov/Archives/edgar/data/851478...
# 4       19990104  https://www.sec.gov/Archives/edgar/data/884124...
# ...          ...                                                ...
# 178185  20230921  https://www.sec.gov/Archives/edgar/data/180889...
# 178186  20230921  https://www.sec.gov/Archives/edgar/data/194856...
# 178187  20230921  https://www.sec.gov/Archives/edgar/data/33533/...
# 178188  20230921  https://www.sec.gov/Archives/edgar/data/718332...
# 178189  20230921  https://www.sec.gov/Archives/edgar/data/787253...
#
# [178190 rows x 5 columns]

# %%
#filtered_df = df[df['form_id']=='10-K'].reset_index()
#filtered_df = filtered_df.drop(columns='index')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 178190 entries, 0 to 178189
# Data columns (total 5 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   cik_number    178190 non-null  object
#  1   company_name  178190 non-null  object
#  2   form_id       178190 non-null  object
#  3   date          178190 non-null  object
#  4   file_url      178190 non-null  object
# dtypes: object(5)
# memory usage: 6.8+ MB

# %%
# Save the final DataFrame to CSV
desired_path = '/content/drive/MyDrive/10-K_sec_filings_ver2.csv'
df.to_csv(desired_path, index=False)

print("DataFrame saved to CSV:", desired_path)
# Out:
# DataFrame saved to CSV: /content/drive/MyDrive/10-K_sec_filings_ver2.csv
