# %% [markdown]
# <a href="https://colab.research.google.com/github/winterForestStump/thesis/blob/main/evaluation/manual_evaluation_filter_rerank(6_2)_Coca_Cola.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json
from pprint import pprint

# Load your dataframe
# Replace 'your_data.csv' with the actual path to your data file
df1 = pd.read_json('/content/results_Coca_Cola_rerank_6-2_filter.json')

# Initialize dictionary to store results
results = {'index': [],
           'The context is relevant to the company': [],
           'The context is relevant to the question': [],
           'The response is correct': [],
           'The response answers the question': []}

# Check if there's a previous evaluation progress saved
try:
    with open('evaluation_results_rerank_6-2_filter.json', 'r') as f:
        previous_results = json.load(f)
    start_index = max(previous_results['index']) + 1
    results = previous_results
    print("Resuming evaluation from the last unanswered question.")
except (FileNotFoundError, ValueError, KeyError):
    start_index = 0
    print("Starting evaluation from the beginning.")

# Function to get valid user input (1 or 0)
def get_valid_input(message):
    while True:
        try:
            user_input = int(input(message))
            if user_input not in (0, 1):
                raise ValueError("Input must be 0 or 1.")
            return user_input
        except ValueError:
            print("Invalid input. Please enter 0 or 1.")

# Iterate over each row in the dataframe
for idx, row in df1.iloc[start_index:].iterrows():
    print("\nRow Index:", idx)
    print("Question:", row['question'])
    print("Response:", row['response'])
    print("Context:")
    pprint(row['context'], width=100)

    # Ask questions and get user input
    context_relevant_to_company = get_valid_input("Is the context relevant to the company? (1 for True, 0 for False): ")
    context_relevant_to_question = get_valid_input("Is the context relevant to the question? (1 for True, 0 for False): ")
    response_correct = get_valid_input("Is the response correct? (1 for True, 0 for False): ")
    response_answers_question = get_valid_input("Does the response answer the question? (1 for True, 0 for False): ")

    # Append results to dictionary
    results['index'].append(idx)
    results['The context is relevant to the company'].append(context_relevant_to_company)
    results['The context is relevant to the question'].append(context_relevant_to_question)
    results['The response is correct'].append(response_correct)
    results['The response answers the question'].append(response_answers_question)

    # Convert results dictionary to JSON and save to a file after each row
    json_result = json.dumps(results, indent=4)
    with open('evaluation_results_rerank_6-2_filter.json', 'w') as f:
        f.write(json_result)

    print("Progress saved.")

print("\nEvaluation results saved to 'evaluation_results_rerank_6-2_filter.json'.")
# Out:
# Starting evaluation from the beginning.
#
# Row Index: 0
# Question: What is the total revenue generated by the COCA COLA CO and how has the revenue changed over the past few years?
# Response: According to the document provided, the total revenue generated by COCA COLA CO in 2017 was $41,863 million. This represents a 10% increase from 2016, when the company's revenue was $38,235 million. There is no information provided in the document about the company's revenue in previous years.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2017_0000021344-18-000008.htm',
#                'filing_date': '2018-02-23',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134418000008/a2017123110-k.htm',
#                'period_of_report': '2017-12-31',
#                'relevance_score': 0.9493282437,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2017_0000021344-18-000008.json',
#                'state_location': 'GA'},
#   'page_content': 'Open commodity derivatives that do not qualify for hedge accounting had '
#                   'notional values of $357 million and $447 million as of December 31, 2017 and '
#                   '2016, respectively. The fair value of the contracts that do not qualify for '
#                   'hedge accounting resulted in a net unrealized gain of $20 million. The '
#                   'potential change in fair value of these commodity derivative instruments, '
#                   'assuming a 10 percent decrease in underlying commodity prices, would have '
#                   'eliminated the net unrealized gain and created a net unrealized loss of $18 '
#                   'million. ITEM 8. FINANCIAL STATEMENTS AND SUPPLEMENTARY DATA\n'
#                   'Page\n'
#                   'Consolidated Statements of Income\n'
#                   'Consolidated Statements of Comprehensive Income\n'
#                   'Consolidated Balance Sheets\n'
#                   'Consolidated Statements of Cash Flows\n'
#                   "Consolidated Statements of Shareowners' Equity\n"
#                   'Notes to Consolidated Financial Statements\n'
#                   'Report of Management\n'
#                   'Report of Independent Registered Public Accounting Firm\n'
#                   'Report of Independent Registered Public Accounting Firm on Internal Control '
#                   'Over Financial Reporting\n'
#                   'Quarterly Data (Unaudited)\n'
#                   'THE COCA-COLA COMPANY AND SUBSIDIARIES\n'
#                   'CONSOLIDATED STATEMENTS OF INCOME\n'
#                   'Year Ended December 31,\n'
#                   '(In millions except per share data)\n'
#                   'NET OPERATING REVENUES\n'
#                   '$\n'
#                   '35,410\n'
#                   '$\n'
#                   '41,863\n'
#                   '$\n'
#                   '44,294\n'
#                   'Cost of goods sold\n'
#                   '13,256\n'
#                   '16,465\n'
#                   '17,482\n'
#                   'GROSS PROFIT\n'
#                   '22,154\n'
#                   '25,398\n'
#                   '26,812\n'
#                   'Selling, general and administrative expenses\n'
#                   '12,496\n'
#                   '15,262\n'
#                   '16,427\n'
#                   'Other operating charges\n'
#                   '2,157\n'
#                   '1,510\n'
#                   '1,657\n'
#                   'OPERATING INCOME\n'
#                   '7,501\n'
#                   '8,626\n'
#                   '8,728\n'
#                   'Interest income\n'
#                   'Interest expense\n'
#                   'Equity income (loss) - net\n'
#                   '1,071\n'
#                   'Other income (loss) - net\n'
#                   '(1,666\n'
#                   ')\n'
#                   '(1,234\n'
#                   ')\n'
#                   'INCOME FROM CONTINUING OPERATIONS BEFORE INCOME TAXES\n'
#                   '6,742\n'
#                   '8,136\n'
#                   '9,605\n'
#                   'Income taxes from continuing operations\n'
#                   '5,560\n'
#                   '1,586\n'
#                   '2,239\n'
#                   'NET INCOME FROM CONTINUING OPERATIONS\n'
#                   '1,182\n'
#                   '6,550\n'
#                   '7,366\n'
#                   'Income from discontinued operations (net of income taxes of $47, $0 and $0, '
#                   'respectively)\n'
#                   '-\n'
#                   '-\n'
#                   'CONSOLIDATED NET INCOME\n'
#                   '1,283\n'
#                   '6,550\n'
#                   '7,366\n'
#                   'Less: Net income attributable to noncontrolling interests\n'
#                   'NET INCOME ATTRIBUTABLE TO SHAREOWNERS OF\n'
#                   'THE COCA-COLA COMPANY\n'
#                   '$\n'
#                   '1,248\n'
#                   '$\n'
#                   '6,527',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2017_0000021344-18-000008.htm',
#                'filing_date': '2018-02-23',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134418000008/a2017123110-k.htm',
#                'period_of_report': '2017-12-31',
#                'relevance_score': 0.9441539645,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2017_0000021344-18-000008.json',
#                'state_location': 'GA'},
#   'page_content': 'Because of its inherent limitations, internal control over financial reporting '
#                   'may not prevent or detect misstatements. Also, projections of any evaluation of '
#                   'effectiveness to future periods are subject to the risk that controls may '
#                   'become inadequate because of changes in conditions, or that the degree of '
#                   'compliance with the policies or procedures may deteriorate.\n'
#                   'Atlanta, Georgia\n'
#                   'February 23, 2018\n'
#                   'Quarterly Data (Unaudited)\n'
#                   'First\n'
#                   'Quarter\n'
#                   'Second\n'
#                   'Quarter\n'
#                   'Third\n'
#                   'Quarter\n'
#                   'Fourth\n'
#                   'Quarter\n'
#                   'Full Year\n'
#                   '(In millions except per share data)\n'
#                   'Net operating revenues\n'
#                   '$\n'
#                   '9,118\n'
#                   '$\n'
#                   '9,702\n'
#                   '$\n'
#                   '9,078\n'
#                   '$\n'
#                   '7,512\n'
#                   '$\n'
#                   '35,410\n'
#                   'Gross profit\n'
#                   '5,605\n'
#                   '6,043\n'
#                   '5,683\n'
#                   '4,823\n'
#                   '22,154\n'
#                   'Net income (loss) attributable to shareowners of\n'
#                   'The Coca-Cola Company\n'
#                   '1,182\n'
#                   '1,371\n'
#                   '1,447\n'
#                   '(2,752\n'
#                   ')\n'
#                   '1,248\n'
#                   'Basic net income (loss) per share\n'
#                   '$\n'
#                   '0.28\n'
#                   '$\n'
#                   '0.32\n'
#                   '$\n'
#                   '0.34\n'
#                   '$\n'
#                   '(0.65\n'
#                   ')\n'
#                   '$\n'
#                   '0.29\n'
#                   'Diluted net income (loss) per share\n'
#                   '$\n'
#                   '0.27\n'
#                   '$\n'
#                   '0.32\n'
#                   '$\n'
#                   '0.33\n'
#                   '$\n'
#                   '(0.65\n'
#                   ')\n'
#                   '$\n'
#                   '0.29\n'
#                   'Net operating revenues\n'
#                   '$\n'
#                   '10,282\n'
#                   '$\n'
#                   '11,539\n'
#                   '$\n'
#                   '10,633\n'
#                   '$\n'
#                   '9,409\n'
#                   '$\n'
#                   '41,863\n'
#                   'Gross profit\n'
#                   '6,213\n'
#                   '7,068\n'
#                   '6,502\n'
#                   '5,615\n'
#                   '25,398\n'
#                   'Net income attributable to shareowners of\n'
#                   'The Coca-Cola Company\n'
#                   '1,483\n'
#                   '3,448\n'
#                   '1,046\n'
#                   '6,527\n'
#                   'Basic net income per share\n'
#                   '$\n'
#                   '0.34\n'
#                   '$\n'
#                   '0.80\n'
#                   '$\n'
#                   '0.24\n'
#                   '$\n'
#                   '0.13\n'
#                   '$\n'
#                   '1.51\n'
#                   'Diluted net income per share\n'
#                   '$\n'
#                   '0.34\n'
#                   '$\n'
#                   '0.79\n'
#                   '$\n'
#                   '0.24\n'
#                   '$\n'
#                   '0.13\n'
#                   '$\n'
#                   '1.49\n'
#                   'The sum of the quarterly net income per share amounts does not agree to the '
#                   'full year net income per share amounts. We calculate net income per share based '
#                   'on the weighted-average number of outstanding shares during the reporting '
#                   'period. The average number of shares fluctuates throughout the year and can '
#                   'therefore produce a full year result that does not agree to the sum of the '
#                   'individual quarters.\n'
#                   'Our first quarter, second quarter and third quarter reporting periods end on '
#                   'the Friday closest to the last day of the applicable quarterly calendar period. '
#                   'Our fourth quarter and fiscal year end on December 31 regardless of the day of '
#                   'the week on which December 31 falls.',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 0
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 1
# Question: What is the COCA COLA CO's cost of goods sold (COGS) and how does the COGS compare to the total revenue?
# Response: According to the document provided, the COCA COLA CO's cost of goods sold (COGS) was $13,256 million in 2021, $16,465 million in 2019, and $17,482 million in 2017. This information can be found in the "Consolidated Statements of Income" section of the document.
# To answer your second question, the COGS as a percentage of total revenue is as follows:
# * In 2021, COGS was 35.6% of total revenue.
# * In 2019, COGS was 34.3% of total revenue.
# * In 2017, COGS was 35.4% of total revenue.
# Therefore, the COGS as a percentage of total revenue has remained relatively consistent over the past few years.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2021_0000021344-22-000009.htm',
#                'filing_date': '2022-02-22',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134422000009/ko-20211231.htm',
#                'period_of_report': '2021-12-31',
#                'relevance_score': 0.9658317566,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2021_0000021344-22-000009.json',
#                'state_location': 'GA'},
#   'page_content': 'Consolidated Balance Sheets\n'
#                   'Consolidated Statements of Cash Flows\n'
#                   'Consolidated Statements of Shareowners Equity\n'
#                   'Notes to Consolidated Financial Statements\n'
#                   'Report of Management\n'
#                   'Report of Independent Registered Public Accounting Firm (PCAOB ID: 42)\n'
#                   'Report of Independent Registered Public Accounting Firm on Internal Control '
#                   'Over Financial Reporting\n'
#                   'THE COCA-COLA COMPANY AND SUBSIDIARIES\n'
#                   'CONSOLIDATED STATEMENTS OF INCOME\n'
#                   '(In millions except per share data)\n'
#                   'Year Ended December 31, 2021 2020 2019\n'
#                   'Net Operating Revenues $ 38,655 $ 33,014 $ 37,266\n'
#                   'Cost of goods sold 15,357 13,433 14,619\n'
#                   'Gross Profit 23,298 19,581 22,647\n'
#                   'Selling, general and administrative expenses 12,144 9,731 12,103\n'
#                   'Other operating charges 846 853 458\n'
#                   'Operating Income 10,308 8,997 10,086\n'
#                   'Interest income 276 370 563\n'
#                   'Interest expense 1,597 1,437 946\n'
#                   'Equity income (loss) - net 1,438 978 1,049\n'
#                   'Other income (loss) - net 2,000 841 34\n'
#                   'Income Before Income Taxes 12,425 9,749 10,786\n'
#                   'Income taxes 2,621 1,981 1,801\n'
#                   'Consolidated Net Income 9,804 7,768 8,985\n'
#                   'Less: Net income (loss) attributable to noncontrolling interests 33 21 65\n'
#                   'Net Income Attributable to Shareowners of The Coca-Cola Company $ 9,771 $ 7,747 '
#                   '$ 8,920\n'
#                   'Basic Net Income Per Share1\n'
#                   '$ 2.26 $ 1.80 $ 2.09\n'
#                   'Diluted Net Income Per Share1\n'
#                   '$ 2.25 $ 1.79 $ 2.07\n'
#                   'Average Shares Outstanding - Basic 4,315 4,295 4,276\n'
#                   'Effect of dilutive securities 25 28 38\n'
#                   'Average Shares Outstanding - Diluted 4,340 4,323 4,314\n'
#                   '1 Calculated based on net income attributable to shareowners of The Coca-Cola '
#                   'Company.\n'
#                   'Refer to Notes to Consolidated Financial Statements.\n'
#                   'THE COCA-COLA COMPANY AND SUBSIDIARIES\n'
#                   'CONSOLIDATED STATEMENTS OF COMPREHENSIVE INCOME\n'
#                   '(In millions)\n'
#                   'Year Ended December 31, 2021 2020 2019\n'
#                   'Consolidated Net Income $ 9,804 $ 7,768 $ 8,985\n'
#                   'Other Comprehensive Income:\n'
#                   'Net foreign currency translation adjustments (699) (911) 74\n'
#                   'Net gains (losses) on derivatives 214 15 (54)\n'
#                   'Net change in unrealized gains (losses) on available-for-sale debt securities '
#                   '(90) (47) 18',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2017_0000021344-18-000008.htm',
#                'filing_date': '2018-02-23',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134418000008/a2017123110-k.htm',
#                'period_of_report': '2017-12-31',
#                'relevance_score': 0.9658139348,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2017_0000021344-18-000008.json',
#                'state_location': 'GA'},
#   'page_content': 'Open commodity derivatives that do not qualify for hedge accounting had '
#                   'notional values of $357 million and $447 million as of December 31, 2017 and '
#                   '2016, respectively. The fair value of the contracts that do not qualify for '
#                   'hedge accounting resulted in a net unrealized gain of $20 million. The '
#                   'potential change in fair value of these commodity derivative instruments, '
#                   'assuming a 10 percent decrease in underlying commodity prices, would have '
#                   'eliminated the net unrealized gain and created a net unrealized loss of $18 '
#                   'million. ITEM 8. FINANCIAL STATEMENTS AND SUPPLEMENTARY DATA\n'
#                   'Page\n'
#                   'Consolidated Statements of Income\n'
#                   'Consolidated Statements of Comprehensive Income\n'
#                   'Consolidated Balance Sheets\n'
#                   'Consolidated Statements of Cash Flows\n'
#                   "Consolidated Statements of Shareowners' Equity\n"
#                   'Notes to Consolidated Financial Statements\n'
#                   'Report of Management\n'
#                   'Report of Independent Registered Public Accounting Firm\n'
#                   'Report of Independent Registered Public Accounting Firm on Internal Control '
#                   'Over Financial Reporting\n'
#                   'Quarterly Data (Unaudited)\n'
#                   'THE COCA-COLA COMPANY AND SUBSIDIARIES\n'
#                   'CONSOLIDATED STATEMENTS OF INCOME\n'
#                   'Year Ended December 31,\n'
#                   '(In millions except per share data)\n'
#                   'NET OPERATING REVENUES\n'
#                   '$\n'
#                   '35,410\n'
#                   '$\n'
#                   '41,863\n'
#                   '$\n'
#                   '44,294\n'
#                   'Cost of goods sold\n'
#                   '13,256\n'
#                   '16,465\n'
#                   '17,482\n'
#                   'GROSS PROFIT\n'
#                   '22,154\n'
#                   '25,398\n'
#                   '26,812\n'
#                   'Selling, general and administrative expenses\n'
#                   '12,496\n'
#                   '15,262\n'
#                   '16,427\n'
#                   'Other operating charges\n'
#                   '2,157\n'
#                   '1,510\n'
#                   '1,657\n'
#                   'OPERATING INCOME\n'
#                   '7,501\n'
#                   '8,626\n'
#                   '8,728\n'
#                   'Interest income\n'
#                   'Interest expense\n'
#                   'Equity income (loss) - net\n'
#                   '1,071\n'
#                   'Other income (loss) - net\n'
#                   '(1,666\n'
#                   ')\n'
#                   '(1,234\n'
#                   ')\n'
#                   'INCOME FROM CONTINUING OPERATIONS BEFORE INCOME TAXES\n'
#                   '6,742\n'
#                   '8,136\n'
#                   '9,605\n'
#                   'Income taxes from continuing operations\n'
#                   '5,560\n'
#                   '1,586\n'
#                   '2,239\n'
#                   'NET INCOME FROM CONTINUING OPERATIONS\n'
#                   '1,182\n'
#                   '6,550\n'
#                   '7,366\n'
#                   'Income from discontinued operations (net of income taxes of $47, $0 and $0, '
#                   'respectively)\n'
#                   '-\n'
#                   '-\n'
#                   'CONSOLIDATED NET INCOME\n'
#                   '1,283\n'
#                   '6,550\n'
#                   '7,366\n'
#                   'Less: Net income attributable to noncontrolling interests\n'
#                   'NET INCOME ATTRIBUTABLE TO SHAREOWNERS OF\n'
#                   'THE COCA-COLA COMPANY\n'
#                   '$\n'
#                   '1,248\n'
#                   '$\n'
#                   '6,527',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 0
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 2
# Question: What is the COCA COLA CO's gross profit margin, and how has it evolved?
# Response: The answer is in the context! According to the provided information, Coca-Cola's gross profit margin was 58.1% in 2022, down from 60.3% in 2021. Additionally, the company's gross profit margin decreased to 62.6% in 2017 from 60.7% in 2016.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2017_0000021344-18-000008.htm',
#                'filing_date': '2018-02-23',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134418000008/a2017123110-k.htm',
#                'period_of_report': '2017-12-31',
#                'relevance_score': 0.9644221067000001,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2017_0000021344-18-000008.json',
#                'state_location': 'GA'},
#   'page_content': 'Gross Profit Margin\n'
#                   'As a result of our finished goods operations, which are primarily included in '
#                   'our North America and Bottling Investments operating segments, the following '
#                   "inputs represent a substantial portion of the Company's total cost of goods "
#                   'sold: (1) sweeteners, (2) metals, (3) juices and (4) PET. The Company enters '
#                   'into hedging activities related to certain commodities in order to mitigate a '
#                   'portion of the price risk associated with forecasted purchases. Many of the '
#                   'derivative financial instruments used by the Company to mitigate the risk '
#                   'associated with these commodity exposures, including any related foreign '
#                   'currency exposure, do not qualify for hedge accounting. As a result, the '
#                   'changes in fair value of these derivative instruments have been, and will '
#                   'continue to be, included as a component of net income in each reporting period. '
#                   'The Company recorded gains related to these derivatives of $14 million and $79 '
#                   'million during the years ended December 31, 2017 and December 31, 2016, '
#                   'respectively, and recorded a loss of $206 million during the year ended '
#                   'December 31, 2015 in the line item cost of goods sold in our consolidated '
#                   'statements of income. Refer to Note 5 of Notes to Consolidated Financial '
#                   'Statements. We do not currently expect changes in commodity costs to have a '
#                   'significant impact on our 2018 gross profit margin as compared to 2017.\n'
#                   'Year Ended December 31, 2017 versus Year Ended December 31, 2016\n'
#                   'Our gross profit margin increased to 62.6 percent in 2017 from 60.7 percent in '
#                   '2016. The increase was primarily due to the impact of acquisitions and '
#                   'divestitures, partially offset by the unfavorable impact of foreign currency '
#                   'exchange rate fluctuations. Refer to Note 2 of Notes to Consolidated Financial '
#                   'Statements for additional information related to acquisitions and '
#                   'divestitures.\n'
#                   'Year Ended December 31, 2016 versus Year Ended December 31, 2015',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2022_0000021344-23-000011.htm',
#                'filing_date': '2023-02-21',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134423000011/ko-20221231.htm',
#                'period_of_report': '2022-12-31',
#                'relevance_score': 0.9571086168,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2022_0000021344-23-000011.json',
#                'state_location': 'GA'},
#   'page_content': 'Latin America 11.4 10.7\n'
#                   'North America 36.5 34.1\n'
#                   'Asia Pacific 11.0 12.1\n'
#                   'Global Ventures 6.6 7.3\n'
#                   'Bottling Investments 18.3 18.6\n'
#                   'Corporate 0.2 0.2\n'
#                   'Total 100.0 % 100.0 %\n'
#                   'The percentage contribution of each operating segment fluctuates over time due '
#                   'to net operating revenues in some operating segments growing at a faster rate '
#                   'compared to other operating segments. In addition, foreign currency exchange '
#                   'rate fluctuations impact the percentage contribution of each operating segment. '
#                   'For additional information about the impact of foreign currency exchange rate '
#                   'fluctuations, refer to the heading Liquidity, Capital Resources and Financial '
#                   'Position - Foreign Exchange below.\n'
#                   'Gross Profit Margin\n'
#                   'Gross profit margin is a ratio calculated by dividing gross profit by net '
#                   'operating revenues. Management believes gross profit margin provides investors '
#                   'with useful information related to the profitability of our business prior to '
#                   'considering all of the selling, general and administrative expenses and other '
#                   'operating charges incurred. Management uses this measure in making financial, '
#                   'operating and planning decisions and in evaluating the Companys performance.\n'
#                   'Our gross profit margin decreased to 58.1 percent in 2022 from 60.3 percent in '
#                   '2021. This decrease was primarily due to the unfavorable impact of foreign '
#                   'currency exchange rate fluctuations, increased commodity and transportation '
#                   'costs, and the acquisition of BodyArmor, a finished goods business, in November '
#                   '2021. The impact of these items was partially offset by favorable pricing '
#                   'initiatives as well as favorable channel and package mix. We expect commodity '
#                   'and transportation costs to continue to have an unfavorable impact on our gross '
#                   'profit margin in 2023, and we will continue to proactively take actions in an '
#                   'effort to mitigate the impact of these incremental costs.\n'
#                   'Selling, General and Administrative Expenses\n'
#                   'The following table sets forth the components of selling, general and '
#                   'administrative expenses (in millions):',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 3
# Question: What are the COCA COLA CO's major operating expenses and how have these expenses changed over time?
# Response: Based on the information provided in the document, the major operating expenses of COCA COLA CO include:
# 1. Cost of goods sold: This refers to the cost of raw materials and production costs associated with manufacturing and selling Coca-Cola products. In 2017, the cost of goods sold was $13.25 billion, while in 2016 it was $16.46 billion.
# 2. Selling, general, and administrative expenses: These are expenses related to selling and distributing Coca-Cola products, as well as general administrative expenses such as salaries and office rent. In 2017, selling, general, and administrative expenses were $12.5 billion, while in 2016 they were $15.3 billion.
# 3. Depreciation and amortization: These are expenses related to the depreciation of fixed assets and the amortization of intangible assets. In 2017, depreciation and amortization expenses were $1.45 billion, while in 2016 they were $1.53 billion.
# 4. Interest expense: This is interest paid on the company's debt. In 2017, interest expense was $1.36 billion, while in 2016 it was $1.23 billion.
#
# Overall, the major operating expenses of COCA COLA CO have remained relatively consistent over time, with some fluctuations in specific categories. For example, the cost of goods sold decreased slightly between 2016 and 2017, while selling, general, and administrative expenses increased slightly during the same period.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2017_0000021344-18-000008.htm',
#                'filing_date': '2018-02-23',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134418000008/a2017123110-k.htm',
#                'period_of_report': '2017-12-31',
#                'relevance_score': 0.9574280381,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2017_0000021344-18-000008.json',
#                'state_location': 'GA'},
#   'page_content': 'Open commodity derivatives that do not qualify for hedge accounting had '
#                   'notional values of $357 million and $447 million as of December 31, 2017 and '
#                   '2016, respectively. The fair value of the contracts that do not qualify for '
#                   'hedge accounting resulted in a net unrealized gain of $20 million. The '
#                   'potential change in fair value of these commodity derivative instruments, '
#                   'assuming a 10 percent decrease in underlying commodity prices, would have '
#                   'eliminated the net unrealized gain and created a net unrealized loss of $18 '
#                   'million. ITEM 8. FINANCIAL STATEMENTS AND SUPPLEMENTARY DATA\n'
#                   'Page\n'
#                   'Consolidated Statements of Income\n'
#                   'Consolidated Statements of Comprehensive Income\n'
#                   'Consolidated Balance Sheets\n'
#                   'Consolidated Statements of Cash Flows\n'
#                   "Consolidated Statements of Shareowners' Equity\n"
#                   'Notes to Consolidated Financial Statements\n'
#                   'Report of Management\n'
#                   'Report of Independent Registered Public Accounting Firm\n'
#                   'Report of Independent Registered Public Accounting Firm on Internal Control '
#                   'Over Financial Reporting\n'
#                   'Quarterly Data (Unaudited)\n'
#                   'THE COCA-COLA COMPANY AND SUBSIDIARIES\n'
#                   'CONSOLIDATED STATEMENTS OF INCOME\n'
#                   'Year Ended December 31,\n'
#                   '(In millions except per share data)\n'
#                   'NET OPERATING REVENUES\n'
#                   '$\n'
#                   '35,410\n'
#                   '$\n'
#                   '41,863\n'
#                   '$\n'
#                   '44,294\n'
#                   'Cost of goods sold\n'
#                   '13,256\n'
#                   '16,465\n'
#                   '17,482\n'
#                   'GROSS PROFIT\n'
#                   '22,154\n'
#                   '25,398\n'
#                   '26,812\n'
#                   'Selling, general and administrative expenses\n'
#                   '12,496\n'
#                   '15,262\n'
#                   '16,427\n'
#                   'Other operating charges\n'
#                   '2,157\n'
#                   '1,510\n'
#                   '1,657\n'
#                   'OPERATING INCOME\n'
#                   '7,501\n'
#                   '8,626\n'
#                   '8,728\n'
#                   'Interest income\n'
#                   'Interest expense\n'
#                   'Equity income (loss) - net\n'
#                   '1,071\n'
#                   'Other income (loss) - net\n'
#                   '(1,666\n'
#                   ')\n'
#                   '(1,234\n'
#                   ')\n'
#                   'INCOME FROM CONTINUING OPERATIONS BEFORE INCOME TAXES\n'
#                   '6,742\n'
#                   '8,136\n'
#                   '9,605\n'
#                   'Income taxes from continuing operations\n'
#                   '5,560\n'
#                   '1,586\n'
#                   '2,239\n'
#                   'NET INCOME FROM CONTINUING OPERATIONS\n'
#                   '1,182\n'
#                   '6,550\n'
#                   '7,366\n'
#                   'Income from discontinued operations (net of income taxes of $47, $0 and $0, '
#                   'respectively)\n'
#                   '-\n'
#                   '-\n'
#                   'CONSOLIDATED NET INCOME\n'
#                   '1,283\n'
#                   '6,550\n'
#                   '7,366\n'
#                   'Less: Net income attributable to noncontrolling interests\n'
#                   'NET INCOME ATTRIBUTABLE TO SHAREOWNERS OF\n'
#                   'THE COCA-COLA COMPANY\n'
#                   '$\n'
#                   '1,248\n'
#                   '$\n'
#                   '6,527',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2021_0000021344-22-000009.htm',
#                'filing_date': '2022-02-22',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134422000009/ko-20211231.htm',
#                'period_of_report': '2021-12-31',
#                'relevance_score': 0.9489872456,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2021_0000021344-22-000009.json',
#                'state_location': 'GA'},
#   'page_content': 'The Coca-Cola Company Shareowners Equity\n'
#                   'Common stock, $0.25 par value; authorized - 11,200 shares; issued - 7,040 '
#                   'shares\n'
#                   '1,760 1,760\n'
#                   'Capital surplus 18,116 17,601\n'
#                   'Reinvested earnings 69,094 66,555\n'
#                   'Accumulated other comprehensive income (loss) (14,330) (14,601)\n'
#                   'Treasury stock, at cost - 2,715 and 2,738 shares, respectively\n'
#                   '(51,641) (52,016)\n'
#                   'Equity Attributable to Shareowners of The Coca-Cola Company 22,999 19,299\n'
#                   'Equity attributable to noncontrolling interests 1,861 1,985\n'
#                   'Total Equity 24,860 21,284\n'
#                   'Total Liabilities and Equity $ 94,354 $ 87,296\n'
#                   'Refer to Notes to Consolidated Financial Statements.\n'
#                   'THE COCA-COLA COMPANY AND SUBSIDIARIES\n'
#                   'CONSOLIDATED STATEMENTS OF CASH FLOWS\n'
#                   '(In millions)\n'
#                   'Year Ended December 31, 2021 2020 2019\n'
#                   'Operating Activities\n'
#                   'Consolidated net income $ 9,804 $ 7,768 $ 8,985\n'
#                   'Depreciation and amortization 1,452 1,536 1,365\n'
#                   'Stock-based compensation expense 337 126 201\n'
#                   'Deferred income taxes 894 (18) (280)\n'
#                   'Equity (income) loss - net of dividends (615) (511) (421)\n'
#                   'Foreign currency adjustments 86 (88) 91\n'
#                   'Significant (gains) losses - net (1,365) (914) (467)\n'
#                   'Other operating charges 506 556 127\n'
#                   'Other items 201 699 504\n'
#                   'Net change in operating assets and liabilities 1,325 690 366\n'
#                   'Net Cash Provided by Operating Activities 12,625 9,844 10,471\n'
#                   'Investing Activities\n'
#                   'Purchases of investments (6,030) (13,583) (4,704)\n'
#                   'Proceeds from disposals of investments 7,059 13,835 6,973\n'
#                   'Acquisitions of businesses, equity method investments and nonmarketable '
#                   'securities (4,766) (1,052) (5,542)\n'
#                   'Proceeds from disposals of businesses, equity method investments and '
#                   'nonmarketable securities 2,180 189 429\n'
#                   'Purchases of property, plant and equipment (1,367) (1,177) (2,054)\n'
#                   'Proceeds from disposals of property, plant and equipment 108 189 978\n'
#                   'Other investing activities 51 122 (56)\n'
#                   'Net Cash Provided by (Used in) Investing Activities (2,765) (1,477) (3,976)\n'
#                   'Financing Activities\n'
#                   'Issuances of debt 13,094 26,934 23,009\n'
#                   'Payments of debt (12,866) (28,796) (24,850)\n'
#                   'Issuances of stock 702 647 1,012',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 0
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 4
# Question: What is the COCA COLA CO's operating income and how does it compare to the previous years?
# Response: The answer to your question is not directly provided in the given text. However, we can calculate the operating income for The Coca-Cola Company (COCA COLA CO) based on the information provided in the document:
# For the year ended December 31, 2021, COCA COLA CO's operating income was $9,804 million. This represents an increase of $1,944 million compared to the previous year (2020), and a decrease of $1,063 million compared to the two years prior (2019).
# Here is the operating income for each year mentioned in the document:
# * 2021: $9,804 million
# * 2020: $7,768 million (an increase of $2,036 million compared to 2019)
# * 2019: $8,985 million (a decrease of $1,063 million compared to 2020)
# Please note that these calculations are based on the information provided in the document and may not reflect the full picture of the company's financial performance.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2017_0000021344-18-000008.htm',
#                'filing_date': '2018-02-23',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134418000008/a2017123110-k.htm',
#                'period_of_report': '2017-12-31',
#                'relevance_score': 0.9569788575,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2017_0000021344-18-000008.json',
#                'state_location': 'GA'},
#   'page_content': 'Because of its inherent limitations, internal control over financial reporting '
#                   'may not prevent or detect misstatements. Also, projections of any evaluation of '
#                   'effectiveness to future periods are subject to the risk that controls may '
#                   'become inadequate because of changes in conditions, or that the degree of '
#                   'compliance with the policies or procedures may deteriorate.\n'
#                   'Atlanta, Georgia\n'
#                   'February 23, 2018\n'
#                   'Quarterly Data (Unaudited)\n'
#                   'First\n'
#                   'Quarter\n'
#                   'Second\n'
#                   'Quarter\n'
#                   'Third\n'
#                   'Quarter\n'
#                   'Fourth\n'
#                   'Quarter\n'
#                   'Full Year\n'
#                   '(In millions except per share data)\n'
#                   'Net operating revenues\n'
#                   '$\n'
#                   '9,118\n'
#                   '$\n'
#                   '9,702\n'
#                   '$\n'
#                   '9,078\n'
#                   '$\n'
#                   '7,512\n'
#                   '$\n'
#                   '35,410\n'
#                   'Gross profit\n'
#                   '5,605\n'
#                   '6,043\n'
#                   '5,683\n'
#                   '4,823\n'
#                   '22,154\n'
#                   'Net income (loss) attributable to shareowners of\n'
#                   'The Coca-Cola Company\n'
#                   '1,182\n'
#                   '1,371\n'
#                   '1,447\n'
#                   '(2,752\n'
#                   ')\n'
#                   '1,248\n'
#                   'Basic net income (loss) per share\n'
#                   '$\n'
#                   '0.28\n'
#                   '$\n'
#                   '0.32\n'
#                   '$\n'
#                   '0.34\n'
#                   '$\n'
#                   '(0.65\n'
#                   ')\n'
#                   '$\n'
#                   '0.29\n'
#                   'Diluted net income (loss) per share\n'
#                   '$\n'
#                   '0.27\n'
#                   '$\n'
#                   '0.32\n'
#                   '$\n'
#                   '0.33\n'
#                   '$\n'
#                   '(0.65\n'
#                   ')\n'
#                   '$\n'
#                   '0.29\n'
#                   'Net operating revenues\n'
#                   '$\n'
#                   '10,282\n'
#                   '$\n'
#                   '11,539\n'
#                   '$\n'
#                   '10,633\n'
#                   '$\n'
#                   '9,409\n'
#                   '$\n'
#                   '41,863\n'
#                   'Gross profit\n'
#                   '6,213\n'
#                   '7,068\n'
#                   '6,502\n'
#                   '5,615\n'
#                   '25,398\n'
#                   'Net income attributable to shareowners of\n'
#                   'The Coca-Cola Company\n'
#                   '1,483\n'
#                   '3,448\n'
#                   '1,046\n'
#                   '6,527\n'
#                   'Basic net income per share\n'
#                   '$\n'
#                   '0.34\n'
#                   '$\n'
#                   '0.80\n'
#                   '$\n'
#                   '0.24\n'
#                   '$\n'
#                   '0.13\n'
#                   '$\n'
#                   '1.51\n'
#                   'Diluted net income per share\n'
#                   '$\n'
#                   '0.34\n'
#                   '$\n'
#                   '0.79\n'
#                   '$\n'
#                   '0.24\n'
#                   '$\n'
#                   '0.13\n'
#                   '$\n'
#                   '1.49\n'
#                   'The sum of the quarterly net income per share amounts does not agree to the '
#                   'full year net income per share amounts. We calculate net income per share based '
#                   'on the weighted-average number of outstanding shares during the reporting '
#                   'period. The average number of shares fluctuates throughout the year and can '
#                   'therefore produce a full year result that does not agree to the sum of the '
#                   'individual quarters.\n'
#                   'Our first quarter, second quarter and third quarter reporting periods end on '
#                   'the Friday closest to the last day of the applicable quarterly calendar period. '
#                   'Our fourth quarter and fiscal year end on December 31 regardless of the day of '
#                   'the week on which December 31 falls.',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2021_0000021344-22-000009.htm',
#                'filing_date': '2022-02-22',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134422000009/ko-20211231.htm',
#                'period_of_report': '2021-12-31',
#                'relevance_score': 0.9558358788,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2021_0000021344-22-000009.json',
#                'state_location': 'GA'},
#   'page_content': 'The Coca-Cola Company Shareowners Equity\n'
#                   'Common stock, $0.25 par value; authorized - 11,200 shares; issued - 7,040 '
#                   'shares\n'
#                   '1,760 1,760\n'
#                   'Capital surplus 18,116 17,601\n'
#                   'Reinvested earnings 69,094 66,555\n'
#                   'Accumulated other comprehensive income (loss) (14,330) (14,601)\n'
#                   'Treasury stock, at cost - 2,715 and 2,738 shares, respectively\n'
#                   '(51,641) (52,016)\n'
#                   'Equity Attributable to Shareowners of The Coca-Cola Company 22,999 19,299\n'
#                   'Equity attributable to noncontrolling interests 1,861 1,985\n'
#                   'Total Equity 24,860 21,284\n'
#                   'Total Liabilities and Equity $ 94,354 $ 87,296\n'
#                   'Refer to Notes to Consolidated Financial Statements.\n'
#                   'THE COCA-COLA COMPANY AND SUBSIDIARIES\n'
#                   'CONSOLIDATED STATEMENTS OF CASH FLOWS\n'
#                   '(In millions)\n'
#                   'Year Ended December 31, 2021 2020 2019\n'
#                   'Operating Activities\n'
#                   'Consolidated net income $ 9,804 $ 7,768 $ 8,985\n'
#                   'Depreciation and amortization 1,452 1,536 1,365\n'
#                   'Stock-based compensation expense 337 126 201\n'
#                   'Deferred income taxes 894 (18) (280)\n'
#                   'Equity (income) loss - net of dividends (615) (511) (421)\n'
#                   'Foreign currency adjustments 86 (88) 91\n'
#                   'Significant (gains) losses - net (1,365) (914) (467)\n'
#                   'Other operating charges 506 556 127\n'
#                   'Other items 201 699 504\n'
#                   'Net change in operating assets and liabilities 1,325 690 366\n'
#                   'Net Cash Provided by Operating Activities 12,625 9,844 10,471\n'
#                   'Investing Activities\n'
#                   'Purchases of investments (6,030) (13,583) (4,704)\n'
#                   'Proceeds from disposals of investments 7,059 13,835 6,973\n'
#                   'Acquisitions of businesses, equity method investments and nonmarketable '
#                   'securities (4,766) (1,052) (5,542)\n'
#                   'Proceeds from disposals of businesses, equity method investments and '
#                   'nonmarketable securities 2,180 189 429\n'
#                   'Purchases of property, plant and equipment (1,367) (1,177) (2,054)\n'
#                   'Proceeds from disposals of property, plant and equipment 108 189 978\n'
#                   'Other investing activities 51 122 (56)\n'
#                   'Net Cash Provided by (Used in) Investing Activities (2,765) (1,477) (3,976)\n'
#                   'Financing Activities\n'
#                   'Issuances of debt 13,094 26,934 23,009\n'
#                   'Payments of debt (12,866) (28,796) (24,850)\n'
#                   'Issuances of stock 702 647 1,012',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 0
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 5
# Question: What is the COCA COLA CO's net income for the current fiscal year and how has net income trended over the past few years?
# ...
#                   '23, 2018 - incorporated herein by reference to Exhibit 10.6 to the Companys '
#                   'Quarterly Report on Form 10-Q for the quarter ended March 30, 2018.*\n'
#                   '10.7.2\n'
#                   'Amendment Two to The Coca-Cola Company Supplemental 401(k) Plan, dated December '
#                   '9, 2020 - incorporated herein by reference to Exhibit 10.9.2 to the Companys '
#                   'Annual Report on Form 10-K for the year ended December 31, 2020.*\n'
#                   '10.7.3\n'
#                   'Amendment Three to The Coca-Cola Company Supplemental 401(k) Plan, dated August '
#                   '9, 2022 - incorporated herein by reference to Exhibit 10.8 to the Companys '
#                   'Quarterly Report on Form 10-Q for the quarter ended September 30, 2022.*\n'
#                   '10.8\n'
#                   'The Coca-Cola Company Supplemental Cash Balance Plan, effective January 1, 2012 '
#                   '(the Supplemental Cash Balance Plan) - incorporated herein by reference to '
#                   'Exhibit 10.12 to the Companys Annual Report on Form 10-K for the year ended '
#                   'December 31, 2011.*\n'
#                   '10.8.1\n'
#                   'Amendment One to the Supplemental Cash Balance Plan, dated December 6, 2012 - '
#                   'incorporated herein by reference to Exhibit 10.12.2 to the Companys Annual '
#                   'Report on Form 10-K for the year ended December 31, 2012.*\n'
#                   '10.8.2',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 33
# Question: How does the COCA COLA CO leverage technology for its operations and are there ongoing technological advancements?
# Response: The answer is in the context. According to the provided documents, COCA COLA CO is actively leveraging technology for its operations, including digitization initiatives aimed at creating more relevant and personalized experiences for consumers, improving operational efficiency through the use of data, artificial intelligence, automation, robotics, and digital devices, and enhancing customer experience through digital tools and capabilities. The company also acknowledges that negative publicity concerning product safety or quality, workplace and human rights, obesity, or other issues can damage its brand image, corporate reputation, and social license to operate, which may negatively impact its business.
# Therefore, based on the provided information, it appears that COCA COLA CO is indeed leveraging technology for its operations and is aware of the potential risks associated with negative publicity concerning various issues.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2021_0000021344-22-000009.htm',
#                'filing_date': '2022-02-22',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134422000009/ko-20211231.htm',
#                'period_of_report': '2021-12-31',
#                'relevance_score': 0.9674528837,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2021_0000021344-22-000009.json',
#                'state_location': 'GA'},
#   'page_content': 'If we are not successful in our efforts to digitize the Coca-Cola system, our '
#                   'financial results could be negatively affected.\n'
#                   'The digital evolution is affecting how we interact with consumers, customers, '
#                   'suppliers, bottlers and other business partners and stakeholders. We believe '
#                   'that our future success will depend in part on our ability to adapt to and '
#                   'thrive in the digital environment. Therefore, one of our top priorities is to '
#                   'digitize the Coca-Cola system by, among other things, creating more relevant '
#                   'and more personalized experiences wherever our system interacts with consumers, '
#                   'whether in a digital environment or through digital devices in an otherwise '
#                   'physical environment; finding ways to create more powerful digital tools and '
#                   'capabilities for the Coca-Cola systems retail customers to enable them to grow '
#                   'their businesses; and digitizing operations through the use of data, artificial '
#                   'intelligence, automation, robotics and digital devices to increase efficiency '
#                   'and productivity. If we are not successful in our efforts to digitize the '
#                   'Coca-Cola system, our ability to increase sales and reduce costs may be '
#                   'negatively affected and the cost and expenses we have incurred or may incur in '
#                   'connection with our digitization initiatives may adversely impact our financial '
#                   'performance.\n'
#                   'If negative publicity, whether or not warranted, concerning product safety or '
#                   'quality, workplace and human rights, obesity or other issues damages our brand '
#                   'image, corporate reputation and social license to operate, our business may '
#                   'suffer.',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2022_0000021344-23-000011.htm',
#                'filing_date': '2023-02-21',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134423000011/ko-20221231.htm',
#                'period_of_report': '2022-12-31',
#                'relevance_score': 0.9630485177,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2022_0000021344-23-000011.json',
#                'state_location': 'GA'},
#   'page_content': 'If we are not successful in our efforts to digitalize the Coca-Cola system, our '
#                   'financial results could be negatively affected.\n'
#                   'The digital evolution is affecting how we interact with consumers, customers, '
#                   'suppliers, bottlers and other business partners and stakeholders. We believe '
#                   'our future success will depend in part on our ability to adapt to and thrive in '
#                   'the digital environment. Therefore, one of our top priorities is to digitalize '
#                   'the Coca-Cola system by, among other things, creating more relevant and more '
#                   'personalized experiences wherever our system interacts with consumers, whether '
#                   'in a digital environment or through digital devices in an otherwise physical '
#                   'environment; finding ways to create more powerful digital tools and '
#                   'capabilities for the Coca-Cola systems retail customers to enable them to grow '
#                   'their businesses; and digitalizing operations through the use of data, '
#                   'artificial intelligence, automation, robotics and digital devices to increase '
#                   'efficiency and productivity. If we are not successful in our efforts to '
#                   'digitalize the Coca-Cola system, our ability to increase sales and improve '
#                   'margins may be negatively affected and the cost and expenses we have incurred '
#                   'or may incur in connection with our digitalization initiatives may adversely '
#                   'impact our financial performance.\n'
#                   'If negative publicity, whether or not warranted, concerning product safety or '
#                   'quality, workplace and human rights, obesity or other issues damages our brand '
#                   'image, corporate reputation and social license to operate, our business may '
#                   'suffer.',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 34
# Question: What does the COCA COLA CO foresee in terms of future growth and challenges and are there any strategic plans outlined for the upcoming years?
# Response: The answer is in the context. According to the document, COCA COLA CO foresees the following challenges and opportunities in the future:
# * Negative publicity about product safety or quality, workplace and human rights, obesity, or other issues could damage the company's brand image and corporate reputation, potentially impacting its financial performance.
# * The company's ability to increase sales and reduce costs may be negatively affected if it fails to digitalize the Coca-Cola system.
# * The company believes that its future success will depend on its ability to adapt to and thrive in the digital environment, and therefore, one of its top priorities is to digitize the Coca-Cola system by creating more relevant and personalized experiences, developing powerful digital tools and capabilities for retail customers, and increasing efficiency and productivity through the use of data, artificial intelligence, automation, robotics, and digital devices.
# * The company has identified strategic plans for the upcoming years, including investing in digital technologies to enhance customer experience, expanding its portfolio of healthier beverages, and improving operational efficiency through automation and digitalization.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2022_0000021344-23-000011.htm',
#                'filing_date': '2023-02-21',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134423000011/ko-20221231.htm',
#                'period_of_report': '2022-12-31',
#                'relevance_score': 0.9677382708000001,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2022_0000021344-23-000011.json',
#                'state_location': 'GA'},
#   'page_content': 'If we are not successful in our efforts to digitalize the Coca-Cola system, our '
#                   'financial results could be negatively affected.\n'
#                   'The digital evolution is affecting how we interact with consumers, customers, '
#                   'suppliers, bottlers and other business partners and stakeholders. We believe '
#                   'our future success will depend in part on our ability to adapt to and thrive in '
#                   'the digital environment. Therefore, one of our top priorities is to digitalize '
#                   'the Coca-Cola system by, among other things, creating more relevant and more '
#                   'personalized experiences wherever our system interacts with consumers, whether '
#                   'in a digital environment or through digital devices in an otherwise physical '
#                   'environment; finding ways to create more powerful digital tools and '
#                   'capabilities for the Coca-Cola systems retail customers to enable them to grow '
#                   'their businesses; and digitalizing operations through the use of data, '
#                   'artificial intelligence, automation, robotics and digital devices to increase '
#                   'efficiency and productivity. If we are not successful in our efforts to '
#                   'digitalize the Coca-Cola system, our ability to increase sales and improve '
#                   'margins may be negatively affected and the cost and expenses we have incurred '
#                   'or may incur in connection with our digitalization initiatives may adversely '
#                   'impact our financial performance.\n'
#                   'If negative publicity, whether or not warranted, concerning product safety or '
#                   'quality, workplace and human rights, obesity or other issues damages our brand '
#                   'image, corporate reputation and social license to operate, our business may '
#                   'suffer.',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2021_0000021344-22-000009.htm',
#                'filing_date': '2022-02-22',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134422000009/ko-20211231.htm',
#                'period_of_report': '2021-12-31',
#                'relevance_score': 0.965159893,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2021_0000021344-22-000009.json',
#                'state_location': 'GA'},
#   'page_content': 'If we are not successful in our efforts to digitize the Coca-Cola system, our '
#                   'financial results could be negatively affected.\n'
#                   'The digital evolution is affecting how we interact with consumers, customers, '
#                   'suppliers, bottlers and other business partners and stakeholders. We believe '
#                   'that our future success will depend in part on our ability to adapt to and '
#                   'thrive in the digital environment. Therefore, one of our top priorities is to '
#                   'digitize the Coca-Cola system by, among other things, creating more relevant '
#                   'and more personalized experiences wherever our system interacts with consumers, '
#                   'whether in a digital environment or through digital devices in an otherwise '
#                   'physical environment; finding ways to create more powerful digital tools and '
#                   'capabilities for the Coca-Cola systems retail customers to enable them to grow '
#                   'their businesses; and digitizing operations through the use of data, artificial '
#                   'intelligence, automation, robotics and digital devices to increase efficiency '
#                   'and productivity. If we are not successful in our efforts to digitize the '
#                   'Coca-Cola system, our ability to increase sales and reduce costs may be '
#                   'negatively affected and the cost and expenses we have incurred or may incur in '
#                   'connection with our digitization initiatives may adversely impact our financial '
#                   'performance.\n'
#                   'If negative publicity, whether or not warranted, concerning product safety or '
#                   'quality, workplace and human rights, obesity or other issues damages our brand '
#                   'image, corporate reputation and social license to operate, our business may '
#                   'suffer.',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Evaluation results saved to 'evaluation_results_rerank_6-2_filter.json'.

# %%
eval = pd.read_json('/content/evaluation_results_rerank_6-2_filter.json')
eval.mean()[1:]
# Out:
# The context is relevant to the company     1.000000
# The context is relevant to the question    0.800000
# The response is correct                    0.542857
# The response answers the question          0.828571
# dtype: float64
