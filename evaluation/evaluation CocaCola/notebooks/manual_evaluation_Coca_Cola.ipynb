# %% [markdown]
# <a href="https://colab.research.google.com/github/winterForestStump/thesis/blob/main/evaluation/manual_evaluation_Coca_Cola.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json
from pprint import pprint

# Load your dataframe
# Replace 'your_data.csv' with the actual path to your data file
df1 = pd.read_json('/content/results_Coca_Cola.json')

# Initialize dictionary to store results
results = {'index': [],
           'The context is relevant to the company': [],
           'The context is relevant to the question': [],
           'The response is correct': [],
           'The response answers the question': []}

# Check if there's a previous evaluation progress saved
try:
    with open('evaluation_results.json', 'r') as f:
        previous_results = json.load(f)
    start_index = max(previous_results['index']) + 1
    results = previous_results
    print("Resuming evaluation from the last unanswered question.")
except (FileNotFoundError, ValueError, KeyError):
    start_index = 0
    print("Starting evaluation from the beginning.")

# Function to get valid user input (1 or 0)
def get_valid_input(message):
    while True:
        try:
            user_input = int(input(message))
            if user_input not in (0, 1):
                raise ValueError("Input must be 0 or 1.")
            return user_input
        except ValueError:
            print("Invalid input. Please enter 0 or 1.")

# Iterate over each row in the dataframe
for idx, row in df1.iloc[start_index:].iterrows():
    print("\nRow Index:", idx)
    print("Question:", row['question'])
    print("Response:", row['response'])
    print("Context:")
    pprint(row['context'], width=100)

    # Ask questions and get user input
    context_relevant_to_company = get_valid_input("Is the context relevant to the company? (1 for True, 0 for False): ")
    context_relevant_to_question = get_valid_input("Is the context relevant to the question? (1 for True, 0 for False): ")
    response_correct = get_valid_input("Is the response correct? (1 for True, 0 for False): ")
    response_answers_question = get_valid_input("Does the response answer the question? (1 for True, 0 for False): ")

    # Append results to dictionary
    results['index'].append(idx)
    results['The context is relevant to the company'].append(context_relevant_to_company)
    results['The context is relevant to the question'].append(context_relevant_to_question)
    results['The response is correct'].append(response_correct)
    results['The response answers the question'].append(response_answers_question)

    # Convert results dictionary to JSON and save to a file after each row
    json_result = json.dumps(results, indent=4)
    with open('evaluation_results.json', 'w') as f:
        f.write(json_result)

    print("Progress saved.")

print("\nEvaluation results saved to 'evaluation_results.json'.")
# Out:
# Starting evaluation from the beginning.
#
# Row Index: 0
# Question: What is the total revenue generated by the Coca Cola and how has the revenue changed over the past few years?
# Response: The answer is not in the provided information. The document only provides information about Square, Inc.'s financial performance for the year 2020, including revenue and gross profit for its Cash App and Seller segments. It does not contain any information about Coca-Cola's revenue or financial performance.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '1512673',
#                'company': 'Square, Inc.',
#                'filename': '1512673_10K_2020_0001512673-21-000008.htm',
#                'filing_date': '2021-02-23',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/1512673/000151267321000008/sq-20201231.htm',
#                'period_of_report': '2020-12-31',
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/1512673_10K_2020_0001512673-21-000008.json',
#                'state_location': 'CA'},
#   'page_content': 'Cash App Results\n'
#                   'The following tables provide a summary of the revenue and gross profit for our '
#                   'Cash App segment for the year ended December 31, 2020 and 2019 (in thousands):\n'
#                   'Year Ended December 31,\n'
#                   '2020 2019 $ Change % Change\n'
#                   'Net revenue $ 5,968,386 $ 1,105,599 $ 4,862,787 440 %\n'
#                   'Cost of revenue 4,742,808 647,931 4,094,877 632 %\n'
#                   'Gross profit $ 1,225,578 $ 457,668 $ 767,910 168 %\n'
#                   'Revenue\n'
#                   'Revenue for the Cash App segment for the year ended December 31, 2020 increased '
#                   'by $4.9 billion compared to the year ended December 31, 2019. The primary '
#                   'drivers were growth in bitcoin revenue, and to a lesser extent, Cash App '
#                   'Instant Deposit, Cash Card, and Cash for Business. Bitcoin revenue increased '
#                   'primarily due to an increase in the number of active bitcoin customers, as well '
#                   'as growth in customer demand and bitcoin prices. Additionally, Cash App revenue '
#                   'benefited from increased numbers of transacting active Cash App customers and '
#                   'from disbursements of the CARES Act stimulus programs and unemployment '
#                   'benefits, including a portion of customers who direct deposited these payments '
#                   'into their Cash App accounts. Cash App revenue growth may not be sustained at '
#                   'the same levels in future quarters and may be impacted by the enactment of '
#                   'further stimulus relief and benefit programs, as well as the demand and market '
#                   'prices for bitcoin, amongst other factors.\n'
#                   'Cost of revenue\n'
#                   'Cost of revenue for the Cash App segment for the year ended December 31, 2020 '
#                   'increased by $4.1 billion compared to the year ended December 31, 2019. The '
#                   'primary drivers for the increase were growth in bitcoin revenue, and to a '
#                   'lesser extent, Cash App Instant Deposit, Cash Card, and Cash for Business.\n'
#                   'Comparison of Years Ended December 31, 2019 and 2018',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '1512673',
#                'company': 'Square, Inc.',
#                'filename': '1512673_10K_2020_0001512673-21-000008.htm',
#                'filing_date': '2021-02-23',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/1512673/000151267321000008/sq-20201231.htm',
#                'period_of_report': '2020-12-31',
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/1512673_10K_2020_0001512673-21-000008.json',
#                'state_location': 'CA'},
#   'page_content': 'Other expense (income), net was primarily driven by the amounts of gains or '
#                   'losses arising from the revaluation of our equity investments. In November '
#                   "2020, upon DoorDash's initial public offering, the preferred shares held by the "
#                   'Company converted into common shares of DoorDash. As of December 31, 2020, the '
#                   'Company revalued this investment and recorded a gain of $276.3 million in the '
#                   'year ended December 31, 2020. Additionally, in the fourth quarter of 2020, we '
#                   'recorded a gain on investment in a privately held entity of $19.0 million based '
#                   'on observable prices for similar equity instruments issued by\n'
#                   'the same entity. In the year ended December 31, 2019, we recorded a loss of '
#                   '$12.3 million on the revaluation of our equity investment Eventbrite, Inc. '
#                   '("Eventbrite"), offset by the amortization of and realized gains on the sale of '
#                   'investments in marketable securities of $9.7 million, foreign exchange gains of '
#                   '$1.7 million, and other sources of income. In December 2019, the Company sold '
#                   'its entire equity investment in Eventbrite and as a result this investment will '
#                   'not impact the results in future periods.\n'
#                   'Segment Results\n'
#                   'Seller Results\n'
#                   'The following tables provide a summary of the revenue and gross profit for our '
#                   'Seller segment for the year ended December 31, 2020 and 2019 (in thousands):\n'
#                   'Year Ended December 31,\n'
#                   '2020 2019 $ Change % Change\n'
#                   'Net revenue $ 3,529,192 $ 3,461,988 $ 67,204 2 %\n'
#                   'Cost of revenue 2,021,361 2,071,561 (50,200) (2) %\n'
#                   'Gross profit $ 1,507,831 $ 1,390,427 $ 117,404 8 %\n'
#                   'Revenue\n'
#                   'Revenue for the Seller segment for the year ended December 31, 2020 increased '
#                   'by $67.2 million compared to the year ended December 31, 2019.',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 0
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 0
# Progress saved.
#
# Row Index: 1
# Question: What is the Coca Cola's cost of goods sold (COGS) and how does the COGS compare to the total revenue?
# Response: The answer is not in the context. The passage provides information about Boeing's cost of sales, Square's cost of revenue and gross margin, and Starbucks' transaction-based costs, but it does not mention Coca-Cola or its cost of goods sold.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '12927',
#                'company': 'BOEING CO',
#                'filename': '12927_10K_2022_0000012927-23-000007.htm',
#                'filing_date': '2023-01-27',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/12927/000001292723000007/ba-20221231.htm',
#                'period_of_report': '2022-12-31',
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/12927_10K_2022_0000012927-23-000007.json',
#                'state_location': 'VA'},
#   'page_content': 'Non-operating postretirement income included in Other income, net was $58 '
#                   'million in 2022, compared with income of $1 million in 2021 and expense of $16 '
#                   'million in 2020. The increased income in 2022 and 2021 was due to lower '
#                   'amortization of net actuarial losses.\n'
#                   'Interest and debt expense decreased by $149 million in 2022 primarily due to '
#                   'lower average debt balances and increased by $526 million in 2021 as a result '
#                   'of higher average debt balances.\n'
#                   'In August 2022, the President signed into law the Inflation Reduction Act of '
#                   '2022, which contained provisions effective January 1, 2023, including a 15% '
#                   'corporate minimum tax and a 1% excise tax on stock buybacks, both of which we '
#                   'do not expect to have a material impact on our results of operations, financial '
#                   'condition or cash flows. For additional discussion related to Income Taxes, see '
#                   'Note 4 to our Consolidated Financial Statements.\n'
#                   'Total Costs and Expenses (Cost of Sales)\n'
#                   'Cost of sales, for both products and services, consists primarily of raw '
#                   'materials, parts, sub-assemblies, labor, overhead and subcontracting costs. Our '
#                   'BCA segment predominantly uses program accounting to account for cost of sales. '
#                   'Under program accounting, cost of sales for each commercial aircraft program '
#                   'equals the product of (i) revenue recognized in connection with customer '
#                   'deliveries and (ii) the estimated cost of sales percentage applicable to the '
#                   'total remaining program. For long-term contracts, the amount reported as cost '
#                   'of sales is recognized as incurred. Substantially all contracts at our BDS '
#                   'segment and certain contracts at our BGS segment are long-term contracts with '
#                   'the U.S. government and other customers that generally extend over several '
#                   'years. Cost of sales for commercial spare parts is recorded at average cost.\n'
#                   'The following table summarizes cost of sales:\n'
#                   '(Dollars in millions)\n'
#                   'Years ended December 31 2022 2021 Change 2021 2020 Change\n'
#                   'Cost of sales $63,106 $59,269 $3,837 $59,269 $63,843 ($4,574)',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '1512673',
#                'company': 'Square, Inc.',
#                'filename': '1512673_10K_2016_0001628280-17-001754.htm',
#                'filing_date': '2017-02-27',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/1512673/000162828017001754/a10-kfilingsquareinc2016.htm',
#                'period_of_report': '2016-12-31',
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/1512673_10K_2016_0001628280-17-001754.json',
#                'state_location': 'CA'},
#   'page_content': 'Revenue for Caviar, our food ordering service, is derived from seller fees, '
#                   'which are a percentage of total food order value, delivery fees, and service '
#                   'fees paid by the consumer based on total food order value.\n'
#                   'Hardware revenue. Hardware revenue includes revenue from sales of contactless '
#                   'and chip readers, chip card readers, Square Stand, and third-party peripherals. '
#                   'Third-party peripherals include cash drawers, receipt printers, and barcode '
#                   'scanners, all of which can be integrated with Square Stand to provide a '
#                   'comprehensive point-of-sale solution. In the second quarter of 2015, we began '
#                   'selling our first chip card reader, and in the fourth quarter of 2015, we began '
#                   'selling our contactless and chip reader.\n'
#                   'Cost of Revenue and Gross Margin\n'
#                   'Transaction-based costs. Transaction-based costs consist primarily of '
#                   'interchange fees set by payment card networks and that are paid to the '
#                   'card-issuing financial institution, assessment fees paid to payment card '
#                   'networks, fees paid to third-party payment processors, and bank settlement '
#                   'fees.\n'
#                   'Starbucks transaction-based costs. Starbucks transaction-based costs consist of '
#                   'the same components as our overall transaction-based costs.\n'
#                   'Subscription and services-based costs. Subscription and services-based costs '
#                   'consist primarily of Caviar-related costs, which include payments to '
#                   'third-party couriers for deliveries and the costs of equipment provided to '
#                   'sellers. Cost of revenue for other subscription and services-based products '
#                   'consists primarily of the amortization related to the development of certain '
#                   'subscription and services-based products.',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 0
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 0
# Progress saved.
#
# Row Index: 2
# Question: What is the Coca Cola's gross profit margin, and how has it evolved?
# Response: The answer is in the context. According to the provided information, Coca Cola's gross profit margin was 58.1% in 2022, down from 60.3% in 2021. Additionally, the company's gross profit margin decreased to 62.6% in 2017 from 60.7% in 2016, primarily due to the unfavorable impact of foreign currency exchange rate fluctuations.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2017_0000021344-18-000008.htm',
#                'filing_date': '2018-02-23',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134418000008/a2017123110-k.htm',
#                'period_of_report': '2017-12-31',
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2017_0000021344-18-000008.json',
#                'state_location': 'GA'},
#   'page_content': 'Gross Profit Margin\n'
#                   'As a result of our finished goods operations, which are primarily included in '
#                   'our North America and Bottling Investments operating segments, the following '
#                   "inputs represent a substantial portion of the Company's total cost of goods "
#                   'sold: (1) sweeteners, (2) metals, (3) juices and (4) PET. The Company enters '
#                   'into hedging activities related to certain commodities in order to mitigate a '
#                   'portion of the price risk associated with forecasted purchases. Many of the '
#                   'derivative financial instruments used by the Company to mitigate the risk '
#                   'associated with these commodity exposures, including any related foreign '
#                   'currency exposure, do not qualify for hedge accounting. As a result, the '
#                   'changes in fair value of these derivative instruments have been, and will '
#                   'continue to be, included as a component of net income in each reporting period. '
#                   'The Company recorded gains related to these derivatives of $14 million and $79 '
#                   'million during the years ended December 31, 2017 and December 31, 2016, '
#                   'respectively, and recorded a loss of $206 million during the year ended '
#                   'December 31, 2015 in the line item cost of goods sold in our consolidated '
#                   'statements of income. Refer to Note 5 of Notes to Consolidated Financial '
#                   'Statements. We do not currently expect changes in commodity costs to have a '
#                   'significant impact on our 2018 gross profit margin as compared to 2017.\n'
#                   'Year Ended December 31, 2017 versus Year Ended December 31, 2016\n'
#                   'Our gross profit margin increased to 62.6 percent in 2017 from 60.7 percent in '
#                   '2016. The increase was primarily due to the impact of acquisitions and '
#                   'divestitures, partially offset by the unfavorable impact of foreign currency '
#                   'exchange rate fluctuations. Refer to Note 2 of Notes to Consolidated Financial '
#                   'Statements for additional information related to acquisitions and '
#                   'divestitures.\n'
#                   'Year Ended December 31, 2016 versus Year Ended December 31, 2015',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2022_0000021344-23-000011.htm',
#                'filing_date': '2023-02-21',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134423000011/ko-20221231.htm',
#                'period_of_report': '2022-12-31',
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2022_0000021344-23-000011.json',
#                'state_location': 'GA'},
#   'page_content': 'Latin America 11.4 10.7\n'
#                   'North America 36.5 34.1\n'
#                   'Asia Pacific 11.0 12.1\n'
#                   'Global Ventures 6.6 7.3\n'
#                   'Bottling Investments 18.3 18.6\n'
#                   'Corporate 0.2 0.2\n'
#                   'Total 100.0 % 100.0 %\n'
#                   'The percentage contribution of each operating segment fluctuates over time due '
#                   'to net operating revenues in some operating segments growing at a faster rate '
#                   'compared to other operating segments. In addition, foreign currency exchange '
#                   'rate fluctuations impact the percentage contribution of each operating segment. '
#                   'For additional information about the impact of foreign currency exchange rate '
#                   'fluctuations, refer to the heading Liquidity, Capital Resources and Financial '
#                   'Position - Foreign Exchange below.\n'
#                   'Gross Profit Margin\n'
#                   'Gross profit margin is a ratio calculated by dividing gross profit by net '
#                   'operating revenues. Management believes gross profit margin provides investors '
#                   'with useful information related to the profitability of our business prior to '
#                   'considering all of the selling, general and administrative expenses and other '
#                   'operating charges incurred. Management uses this measure in making financial, '
#                   'operating and planning decisions and in evaluating the Companys performance.\n'
#                   'Our gross profit margin decreased to 58.1 percent in 2022 from 60.3 percent in '
#                   '2021. This decrease was primarily due to the unfavorable impact of foreign '
#                   'currency exchange rate fluctuations, increased commodity and transportation '
#                   'costs, and the acquisition of BodyArmor, a finished goods business, in November '
#                   '2021. The impact of these items was partially offset by favorable pricing '
#                   'initiatives as well as favorable channel and package mix. We expect commodity '
#                   'and transportation costs to continue to have an unfavorable impact on our gross '
#                   'profit margin in 2023, and we will continue to proactively take actions in an '
#                   'effort to mitigate the impact of these incremental costs.\n'
#                   'Selling, General and Administrative Expenses\n'
#                   'The following table sets forth the components of selling, general and '
#                   'administrative expenses (in millions):',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 3
# Question: What are the Coca Cola's major operating expenses and how have these expenses changed over time?
# Response: The answer is not in the context. The document provides information about the company's income tax provisions, tax audits, and unrecognized tax benefits, but does not mention the company's major operating expenses.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2021_0000021344-22-000009.htm',
#                'filing_date': '2022-02-22',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134422000009/ko-20211231.htm',
#                'period_of_report': '2021-12-31',
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2021_0000021344-22-000009.json',
#                'state_location': 'GA'},
#   'page_content': 'The Global Intangible Low-Taxed Income (GILTI) provisions of the Tax Reform Act '
#                   'require the Company to include in its U.S. income tax return each foreign '
#                   'subsidiarys earnings in excess of an allowable return on the foreign '
#                   'subsidiarys tangible assets. An accounting policy election is available to '
#                   'either account for the tax effects of GILTI in the period that is subject to '
#                   'such taxes or to provide deferred taxes for book and tax basis differences that '
#                   'upon reversal may be subject to such taxes. We have elected to account for the '
#                   'tax effects of these provisions in the period that is subject to such tax and '
#                   'the impact is reflected in our full year provision.\n'
#                   'The Company and its subsidiaries file income tax returns in all applicable '
#                   'jurisdictions, including the U.S. federal jurisdiction, U.S. state '
#                   'jurisdictions and foreign jurisdictions. U.S. tax authorities have completed '
#                   'their federal income tax examinations for all years prior to 2007. With respect '
#                   'to U.S. state jurisdictions and foreign jurisdictions, with limited exceptions, '
#                   'the Company and its subsidiaries are no longer subject to income tax audits for '
#                   'years prior to 2006. For U.S. federal and state tax purposes, the net operating '
#                   'losses and tax credit carryovers acquired in connection with our acquisition of '
#                   'Coca-Cola Enterprises Inc.s former North America business that were generated '
#                   'from the years of 1990 through 2010 are subject to adjustments until the year '
#                   'in which they are actually utilized is no longer subject to examination. '
#                   'Although the outcome of tax audits is always uncertain, the Company believes '
#                   'that adequate amounts of tax, including interest and penalties, have been '
#                   'provided for in accordance with the applicable accounting guidance.',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2022_0000021344-23-000011.htm',
#                'filing_date': '2023-02-21',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134423000011/ko-20221231.htm',
#                'period_of_report': '2022-12-31',
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2022_0000021344-23-000011.json',
#                'state_location': 'GA'},
#   'page_content': 'The Company and its subsidiaries file income tax returns in all applicable '
#                   'jurisdictions, including the U.S. federal jurisdiction, U.S. state '
#                   'jurisdictions and foreign jurisdictions. U.S. tax authorities have completed '
#                   'their federal income tax examinations for all years prior to 2007. With respect '
#                   'to U.S. state jurisdictions and foreign jurisdictions, with limited exceptions, '
#                   'the Company and its subsidiaries are no longer subject to income tax audits for '
#                   'years prior to 2007. For U.S. federal and state tax purposes, the net operating '
#                   'losses and tax credit carryovers that were acquired in connection with our '
#                   'acquisition of Coca-Cola Enterprises Inc.s former North America business and '
#                   'that were generated from 1990 through 2010 are subject to adjustments until the '
#                   'year in which they are utilized is no longer subject to examination. Although '
#                   'the outcome of tax audits is always uncertain, the Company believes that '
#                   'adequate amounts of tax, including interest and penalties, have been provided '
#                   'for in accordance with the applicable accounting guidance.\n'
#                   'On November 18, 2020, the Tax Court issued the Opinion regarding the Companys '
#                   '2015 litigation with the IRS involving transfer pricing tax adjustments in '
#                   'which the court predominantly sided with the IRS. The Company disagrees with '
#                   'the Opinion and intends to vigorously defend its position. Refer to Note 11.\n'
#                   'As of December 31, 2022, the gross amount of unrecognized tax benefits was $926 '
#                   'million. If the Company were to prevail on all uncertain tax positions, the net '
#                   'effect would be a benefit of $617 million, exclusive of any benefits related to '
#                   'interest and penalties. The remaining $309 million primarily represents tax '
#                   'benefits that would be received in different tax jurisdictions in the event the '
#                   'Company did not prevail on all uncertain tax positions.\n'
#                   'A reconciliation of the changes in the gross amount of unrecognized tax '
#                   'benefits is as follows (in millions):\n'
#                   'Year Ended December 31, 2022 2021 2020',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 0
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 0
# Progress saved.
#
# Row Index: 4
# Question: What is the Coca Cola's operating income and how does it compare to the previous years?
# Response: According to the provided document, Coca-Cola's operating income for the year 2021 was $10,308 million, which is lower than the previous year's operating income of $12,425 million in 2020 and $9,749 million in 2019.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2017_0000021344-18-000008.htm',
#                'filing_date': '2018-02-23',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134418000008/a2017123110-k.htm',
#                'period_of_report': '2017-12-31',
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2017_0000021344-18-000008.json',
#                'state_location': 'GA'},
#   'page_content': '13,256\n'
#                   '16,465\n'
#                   '17,482\n'
#                   '(19\n'
#                   ')\n'
#                   '(6\n'
#                   ')\n'
#                   'GROSS PROFIT\n'
#                   '22,154\n'
#                   '25,398\n'
#                   '26,812\n'
#                   '(13\n'
#                   ')\n'
#                   '(5\n'
#                   ')\n'
#                   'GROSS PROFIT MARGIN\n'
#                   '62.6\n'
#                   '%\n'
#                   '60.7\n'
#                   '%\n'
#                   '60.5\n'
#                   '%\n'
#                   'Selling, general and administrative expenses\n'
#                   '12,496\n'
#                   '15,262\n'
#                   '16,427\n'
#                   '(18\n'
#                   ')\n'
#                   '(7\n'
#                   ')\n'
#                   'Other operating charges\n'
#                   '2,157\n'
#                   '1,510\n'
#                   '1,657\n'
#                   '(9\n'
#                   ')\n'
#                   'OPERATING INCOME\n'
#                   '7,501\n'
#                   '8,626\n'
#                   '8,728\n'
#                   '(13\n'
#                   ')\n'
#                   '(1\n'
#                   ')\n'
#                   'OPERATING MARGIN\n'
#                   '21.2\n'
#                   '%\n'
#                   '20.6\n'
#                   '%\n'
#                   '19.7\n'
#                   '%\n'
#                   'Interest income\n'
#                   'Interest expense\n'
#                   '(14\n'
#                   ')\n'
#                   'Equity income (loss) - net\n'
#                   '1,071\n'
#                   'Other income (loss) - net\n'
#                   '(1,666\n'
#                   ')\n'
#                   '(1,234\n'
#                   ')\n'
#                   '(35\n'
#                   ')\n'
#                   '*\n'
#                   'INCOME FROM CONTINUING OPERATIONS BEFORE INCOME TAXES\n'
#                   '6,742\n'
#                   '8,136\n'
#                   '9,605\n'
#                   '(17\n'
#                   ')\n'
#                   '(15\n'
#                   ')\n'
#                   'Income taxes from continuing operations\n'
#                   '5,560\n'
#                   '1,586\n'
#                   '2,239\n'
#                   '(29\n'
#                   ')\n'
#                   'Effective tax rate\n'
#                   '82.5\n'
#                   '%\n'
#                   '19.5\n'
#                   '%\n'
#                   '23.3\n'
#                   '%\n'
#                   'NET INCOME FROM CONTINUING OPERATIONS\n'
#                   '1,182\n'
#                   '6,550\n'
#                   '7,366\n'
#                   '(82\n'
#                   ')\n'
#                   '(11\n'
#                   ')\n'
#                   'Income from discontinued operations (net of income taxes of $47, $0 and $0, '
#                   'respectively)\n'
#                   '-\n'
#                   '-\n'
#                   '*\n'
#                   '*\n'
#                   'CONSOLIDATED NET INCOME\n'
#                   '1,283\n'
#                   '6,550\n'
#                   '7,366\n'
#                   '(80\n'
#                   ')\n'
#                   '(11\n'
#                   ')\n'
#                   'Less: Net income attributable to noncontrolling interests\n'
#                   'NET INCOME ATTRIBUTABLE TO SHAREOWNERS OF\n'
#                   'THE COCA-COLA COMPANY\n'
#                   '$\n'
#                   '1,248\n'
#                   '$\n'
#                   '6,527\n'
#                   '$\n'
#                   '7,351\n'
#                   '(81\n'
#                   ')%\n'
#                   '(11\n'
#                   ')%\n'
#                   'BASIC NET INCOME PER SHARE1\n'
#                   '$\n'
#                   '0.29\n'
#                   '$\n'
#                   '1.51\n'
#                   '$\n'
#                   '1.69\n'
#                   '(81\n'
#                   ')%\n'
#                   '(11\n'
#                   ')%\n'
#                   'DILUTED NET INCOME PER SHARE1\n'
#                   '$\n'
#                   '0.29\n'
#                   '$\n'
#                   '1.49\n'
#                   '$\n'
#                   '1.67\n'
#                   '(81\n'
#                   ')%\n'
#                   '(10\n'
#                   ')%\n'
#                   '*\n'
#                   'Calculation is not meaningful.\n'
#                   'Calculated based on net income attributable to shareowners of The Coca-Cola '
#                   'Company.\n'
#                   'Net Operating Revenues\n'
#                   'Year Ended December 31, 2017 versus Year Ended December 31, 2016\n'
#                   "The Company's net operating revenues decreased $6,453 million, or 15 percent.\n"
#                   'The following table illustrates, on a percentage basis, the estimated impact of '
#                   'key factors resulting in the increase (decrease) in net operating revenues on a '
#                   'consolidated basis and for each of our operating segments:\n'
#                   'Percent Change 2017 vs. 2016\n'
#                   'Volume1\n'
#                   'Acquisitions & Divestitures\n'
#                   'Price, Product &\n'
#                   'Geographic Mix\n'
#                   'Currency\n'
#                   'Fluctuations\n'
#                   'Total\n'
#                   'Consolidated\n'
#                   '-\n'
#                   '%\n'
#                   '(17\n'
#                   ')%\n'
#                   '%\n'
#                   '(1\n'
#                   ')%\n'
#                   '(15\n'
#                   ')%\n'
#                   'Europe, Middle East & Africa\n'
#                   '%\n'
#                   '(2\n'
#                   ')%\n'
#                   '%\n'
#                   '(2\n'
#                   ')%\n'
#                   '%\n'
#                   'Latin America\n'
#                   '(3\n'
#                   ')\n'
#                   '-\n'
#                   '-\n'
#                   'North America\n'
#                   '-\n'
#                   '-\n'
#                   'Asia Pacific\n'
#                   '-\n'
#                   '(1\n'
#                   ')\n'
#                   '(4\n'
#                   ')\n'
#                   '(2\n'
#                   ')\n'
#                   'Bottling Investments\n'
#                   '(3\n'
#                   ')\n'
#                   '(48\n'
#                   ')\n'
#                   '-\n'
#                   '(47\n'
#                   ')\n'
#                   'Corporate\n'
#                   '*\n'
#                   '*\n'
#                   '*\n'
#                   '*\n'
#                   '*',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2021_0000021344-22-000009.htm',
#                'filing_date': '2022-02-22',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134422000009/ko-20211231.htm',
#                'period_of_report': '2021-12-31',
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2021_0000021344-22-000009.json',
#                'state_location': 'GA'},
#   'page_content': 'Consolidated Balance Sheets\n'
#                   'Consolidated Statements of Cash Flows\n'
#                   'Consolidated Statements of Shareowners Equity\n'
#                   'Notes to Consolidated Financial Statements\n'
#                   'Report of Management\n'
#                   'Report of Independent Registered Public Accounting Firm (PCAOB ID: 42)\n'
#                   'Report of Independent Registered Public Accounting Firm on Internal Control '
#                   'Over Financial Reporting\n'
#                   'THE COCA-COLA COMPANY AND SUBSIDIARIES\n'
#                   'CONSOLIDATED STATEMENTS OF INCOME\n'
#                   '(In millions except per share data)\n'
#                   'Year Ended December 31, 2021 2020 2019\n'
#                   'Net Operating Revenues $ 38,655 $ 33,014 $ 37,266\n'
#                   'Cost of goods sold 15,357 13,433 14,619\n'
#                   'Gross Profit 23,298 19,581 22,647\n'
#                   'Selling, general and administrative expenses 12,144 9,731 12,103\n'
#                   'Other operating charges 846 853 458\n'
#                   'Operating Income 10,308 8,997 10,086\n'
#                   'Interest income 276 370 563\n'
#                   'Interest expense 1,597 1,437 946\n'
#                   'Equity income (loss) - net 1,438 978 1,049\n'
#                   'Other income (loss) - net 2,000 841 34\n'
#                   'Income Before Income Taxes 12,425 9,749 10,786\n'
#                   'Income taxes 2,621 1,981 1,801\n'
#                   'Consolidated Net Income 9,804 7,768 8,985\n'
#                   'Less: Net income (loss) attributable to noncontrolling interests 33 21 65\n'
#                   'Net Income Attributable to Shareowners of The Coca-Cola Company $ 9,771 $ 7,747 '
#                   '$ 8,920\n'
#                   'Basic Net Income Per Share1\n'
#                   '$ 2.26 $ 1.80 $ 2.09\n'
#                   'Diluted Net Income Per Share1\n'
#                   '$ 2.25 $ 1.79 $ 2.07\n'
#                   'Average Shares Outstanding - Basic 4,315 4,295 4,276\n'
#                   'Effect of dilutive securities 25 28 38\n'
#                   'Average Shares Outstanding - Diluted 4,340 4,323 4,314\n'
#                   '1 Calculated based on net income attributable to shareowners of The Coca-Cola '
#                   'Company.\n'
#                   'Refer to Notes to Consolidated Financial Statements.\n'
#                   'THE COCA-COLA COMPANY AND SUBSIDIARIES\n'
#                   'CONSOLIDATED STATEMENTS OF COMPREHENSIVE INCOME\n'
#                   '(In millions)\n'
#                   'Year Ended December 31, 2021 2020 2019\n'
#                   'Consolidated Net Income $ 9,804 $ 7,768 $ 8,985\n'
#                   'Other Comprehensive Income:\n'
#                   'Net foreign currency translation adjustments (699) (911) 74\n'
#                   'Net gains (losses) on derivatives 214 15 (54)\n'
#                   'Net change in unrealized gains (losses) on available-for-sale debt securities '
#                   '(90) (47) 18',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 0
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 5
# Question: What is the Coca Cola's net income for the current fiscal year and how has net income trended over the past few years?
# Response: The answer is not in the provided information. The document only provides information on the company's revenue, expenses, and profitability for specific segments and periods, but does not contain information on the overall net income for the company. To find out Coca-Cola's net income for the current fiscal year, you would need to consult the company's annual report or other financial statements.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '24741',
#                'company': 'CORNING INC /NY',
#                'filename': '24741_10K_2021_0001437749-22-003247.htm',
#                'filing_date': '2022-02-14',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/24741/000143774922003247/glw20211231_10k.htm',
#                'period_of_report': '2021-12-31',
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/24741_10K_2021_0001437749-22-003247.json',
#                'state_location': 'NY'},
#   'page_content': 'Net income increased by $55 million, or 40%, in the year ended December 31, '
#                   '2021, primarily driven by the changes in sales outlined above.\n'
#                   'All Other\n'
#                   'All other businesses that do not meet the quantitative threshold for separate '
#                   'reporting have been grouped as All Other. This group is primarily comprised of '
#                   'the results of HSG, pharmaceutical technologies, auto glass, new product lines '
#                   'and development projects, as well as other businesses and certain corporate '
#                   'investments.\n'
#                   'The Company obtained a controlling interest in HSG during the third quarter of '
#                   '2020 and has consolidated results in All Other since September 9, 2020. Refer '
#                   'to Note 4 (HSG Transactions and Acquisitions) to the consolidated financial '
#                   'statements for additional information on this transaction.\n'
#                   'The following table provides net sales and net loss for All Other (in '
#                   'millions):\n'
#                   'Year ended December 31,\n'
#                   '% change\n'
#                   '% change\n'
#                   '21 vs. 20\n'
#                   '20 vs. 19\n'
#                   'Segment net sales\n'
#                   '$ 1,243\n'
#                   '$\n'
#                   '$\n'
#                   '167%\n'
#                   '102%\n'
#                   'Segment net loss\n'
#                   '$ (51 )\n'
#                   '$ (214 )\n'
#                   '$ (289 )\n'
#                   '76%\n'
#                   '26%\n'
#                   'Net sales of this segment increased by $778 million, or 167%, in the year ended '
#                   'December 31, 2021, when compared to the same period in 2020, driven primarily '
#                   'by full-year consolidation of HSG.\n'
#                   'The decrease in the net loss of $163 million is primarily driven by the '
#                   'increases in sales outlined above.\n'
#                   'LIQUIDITY AND CAPITAL RESOURCES\n'
#                   'Financing and Capital Structure\n'
#                   'The following items discuss Cornings financing and changes in capital structure '
#                   'during 2021 and 2020:\n'
#                   'In the third quarter of 2021, Corning redeemed $250 million of 3.7% debentures '
#                   'due in 2023, paying a premium of $19 million by exercising our make-whole call. '
#                   'The bond redemption resulted in a $20 million loss during the same quarter.\n'
#                   'In the second quarter of 2021, Corning redeemed $375 million of 2.9% debentures '
#                   'due in 2022, paying a premium of $10 million by exercising our make-whole call. '
#                   'The bond redemption resulted in an $11 million loss during the same quarter.',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '24741',
#                'company': 'CORNING INC /NY',
#                'filename': '24741_10K_2020_0001562762-21-000023.htm',
#                'filing_date': '2021-02-12',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/24741/000156276221000023/glw-20201231x10k.htm',
#                'period_of_report': '2020-12-31',
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/24741_10K_2020_0001562762-21-000023.json',
#                'state_location': 'NY'},
#   'page_content': 'Display Technologies\n'
#                   'The following table provides net sales and net income for the Display '
#                   'Technologies segment:\n'
#                   'Year ended December 31,\n'
#                   '% change\n'
#                   '% change\n'
#                   '20 vs. 19\n'
#                   '19 vs. 18\n'
#                   'Segment net sales\n'
#                   '$\n'
#                   '3,172\n'
#                   '$\n'
#                   '3,254\n'
#                   '$\n'
#                   '3,276\n'
#                   '(3%)\n'
#                   '(1%)\n'
#                   'Segment net income\n'
#                   '$\n'
#                   '$\n'
#                   '$\n'
#                   '(9%)\n'
#                   '(6%)\n'
#                   'Net sales in the Display Technologies segment decreased by $82 million for the '
#                   'year ended December 31, 2020, when compared to the prior year, primarily driven '
#                   'by lower sales and production volumes in the first half of the year.\n'
#                   'Index\n'
#                   'Net income in the Display Technologies segment decreased by $69 million in the '
#                   'year ended December 31, 2020, primarily driven the changes in sales outlined '
#                   'above.\n'
#                   'Optical Communications\n'
#                   'The following table provides net sales and net income for the Optical '
#                   'Communications segment:\n'
#                   'Year ended December 31,\n'
#                   '% change\n'
#                   '% change\n'
#                   '20 vs. 19\n'
#                   '19 vs. 18\n'
#                   'Segment net sales\n'
#                   '$\n'
#                   '3,563\n'
#                   '$\n'
#                   '4,064\n'
#                   '$\n'
#                   '4,192\n'
#                   '(12%)\n'
#                   '(3%)\n'
#                   'Segment net income\n'
#                   '$\n'
#                   '$\n'
#                   '$\n'
#                   '(25%)\n'
#                   '(17%)\n'
#                   'Net sales declined by $501 million, or 12%, in the year ended December 31, '
#                   '2020, when compared to the same period in 2019, primarily due to lower sales in '
#                   'carrier products and enterprise products, down $273 million and $228 million, '
#                   'respectively, driven by general market weakness and capital spending reductions '
#                   'by several major customers.\n'
#                   'Net income in the year ended December 31, 2020 decreased by $123 million, or '
#                   '25%, primarily driven by the changes in sales, outlined above. Profitability '
#                   'was impacted by lower sales and production volumes.\n'
#                   'Movements in foreign currency exchange rates did not materially impact net '
#                   'income in this segment in the year ended December 31, 2020 when compared to the '
#                   'same period in 2019.\n'
#                   'Specialty Materials\n'
#                   'The following table provides net sales and net income for the Specialty '
#                   'Materials segment:\n'
#                   'Year ended December 31,\n'
#                   '% change\n'
#                   '% change\n'
#                   '20 vs. 19\n'
#                   '19 vs. 18\n'
#                   'Segment net sales\n'
#                   '$\n'
#                   '1,884\n'
#                   '$\n'
#                   '1,594\n'
#                   '$\n'
#                   '1,479\n'
#                   '18%\n'
#                   '8%\n'
#                   'Segment net income\n'
#                   '$\n'
#                   '$\n'
#                   '$\n'
#                   '40%\n'
#                   '(4%)',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 0
# Is the context relevant to the question? (1 for True, 0 for False): 0
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 0
# Progress saved.
#
# ...
#                'period_of_report': '2022-12-31',
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2022_0000021344-23-000011.json',
#                'state_location': 'GA'},
#   'page_content': 'Reclassification adjustments recognized in net income 3 - 3\n'
#                   'Gains (losses) on intra-entity transactions that are of a long-term investment '
#                   'nature 2,133 - 2,133\n'
#                   'Gains (losses) on net investment hedges arising during the year1\n'
#                   '(1,094) 273 (821)\n'
#                   'Net foreign currency translation adjustments $ (1,181) $ 423 $ (758)\n'
#                   'Derivatives:\n'
#                   'Gains (losses) arising during the year $ (54) $ 13 $ (41)\n'
#                   'Reclassification adjustments recognized in net income 74 (18) 56\n'
#                   'Net gains (losses) on derivatives1\n'
#                   '$ 20 $ (5) $ 15\n'
#                   'Available-for-sale debt securities:\n'
#                   'Unrealized gains (losses) arising during the year $ (64) $ 22 $ (42)\n'
#                   'Reclassification adjustments recognized in net income (7) 2 (5)\n'
#                   'Net change in unrealized gains (losses) on available-for-sale debt securities2\n'
#                   '$ (71) $ 24 $ (47)\n'
#                   'Pension and other postretirement benefit liabilities:\n'
#                   'Net pension and other postretirement benefit liabilities arising during the '
#                   'year $ (560) $ 138 $ (422)\n'
#                   'Reclassification adjustments recognized in net income 206 (51) 155\n'
#                   'Net change in pension and other postretirement benefit liabilities3\n'
#                   '$ (354) $ 87 $ (267)\n'
#                   'Other comprehensive income (loss) attributable to shareowners of The Coca-Cola\n'
#                   'Company $ (1,586) $ 529 $ (1,057)\n'
#                   '1Refer to Note 5 for additional information related to the net gains or losses '
#                   'on derivative instruments.\n'
#                   '2Refer to Note 4 for additional information related to the net unrealized gains '
#                   'or losses on available-for-sale debt securities.\n'
#                   '3Refer to Note 13 for additional information related to the Companys pension '
#                   'and other postretirement benefit liabilities.\n'
#                   'The following table presents the amounts and line items in our consolidated '
#                   'statement of income where adjustments reclassified from AOCI into income were '
#                   'recorded during the year ended December 31, 2022 (in millions):\n'
#                   'Description of AOCI Component Financial Statement Line Item Amount Reclassified '
#                   'from AOCI into Income\n'
#                   'Foreign currency translation adjustments:\n'
#                   'Divestitures, deconsolidations and other1\n'
#                   'Other income (loss) - net $ 200',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 0
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 33
# Question: How does the Coca Cola leverage technology for its operations and are there ongoing technological advancements?
# Response: The answer is in the context. According to the provided documents, Coca-Cola is actively leveraging technology for its operations and has ongoing technological advancements in various areas, including:
# 1. Digitalization of the Coca-Cola system: The company is working to create more relevant and personalized experiences for consumers, as well as finding ways to create more powerful digital tools and capabilities for retail customers to grow their businesses.
# 2. Use of data, artificial intelligence, automation, robotics, and digital devices to increase efficiency and productivity in operations.
# 3. Leveraging technology to improve supply chain management, such as using data analytics to optimize inventory levels and shipping routes.
# 4. Investing in digital marketing and media to reach consumers more effectively and efficiently.
# 5. Exploring new technologies like blockchain to enhance transparency and traceability throughout the supply chain.
# 6. Utilizing emerging technologies like augmented reality (AR) and virtual reality (VR) to enhance consumer engagement and brand experiences.
# 7. Developing and implementing new technologies to support sustainability goals, such as reducing waste and carbon emissions.
# 8. Using technology to improve employee engagement and development, such as providing training and development programs online.
#
# In summary, Coca-Cola is leveraging technology across various aspects of its operations, including supply chain management, marketing, sustainability, and employee development. The company is also investing in ongoing technological advancements to stay ahead in the competitive landscape.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2021_0000021344-22-000009.htm',
#                'filing_date': '2022-02-22',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134422000009/ko-20211231.htm',
#                'period_of_report': '2021-12-31',
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2021_0000021344-22-000009.json',
#                'state_location': 'GA'},
#   'page_content': 'If we are not successful in our efforts to digitize the Coca-Cola system, our '
#                   'financial results could be negatively affected.\n'
#                   'The digital evolution is affecting how we interact with consumers, customers, '
#                   'suppliers, bottlers and other business partners and stakeholders. We believe '
#                   'that our future success will depend in part on our ability to adapt to and '
#                   'thrive in the digital environment. Therefore, one of our top priorities is to '
#                   'digitize the Coca-Cola system by, among other things, creating more relevant '
#                   'and more personalized experiences wherever our system interacts with consumers, '
#                   'whether in a digital environment or through digital devices in an otherwise '
#                   'physical environment; finding ways to create more powerful digital tools and '
#                   'capabilities for the Coca-Cola systems retail customers to enable them to grow '
#                   'their businesses; and digitizing operations through the use of data, artificial '
#                   'intelligence, automation, robotics and digital devices to increase efficiency '
#                   'and productivity. If we are not successful in our efforts to digitize the '
#                   'Coca-Cola system, our ability to increase sales and reduce costs may be '
#                   'negatively affected and the cost and expenses we have incurred or may incur in '
#                   'connection with our digitization initiatives may adversely impact our financial '
#                   'performance.\n'
#                   'If negative publicity, whether or not warranted, concerning product safety or '
#                   'quality, workplace and human rights, obesity or other issues damages our brand '
#                   'image, corporate reputation and social license to operate, our business may '
#                   'suffer.',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2022_0000021344-23-000011.htm',
#                'filing_date': '2023-02-21',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134423000011/ko-20221231.htm',
#                'period_of_report': '2022-12-31',
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2022_0000021344-23-000011.json',
#                'state_location': 'GA'},
#   'page_content': 'If we are not successful in our efforts to digitalize the Coca-Cola system, our '
#                   'financial results could be negatively affected.\n'
#                   'The digital evolution is affecting how we interact with consumers, customers, '
#                   'suppliers, bottlers and other business partners and stakeholders. We believe '
#                   'our future success will depend in part on our ability to adapt to and thrive in '
#                   'the digital environment. Therefore, one of our top priorities is to digitalize '
#                   'the Coca-Cola system by, among other things, creating more relevant and more '
#                   'personalized experiences wherever our system interacts with consumers, whether '
#                   'in a digital environment or through digital devices in an otherwise physical '
#                   'environment; finding ways to create more powerful digital tools and '
#                   'capabilities for the Coca-Cola systems retail customers to enable them to grow '
#                   'their businesses; and digitalizing operations through the use of data, '
#                   'artificial intelligence, automation, robotics and digital devices to increase '
#                   'efficiency and productivity. If we are not successful in our efforts to '
#                   'digitalize the Coca-Cola system, our ability to increase sales and improve '
#                   'margins may be negatively affected and the cost and expenses we have incurred '
#                   'or may incur in connection with our digitalization initiatives may adversely '
#                   'impact our financial performance.\n'
#                   'If negative publicity, whether or not warranted, concerning product safety or '
#                   'quality, workplace and human rights, obesity or other issues damages our brand '
#                   'image, corporate reputation and social license to operate, our business may '
#                   'suffer.',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 0
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 34
# Question: What does the Coca Cola foresee in terms of future growth and challenges and are there any strategic plans outlined for the upcoming years?
# Response: Based on the provided document, the answer to your question is: Yes, the Coca-Cola Company provides some insights into its future growth and challenges, as well as strategic plans, in the following areas:
# 1. Consumer-centric brand portfolio: The company aims to accelerate growth in this area by investing in marketing and innovation to enhance consumer awareness and preference for its brands.
# 2. Revenue growth algorithm: The company seeks to drive revenue growth through digitalization and data-driven marketing strategies.
# 3. Strengthening the Coca-Cola system: The company plans to enhance its relationships with its bottling partners and expand its reach in emerging markets.
# 4. Core capabilities: The company highlights the importance of consumer marketing, commercial leadership, and franchise leadership in executing its strategic priorities.
# 5. Digitalization: The company aims to leverage technology to improve efficiency and effectiveness across its operations, including supply chain management and customer engagement.
# 6. Sustainability: The company emphasizes its commitment to reducing its environmental footprint and promoting sustainable practices throughout its operations.
#
# In summary, the Coca-Cola Company outlines several strategic priorities and initiatives aimed at driving growth, improving operational efficiency, and enhancing its sustainability efforts in the coming years.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2017_0000021344-18-000008.htm',
#                'filing_date': '2018-02-23',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134418000008/a2017123110-k.htm',
#                'period_of_report': '2017-12-31',
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2017_0000021344-18-000008.json',
#                'state_location': 'GA'},
#   'page_content': 'People: Being a great place to work where people are inspired to be the best '
#                   'they can be.\n'
#                   'Portfolio: Bringing to the world a portfolio of beverage brands that '
#                   "anticipates and satisfies people's desires and needs.\n"
#                   'Partners: Nurturing a winning network of partners and building mutual loyalty.\n'
#                   'Planet: Being a responsible global citizen that makes a difference.\n'
#                   'Profit: Maximizing return to shareowners while being mindful of our overall '
#                   'responsibilities.\n'
#                   'Productivity: Managing our people, time and money for greatest effectiveness.\n'
#                   'Strategic Priorities\n'
#                   'We have five strategic priorities designed to help us achieve our objective. '
#                   'These strategic priorities are accelerating growth of a consumer-centric brand '
#                   'portfolio; driving our revenue growth algorithm; strengthening the Coca-Cola '
#                   'system; digitizing the enterprise; and unlocking the power of our people. In '
#                   'order to execute on these strategic priorities, we must further enhance our '
#                   'core capabilities of consumer marketing, commercial leadership and franchise '
#                   'leadership.\n'
#                   'Core Capabilities\n'
#                   'Consumer Marketing\n'
#                   'Marketing investments are designed to enhance consumer awareness of, and '
#                   'increase consumer preference for, our brands. Successful marketing investments '
#                   'produce long-term growth in unit case volume, per capita consumption and our '
#                   'share of worldwide nonalcoholic beverage sales. Through our relationships with '
#                   'our bottling partners and those who sell our products in\n'
#                   'the marketplace, we create and implement integrated marketing programs, both '
#                   'globally and locally, that are designed to heighten consumer awareness of and '
#                   'product appeal for our brands. In developing a strategy for a Company brand, we '
#                   'conduct product and packaging research, establish brand positioning, develop '
#                   'precise consumer communications and solicit consumer feedback. Our integrated '
#                   'marketing activities include, but are not limited to, advertising, '
#                   'point-of-sale merchandising and sales promotions.',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 0
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Evaluation results saved to 'evaluation_results.json'.

# %%
eval = pd.read_json('/content/evaluation_results.json')
eval.mean()[1:]
# Out:
# The context is relevant to the company     0.742857
# The context is relevant to the question    0.600000
# The response is correct                    0.542857
# The response answers the question          0.542857
# dtype: float64
