# %% [markdown]
# <a href="https://colab.research.google.com/github/winterForestStump/thesis/blob/main/evaluation/JABIL_INC_evaluation(Llama2_7B_vs_70B).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# * Llama2-7B response is from the [notebook](https://github.com/winterForestStump/thesis/blob/main/notebooks/RAG_ParentDocumentRetriever_JABIL_INC.ipynb)
#
# * Llama2-70B response is from [replicate playground](https://replicate.com/meta/llama-2-70b-chat). Input parameters:
#
# > 1. `prompt`: a question and a context
# > 2. `system_prompt`: 'Use the following information from company annual reports and answer the question at the beginning.
# If the answer is not contained in the provided information or if there is NO context at all, say "The answer is not in the context".
# Do not use phrases that "based on the information provided", etc in the answer.'
# > 3. `max_new_tokens`: 1000
# > 4. `temperature`: 0.01
# > 5. `top_p`: 0.9

# %%
import pandas as pd
df= pd.read_csv('https://raw.githubusercontent.com/winterForestStump/thesis/main/evaluation/eval_JABIL_INC.csv')
df
# Out:
#                                              question  \
# 0   What is the total revenue generated by the JAB...
# 1   What is the JABIL INC's cost of goods sold (CO...
# 2   What is the JABIL INC's gross profit margin, a...
# 3   What are the JABIL INC's major operating expen...
# 4   What is the JABIL INC's operating income and h...
# 5   What is the JABIL INC's net income for the cur...
# 6   What is the JABIL INC's earnings per share and...
# 7   What is the JABIL INC's cash flow generated fr...
# 8   How much has the JABIL INC invested in capital...
# 9   What is the JABIL INC's total outstanding debt...
# 10  What is the JABIL INC's current ratio and quic...
# 11  How much inventory does the JABIL INC hold and...
# 12  What is the JABIL INC's accounts receivable tu...
# 13  What is the JABIL INC's market share in its in...
# 14  Who are the JABIL INC's main competitors and h...
# 15  What are the JABIL INC's key risks mentioned i...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   question             35 non-null     object
#  1   Llama2-7B response   35 non-null     object
#  2   Llama2-70B response  35 non-null     object
#  3   context              35 non-null     object
#  4   7B is good           35 non-null     int64
#  5   70B is good          35 non-null     int64
# dtypes: int64(2), object(4)
# memory usage: 1.8+ KB

# %%
print(df['7B is good'].value_counts())
print(df['70B is good'].value_counts())
# Out:
# 1    24
# 0    11
# Name: 7B is good, dtype: int64
# 1    23
# 0    12
# Name: 70B is good, dtype: int64

# %% [markdown]
# ## takeaways
#
# 1. The results between RAG-Llama2-7B and Llama2-70B  are **very** similar
# 2. 15 out of 35 questions (43%) did not get correct context by the retriever
