# %%
import pandas as pd
import json
from pprint import pprint

# Load your dataframe
# Replace 'your_data.csv' with the actual path to your data file
df1 = pd.read_json('results_3M_rerank_6-2_filter.json')

# Initialize dictionary to store results
results = {'index': [],
           'The context is relevant to the company': [],
           'The context is relevant to the question': [],
           'The response is correct': [],
           'The response answers the question': []}

# Check if there's a previous evaluation progress saved
try:
    with open('evaluation_results_3M.json', 'r') as f:
        previous_results = json.load(f)
    start_index = max(previous_results['index']) + 1
    results = previous_results
    print("Resuming evaluation from the last unanswered question.")
except (FileNotFoundError, ValueError, KeyError):
    start_index = 0
    print("Starting evaluation from the beginning.")

# Function to get valid user input (1 or 0)
def get_valid_input(message):
    while True:
        try:
            user_input = int(input(message))
            if user_input not in (0, 1):
                raise ValueError("Input must be 0 or 1.")
            return user_input
        except ValueError:
            print("Invalid input. Please enter 0 or 1.")

# Iterate over each row in the dataframe
for idx, row in df1.iloc[start_index:].iterrows():
    print("\nRow Index:", idx)
    print("Question:", row['question'])
    print("Response:", row['response'])
    print("Context:")
    pprint(row['context'], width=100)

    # Ask questions and get user input
    context_relevant_to_company = get_valid_input("Is the context relevant to the company? (1 for True, 0 for False): ")
    context_relevant_to_question = get_valid_input("Is the context relevant to the question? (1 for True, 0 for False): ")
    response_correct = get_valid_input("Is the response correct? (1 for True, 0 for False): ")
    response_answers_question = get_valid_input("Does the response answer the question? (1 for True, 0 for False): ")

    # Append results to dictionary
    results['index'].append(idx)
    results['The context is relevant to the company'].append(context_relevant_to_company)
    results['The context is relevant to the question'].append(context_relevant_to_question)
    results['The response is correct'].append(response_correct)
    results['The response answers the question'].append(response_answers_question)

    # Convert results dictionary to JSON and save to a file after each row
    json_result = json.dumps(results, indent=4)
    with open('evaluation_results_3M.json', 'w') as f:
        f.write(json_result)

    print("Progress saved.")
0
print("\nEvaluation results saved to 'evaluation_results_3M.json'.")
# Out:
# Starting evaluation from the beginning.
#
# Row Index: 0
# Question: What is the total revenue generated by the 3M CO and how has the revenue changed over the past few years?
# Response: The answer is not in the provided information. The document only provides information about the company's research and development expenses, patents, and cash flow, but does not provide information about the company's total revenue.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '66740',
#                'company': '3M CO',
#                'filename': '66740_10K_2018_0001558370-19-000470.htm',
#                'filing_date': '2019-02-07',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/66740/000155837019000470/mmm-20181231x10k.htm',
#                'period_of_report': '2018-12-31',
#                'relevance_score': 0.963927269,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/66740_10K_2018_0001558370-19-000470.json',
#                'state_location': 'MN'},
#   'page_content': 'Research and Patents\n'
#                   'Research and product development constitutes an important part of 3Ms '
#                   'activities and has been a major driver of 3Ms sales and profit growth. '
#                   'Research, development and related expenses totaled $1.821 billion in 2018, '
#                   '$1.870 billion in 2017 and $1.764 billion in 2016. Research and development, '
#                   'covering basic scientific research and the application of scientific advances '
#                   'in the development of new and improved products and their uses, totaled $1.253 '
#                   'billion in 2018, $1.352 billion in 2017 and $1.248 billion in 2016. Related '
#                   'expenses primarily include technical support; internally developed patent '
#                   'costs, which include costs and fees incurred to prepare, file, secure and '
#                   'maintain patents; amortization of externally acquired patents and externally '
#                   'acquired in-process research and development; and gains/losses associated with '
#                   'certain corporate approved investments in R&D-related ventures, such as equity '
#                   'method effects and impairments.\n'
#                   'The Companys products are sold around the world under various trademarks. The '
#                   'Company also owns, or holds licenses to use, numerous U.S. and foreign patents. '
#                   'The Companys research and development activities generate a steady stream of '
#                   'inventions that are covered by new patents. Patents applicable to specific '
#                   'products extend for varying periods according to the date of patent application '
#                   'filing or patent grant and the legal term of patents in the various countries '
#                   'where patent protection is obtained. The actual protection afforded by a '
#                   'patent, which can vary from country to country, depends upon the type of '
#                   'patent, the scope of its coverage and the availability of legal remedies in the '
#                   'country.\n'
#                   'The Company believes that its patents provide an important competitive '
#                   'advantage in many of its businesses. In general, no single patent or group of '
#                   'related patents is in itself essential to the Company as a whole or to any of '
#                   'the Companys business segments.\n'
#                   'Raw Materials',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '66740',
#                'company': '3M CO',
#                'filename': '66740_10K_2022_0000066740-23-000014.htm',
#                'filing_date': '2023-02-08',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/66740/000006674023000014/mmm-20221231.htm',
#                'period_of_report': '2022-12-31',
#                'relevance_score': 0.9575650692000001,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/66740_10K_2022_0000066740-23-000014.json',
#                'state_location': 'MN'},
#   'page_content': 'Effect of exchange rate changes on cash and cash equivalents (104) (62) 48\n'
#                   'Net increase (decrease) in cash and cash equivalents (909) (70) 2,281\n'
#                   'Cash and cash equivalents at beginning of year 4,564 4,634 2,353\n'
#                   'Cash and cash equivalents at end of period $ 3,655 $ 4,564 $ 4,634\n'
#                   'The accompanying Notes to Consolidated Financial Statements are an integral '
#                   'part of this statement.\n'
#                   '3M Company and Subsidiaries\n'
#                   'Notes to Consolidated Financial Statements\n'
#                   'NOTE 1. Significant Accounting Policies\n'
#                   'Consolidation: 3M is a diversified global manufacturer, technology innovator '
#                   'and marketer of a wide variety of products. All applicable subsidiaries are '
#                   'consolidated. All intercompany transactions are eliminated. As used herein, the '
#                   'term 3M or Company refers to 3M Company and subsidiaries unless the context '
#                   'indicates otherwise.\n'
#                   '3M deconsolidated the Aearo Entities in the third quarter of 2022. See '
#                   'additional information in Note 16.\n'
#                   'Basis of presentation: Certain amounts in the prior years consolidated '
#                   'financial statements have been reclassified to conform to the current year '
#                   'presentation.\n'
#                   'Effective in the first quarter of 2022, 3M made changes in the measure of '
#                   'segment operating performance used by 3Ms chief operating decision '
#                   'maker-impacting 3Ms disclosed measure of segment profit/loss (business segment '
#                   "operating income). See additional information in Note 19. 3M's disclosed "
#                   'disaggregated revenue was also updated as a result of the changes in segment '
#                   'reporting. See additional information in Note 2. Information provided herein '
#                   'reflects the impact of these changes for all periods presented.',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 2
# Invalid input. Please enter 0 or 1.
# Is the context relevant to the question? (1 for True, 0 for False): 2
# Invalid input. Please enter 0 or 1.
# Is the context relevant to the question? (1 for True, 0 for False): 0
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 0
# Progress saved.
#
# Row Index: 1
# Question: What is the 3M CO's cost of goods sold (COGS) and how does the COGS compare to the total revenue?
# Response: The answer is not in the provided information. The document only provides information on the company's annual revenues, expenses, and other financial metrics but does not provide information on the cost of goods sold (COGS). Therefore, we cannot determine the ratio of COGS to total revenue based on the provided information.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '66740',
#                'company': '3M CO',
#                'filename': '66740_10K_2018_0001558370-19-000470.htm',
#                'filing_date': '2019-02-07',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/66740/000155837019000470/mmm-20181231x10k.htm',
#                'period_of_report': '2018-12-31',
#                'relevance_score': 0.9706819057,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/66740_10K_2018_0001558370-19-000470.json',
#                'state_location': 'MN'},
#   'page_content': 'In the fourth quarter of 2017, 3M sold the assets of an electrical '
#                   'marking/labeling business within its Electronics and Energy business. The '
#                   'former activity, proceeds and gain were not considered material.\n'
#                   '2016 divestitures:\n'
#                   'In the first quarter of 2016, 3M completed the sale of the remainder of the '
#                   'assets of 3Ms library systems business to One Equity Partners Capital Advisors '
#                   'L.P. (OEP). 3M had previously sold the North American business and the majority '
#                   'of the business outside of North America to OEP in the fourth quarter of 2015 '
#                   'which was reported within 3Ms Safety and Graphics business. Also in the first '
#                   'quarter of 2016, 3M sold to Innovative Chemical Products Group, a portfolio '
#                   'company of Audax Private Equity, the assets of 3Ms pressurized polyurethane '
#                   'foam adhesives business (formerly known as Polyfoam). This business is a '
#                   'provider of pressurized polyurethane foam adhesive formulations and systems '
#                   'into the residential roofing, commercial roofing and insulation and industrial '
#                   'foam segments in the United States with annual sales of approximately $20 '
#                   'million and was reported within 3Ms Industrial business. The Company recorded a '
#                   'pre-tax gain of $40 million in the first quarter of 2016 as a result of the '
#                   'sales of these businesses.\n'
#                   'In October 2016, 3M sold the assets of its temporary protective films business '
#                   'to Pregis LLC. This business, with annual sales of approximately $50 million, '
#                   'is a provider of adhesive-backed temporary protective films used in a broad '
#                   'range of industries and was reported within 3Ms Industrial business. In '
#                   'December 2016, 3M sold the assets of its cathode battery technology '
#                   'out-licensing business, with annual sales of approximately $10 million, to '
#                   'UMICORE. This business was reported within 3Ms Electronics and Energy business. '
#                   'The aggregate selling price relative to these two businesses was $86 million. '
#                   'The Company recorded a pre-tax gain of $71 million in the fourth quarter of '
#                   '2016 as a result of the sales of these businesses.',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '66740',
#                'company': '3M CO',
#                'filename': '66740_10K_2018_0001558370-19-000470.htm',
#                'filing_date': '2019-02-07',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/66740/000155837019000470/mmm-20181231x10k.htm',
#                'period_of_report': '2018-12-31',
#                'relevance_score': 0.9679194093000001,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/66740_10K_2018_0001558370-19-000470.json',
#                'state_location': 'MN'},
#   'page_content': 'Research and Patents\n'
#                   'Research and product development constitutes an important part of 3Ms '
#                   'activities and has been a major driver of 3Ms sales and profit growth. '
#                   'Research, development and related expenses totaled $1.821 billion in 2018, '
#                   '$1.870 billion in 2017 and $1.764 billion in 2016. Research and development, '
#                   'covering basic scientific research and the application of scientific advances '
#                   'in the development of new and improved products and their uses, totaled $1.253 '
#                   'billion in 2018, $1.352 billion in 2017 and $1.248 billion in 2016. Related '
#                   'expenses primarily include technical support; internally developed patent '
#                   'costs, which include costs and fees incurred to prepare, file, secure and '
#                   'maintain patents; amortization of externally acquired patents and externally '
#                   'acquired in-process research and development; and gains/losses associated with '
#                   'certain corporate approved investments in R&D-related ventures, such as equity '
#                   'method effects and impairments.\n'
#                   'The Companys products are sold around the world under various trademarks. The '
#                   'Company also owns, or holds licenses to use, numerous U.S. and foreign patents. '
#                   'The Companys research and development activities generate a steady stream of '
#                   'inventions that are covered by new patents. Patents applicable to specific '
#                   'products extend for varying periods according to the date of patent application '
#                   'filing or patent grant and the legal term of patents in the various countries '
#                   'where patent protection is obtained. The actual protection afforded by a '
#                   'patent, which can vary from country to country, depends upon the type of '
#                   'patent, the scope of its coverage and the availability of legal remedies in the '
#                   'country.\n'
#                   'The Company believes that its patents provide an important competitive '
#                   'advantage in many of its businesses. In general, no single patent or group of '
#                   'related patents is in itself essential to the Company as a whole or to any of '
#                   'the Companys business segments.\n'
#                   'Raw Materials',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 0
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 0
# Progress saved.
#
# Row Index: 2
# Question: What is the 3M CO's gross profit margin, and how has it evolved?
# Response: The answer is not in the provided information. The document only provides information about the company's divestitures, impairment tests, and reporting unit structure, but does not provide information on the company's gross profit margin or its evolution.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '66740',
#                'company': '3M CO',
#                'filename': '66740_10K_2018_0001558370-19-000470.htm',
#                'filing_date': '2019-02-07',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/66740/000155837019000470/mmm-20181231x10k.htm',
#                'period_of_report': '2018-12-31',
#                'relevance_score': 0.9674335122000001,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/66740_10K_2018_0001558370-19-000470.json',
#                'state_location': 'MN'},
#   'page_content': 'In the fourth quarter of 2017, 3M sold the assets of an electrical '
#                   'marking/labeling business within its Electronics and Energy business. The '
#                   'former activity, proceeds and gain were not considered material.\n'
#                   '2016 divestitures:\n'
#                   'In the first quarter of 2016, 3M completed the sale of the remainder of the '
#                   'assets of 3Ms library systems business to One Equity Partners Capital Advisors '
#                   'L.P. (OEP). 3M had previously sold the North American business and the majority '
#                   'of the business outside of North America to OEP in the fourth quarter of 2015 '
#                   'which was reported within 3Ms Safety and Graphics business. Also in the first '
#                   'quarter of 2016, 3M sold to Innovative Chemical Products Group, a portfolio '
#                   'company of Audax Private Equity, the assets of 3Ms pressurized polyurethane '
#                   'foam adhesives business (formerly known as Polyfoam). This business is a '
#                   'provider of pressurized polyurethane foam adhesive formulations and systems '
#                   'into the residential roofing, commercial roofing and insulation and industrial '
#                   'foam segments in the United States with annual sales of approximately $20 '
#                   'million and was reported within 3Ms Industrial business. The Company recorded a '
#                   'pre-tax gain of $40 million in the first quarter of 2016 as a result of the '
#                   'sales of these businesses.\n'
#                   'In October 2016, 3M sold the assets of its temporary protective films business '
#                   'to Pregis LLC. This business, with annual sales of approximately $50 million, '
#                   'is a provider of adhesive-backed temporary protective films used in a broad '
#                   'range of industries and was reported within 3Ms Industrial business. In '
#                   'December 2016, 3M sold the assets of its cathode battery technology '
#                   'out-licensing business, with annual sales of approximately $10 million, to '
#                   'UMICORE. This business was reported within 3Ms Electronics and Energy business. '
#                   'The aggregate selling price relative to these two businesses was $86 million. '
#                   'The Company recorded a pre-tax gain of $71 million in the fourth quarter of '
#                   '2016 as a result of the sales of these businesses.',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '66740',
#                'company': '3M CO',
#                'filename': '66740_10K_2018_0001558370-19-000470.htm',
#                'filing_date': '2019-02-07',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/66740/000155837019000470/mmm-20181231x10k.htm',
#                'period_of_report': '2018-12-31',
#                'relevance_score': 0.9643452764,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/66740_10K_2018_0001558370-19-000470.json',
#                'state_location': 'MN'},
#   'page_content': 'An impairment loss would be recognized when the carrying amount of the '
#                   'reporting units net assets exceeds the estimated fair value of the reporting '
#                   'unit, and the loss would equal that difference. The estimated fair value of a '
#                   'reporting unit is determined using earnings for the reporting unit multiplied '
#                   'by a price/earnings ratio for comparable industry groups, or by using a '
#                   'discounted cash flow analysis. 3M typically uses the price/earnings ratio '
#                   'approach for stable and growing businesses that have a long history and track '
#                   'record of generating positive operating income and cash flows. 3M uses the '
#                   'discounted cash flow approach for start-up, loss position and declining '
#                   'businesses, in addition to using for businesses where the price/earnings ratio '
#                   'valuation method indicates additional review is warranted. 3M also uses '
#                   'discounted cash flow as an additional tool for businesses that may be growing '
#                   'at a slower rate than planned due to economic or other conditions.\n'
#                   'As described in Note 18, effective in the first quarter of 2018, 3M made '
#                   'business segment reporting changes. For any product moves that resulted in '
#                   'reporting unit changes, the Company applied the relative fair value method to '
#                   'determine the impact on goodwill of the associated reporting units. During the '
#                   'first quarter of 2018, the Company completed its assessment of any potential '
#                   'goodwill impairment for reporting units impacted by this new structure and '
#                   'determined that no impairment existed. The discussion that follows relates to '
#                   'the separate fourth quarter 2018 annual impairment test and is in the context '
#                   'of the reporting unit structure that existed at that time.',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 0
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 0
# Progress saved.
#
# Row Index: 3
# Question: What are the 3M CO's major operating expenses and how have these expenses changed over time?
# Response: Based on the provided annual reports, the 3M CO's major operating expenses include:
# 1. Cash payment from Food Safety business split-off, net of divested cash: This amount has fluctuated over time, with a negative value of $1.046 billion in 2018 and a negative value of $1.317 billion in 2019.
# 2. Other - net: This amount has remained relatively stable over time, with a positive value of $1 in 2018 and a positive value of $31 in 2022.
# 3. Net cash provided by (used in) investing activities: This amount has also fluctuated over time, with a positive value of $1.403 billion in 2018 and a negative value of $3.086 billion in 2019.
# It is important to note that these expenses are only listed in the provided annual reports and may not be comprehensive of all operating expenses for the 3M CO. Additionally, the values listed may not be directly comparable between years due to changes in accounting policies or practices.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '66740',
#                'company': '3M CO',
#                'filename': '66740_10K_2018_0001558370-19-000470.htm',
#                'filing_date': '2019-02-07',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/66740/000155837019000470/mmm-20181231x10k.htm',
#                'period_of_report': '2018-12-31',
#                'relevance_score': 0.9579340219,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/66740_10K_2018_0001558370-19-000470.json',
#                'state_location': 'MN'},
#   'page_content': 'Cash Flows from Investing Activities:\n'
#                   'Years ended December 31\n'
#                   '(Millions)\n'
#                   'Purchases of property, plant and equipment (PP&E)\n'
#                   '$\n'
#                   '(1,577)\n'
#                   '$\n'
#                   '(1,373)\n'
#                   '$\n'
#                   '(1,420)\n'
#                   'Proceeds from sale of PP&E and other assets\n'
#                   'Acquisitions, net of cash acquired\n'
#                   '(2,023)\n'
#                   '(16)\n'
#                   'Purchases and proceeds from maturities and sale of marketable securities and '
#                   'investments, net\n'
#                   '(798)\n'
#                   '(163)\n'
#                   'Proceeds from sale of businesses, net of cash sold\n'
#                   '1,065\n'
#                   'Other - net\n'
#                   '(6)\n'
#                   '(4)\n'
#                   'Net cash provided by (used in) investing activities\n'
#                   '$\n'
#                   '$\n'
#                   '(3,086)\n'
#                   '$\n'
#                   '(1,403)\n'
#                   '\t\t\n'
#                   'Investments in property, plant and equipment enable growth across many diverse '
#                   'markets, helping to meet product demand and increasing manufacturing '
#                   'efficiency. The Company expects 2019 capital spending to be approximately $1.7 '
#                   'billion to $1.9 billion as 3M continues to invest in its businesses.\n'
#                   '3M invests in renewal and maintenance programs, which pertain to cost '
#                   'reduction, cycle time, maintaining and renewing current capacity, eliminating '
#                   'pollution, and compliance. Costs related to maintenance, ordinary repairs, and '
#                   'certain other items are expensed. 3M also invests in growth, which adds to '
#                   'capacity, driven by new products, both through expansion of current facilities '
#                   'and new facilities. Finally, 3M also invests in other initiatives, such as '
#                   'information technology (IT) and laboratory facilities.\n'
#                   'Refer to Note 3 for information on acquisitions and divestitures. The Company '
#                   'is actively considering additional acquisitions, investments and strategic '
#                   'alliances, and from time to time may also divest certain businesses. Proceeds '
#                   'from sale of businesses in 2018 primarily relate to the sale of 3Ms '
#                   'Communication Markets Division and the sale of certain personal safety product '
#                   'offerings primarily focused on noise, environmental, and heat stress monitoring '
#                   'within the Safety and Graphics business segment.',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '66740',
#                'company': '3M CO',
#                'filename': '66740_10K_2022_0000066740-23-000014.htm',
#                'filing_date': '2023-02-08',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/66740/000006674023000014/mmm-20221231.htm',
#                'period_of_report': '2022-12-31',
#                'relevance_score': 0.9513460398,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/66740_10K_2022_0000066740-23-000014.json',
#                'state_location': 'MN'},
#   'page_content': 'Cash payment from Food Safety business split-off, net of divested cash 478 -\n'
#                   'Other - net 1 31\n'
#                   'Net cash provided by (used in) investing activities $ (1,046) $ (1,317)\n'
#                   'Investments in property, plant and equipment enable growth across many diverse '
#                   'markets, helping to meet product demand and increasing manufacturing '
#                   'efficiency. The Company expects 2023 capital spending to be approximately $1.5 '
#                   'billion to $1.8 billion as 3M continues to invest in growth, productivity and '
#                   'sustainability.\n'
#                   '3M records capital-related government grants earned as reductions to the cost '
#                   'of property, plant and equipment; and associated unpaid liabilities and grant '
#                   'proceeds receivable are considered non-cash changes in such balances for '
#                   'purposes of preparation of statement of cash flows.\n'
#                   '3M invests in renewal and maintenance programs, which pertain to cost '
#                   'reduction, cycle time, maintaining and renewing current capacity, eliminating '
#                   'pollution, and compliance. Costs related to maintenance, ordinary repairs, and '
#                   'certain other items are expensed. 3M also invests in growth, which adds to '
#                   'capacity, driven by new products, both through expansion of current facilities '
#                   'and new facilities. Finally, 3M also invests in other initiatives, such as '
#                   'information technology (IT), laboratory facilities, and a continued focus on '
#                   'investments in sustainability.\n'
#                   'Refer to Note 3 for information on acquisitions and divestitures (including the '
#                   'cash payment from the Food Safety business split-off). The Company is actively '
#                   'considering additional acquisitions, investments and strategic alliances, and '
#                   'from time to time may also divest certain businesses.',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 0
# Is the response correct? (1 for True, 0 for False): 0
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 4
# Question: What is the 3M CO's operating income and how does it compare to the previous years?
# Response: According to the document, the 3M Company's operating income for the year 2018 was $6,662 million, while the operating income for the year 2017 was $6,240 million. Therefore, the operating income for 2018 increased by $422 million compared to the previous year.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '66740',
#                'company': '3M CO',
#                'filename': '66740_10K_2018_0001558370-19-000470.htm',
#                'filing_date': '2019-02-07',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/66740/000155837019000470/mmm-20181231x10k.htm',
#                'period_of_report': '2018-12-31',
#                'relevance_score': 0.9608629346,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/66740_10K_2018_0001558370-19-000470.json',
#                'state_location': 'MN'},
#   'page_content': 'Operating Income Margin:\n'
#                   '3M uses operating income as one of its primary business segment performance '
#                   'measurement tools. Refer to the table below for a reconciliation of operating '
#                   'income margins for 2018 and 2017.\n'
#                   '\t\t\n'
#                   'Three months ended\n'
#                   'Year ended\n'
#                   '(Percent of net sales)\n'
#                   'December 31, 2018\n'
#                   'December 31, 2018\n'
#                   'December 31, 2017\n'
#                   'Same period last year\n'
#                   '22.4\n'
#                   '%\n'
#                   '24.3\n'
#                   '%\n'
#                   '23.3\n'
#                   '%\n'
#                   'Increase/(decrease) in operating income margin, due to:\n'
#                   '2017 divestiture of identity management business\n'
#                   '-\n'
#                   '(1.3)\n'
#                   '1.3\n'
#                   'Organic volume/productivity and other\n'
#                   '1.0\n'
#                   '0.9\n'
#                   '(0.3)\n'
#                   'Acquisitions/other divestiture gains\n'
#                   '(1.2)\n'
#                   '(0.1)\n'
#                   '0.1\n'
#                   'Selling price and raw material impact\n'
#                   '0.2\n'
#                   '0.1\n'
#                   '0.4\n'
#                   'Foreign exchange impacts\n'
#                   '0.1\n'
#                   '(0.2)\n'
#                   '(0.5)\n'
#                   'Legal-related charges\n'
#                   '-\n'
#                   '(0.2)\n'
#                   '-\n'
#                   '2018 divestiture of Communication Markets Division, net of related '
#                   'restructuring actions\n'
#                   '(0.1)\n'
#                   '1.2\n'
#                   '-\n'
#                   'Current period, excluding MN Natural Resource Damages (NRD) resolution\n'
#                   '22.4\n'
#                   '%\n'
#                   '24.7\n'
#                   '%\n'
#                   '24.3\n'
#                   '%\n'
#                   'MN NRD resolution\n'
#                   '-\n'
#                   '(2.7)\n'
#                   '-\n'
#                   'Current period\n'
#                   '22.4\n'
#                   '%\n'
#                   '22.0\n'
#                   '%\n'
#                   '24.3\n'
#                   '%\n'
#                   'Year 2018 and fourth quarter operating income:\n'
#                   'Operating income margins were flat in the fourth quarter of 2018 when compared '
#                   'to the fourth quarter of 2017, and declined 2.3 percentage points in full year '
#                   '2018 when compared to full year 2017.\n'
#                   'Additional discussion related to the components of the year-on-year change in '
#                   'operating income margins follows:\n'
#                   '2017 divestiture of identity management business:\n'
#                   '·\n'
#                   'Operating income margins decreased year-on-year due to the gain on the May 2017 '
#                   'divestiture of the Companys former identity management business.\n'
#                   'Organic volume/productivity and other:\n'
#                   '·\n'
#                   'Operating income margins increased year-on-year due to benefits from organic '
#                   'local-currency growth and productivity, in addition to lower year-on-year '
#                   'portfolio and supply chain footprint optimization charges.\n'
#                   '·\n'
#                   'Operating income margins decreased year-on-year due to higher defined benefit '
#                   'pension and postretirement service cost expense and defined contribution '
#                   'expense.\n'
#                   'Acquisitions/other divestiture gains:\n'
#                   '·',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '66740',
#                'company': '3M CO',
#                'filename': '66740_10K_2018_0001558370-19-000470.htm',
#                'filing_date': '2019-02-07',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/66740/000155837019000470/mmm-20181231x10k.htm',
#                'period_of_report': '2018-12-31',
#                'relevance_score': 0.9599031210000001,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/66740_10K_2018_0001558370-19-000470.json',
#                'state_location': 'MN'},
#   'page_content': '1,074\n'
#                   'Accounts receivable\n'
#                   '(305)\n'
#                   '(245)\n'
#                   '(313)\n'
#                   'Inventories\n'
#                   '(509)\n'
#                   '(387)\n'
#                   'Accounts payable\n'
#                   'Other - net\n'
#                   'Net cash provided by operating activities\n'
#                   '$\n'
#                   '6,439\n'
#                   '$\n'
#                   '6,240\n'
#                   '$\n'
#                   '6,662\n'
#                   'Cash flows from operating activities can fluctuate significantly from period to '
#                   'period, as pension funding decisions, tax timing differences and other items '
#                   'can significantly impact cash flows.\n'
#                   'In 2018, cash flows provided by operating activities increased $199 million '
#                   'compared to the same period last year, with the increase primarily made up of '
#                   'higher net income and lower year-on-year pension and postretirement '
#                   'contributions. The increase was partially offset primarily due to the Minnesota '
#                   'NRD resolution in the first quarter of 2018 and year-on-year increases in '
#                   'income tax payments. Additional factors that decreased operating cash flows '
#                   'were increases in inventory and accounts receivable. The combination of '
#                   'accounts receivable, inventories and accounts payable increased working capital '
#                   'by $406 million in 2018, compared to the working capital increases of $608 '
#                   'million in 2017. Additional discussion on working capital changes is provided '
#                   'earlier in the Financial Condition and Liquidity section.\n'
#                   'In 2017, cash flows provided by operating activities decreased $422 million '
#                   'compared to the same period last year. Factors that decreased operating cash '
#                   'flows were increases in pension contributions, plus year-on-year increases in '
#                   'working capital. In December 2017, 3M contributed $600 million to its U.S. '
#                   'defined benefit pension plan, contributing to a year-on-year increase in '
#                   'pension and postretirement contributions of $584 million. The combination of '
#                   'accounts receivable, inventories and accounts payable increased working capital '
#                   'by $608 million in 2017, compared to working capital increases of $108 million '
#                   'in 2016. In 2017, year-on-year decreases in income tax payments (net of '
#                   'refunds) increased operating cash flows by $284 million.\n'
#                   'Cash Flows from Investing Activities:\n'
#                   'Years ended December 31\n'
#                   '(Millions)',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 0
# Is the response correct? (1 for True, 0 for False): 0
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 5
# Question: What is the 3M CO's net income for the current fiscal year and how has net income trended over the past few years?
# Response: According to the provided document, 3M CO's net income for the current fiscal year (2018) was $5.349 billion, or $8.89 per diluted share. This represents an increase of 12.1% compared to the previous year's net income of $4.858 billion, or $7.93 per diluted share.
# Over the past few years, 3M CO's net income has trended upward. In 2016, the company reported net income of $4.37 billion, or $7.05 per diluted share. By 2018, this had increased to $5.349 billion, or $8.89 per diluted share, representing a growth of 21.5% over this time period.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '66740',
#                'company': '3M CO',
#                'filename': '66740_10K_2018_0001558370-19-000470.htm',
#                'filing_date': '2019-02-07',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/66740/000155837019000470/mmm-20181231x10k.htm',
#                'period_of_report': '2018-12-31',
#                'relevance_score': 0.9673874974000001,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/66740_10K_2018_0001558370-19-000470.json',
#                'state_location': 'MN'},
#   'page_content': 'The TCJA was enacted in December 2017. Among other things, the TCJA reduces the '
#                   'U.S. federal corporate tax rate from 35 percent to 21 percent beginning in '
#                   '2018, requires companies to pay a one-time transition tax on previously '
#                   'unremitted earnings of non-U.S. subsidiaries that were previously tax deferred '
#                   'and creates new taxes on certain foreign sourced earnings. The SEC staff issued '
#                   'Staff Accounting Bulletin (SAB) 118, which provided a measurement period of up '
#                   'to one year from the TCJAs enactment date for companies to complete their '
#                   'accounting under ASC 740. In connection with the enactment of the TCJA, the '
#                   'Company recorded a net tax expense of $762 million in the fourth quarter of '
#                   '2017 and additional net charges of $176 million as measurement period '
#                   'adjustments in 2018. As further discussed below, 3M completed its accounting '
#                   'for the income tax effects of enactment of the TCJA as follows:\n'
#                   'Transition tax: 3M recorded a provisional income tax expense obligation of $745 '
#                   'million in the fourth quarter of 2017. During 2018, the Company recorded an '
#                   'additional obligation of $97 million related to the transition tax portion of '
#                   'the TCJA. The TCJAs transition\n'
#                   '\t\t\n'
#                   'tax is payable over eight years beginning in 2018. As of December 31, 2018, 3M '
#                   'reflected $649 million in long-term income taxes payable associated with the '
#                   'transition tax.\n'
#                   'Remeasurement of deferred tax assets/liabilities and other impacts: 3M '
#                   'remeasured certain deferred tax assets and liabilities based on the rates at '
#                   'which they are expected to reverse in the future, which is generally 21 percent '
#                   'under the TCJA. In the fourth quarter of 2017, 3M recorded a net income tax '
#                   'expense of $17 million related to remeasurement of deferred tax '
#                   'assets/liabilities and other impacts. During 2018, 3M recorded an additional '
#                   'net tax expense of $79 million as an associated measurement period adjustment.',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '66740',
#                'company': '3M CO',
#                'filename': '66740_10K_2018_0001558370-19-000470.htm',
#                'filing_date': '2019-02-07',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/66740/000155837019000470/mmm-20181231x10k.htm',
#                'period_of_report': '2018-12-31',
#                'relevance_score': 0.9657577872,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/66740_10K_2018_0001558370-19-000470.json',
#                'state_location': 'MN'},
#   'page_content': '0.02\n'
#                   '0.50\n'
#                   '-\n'
#                   'Current period, excluding MN Natural Resource Damages (NRD) resolution and TCJA '
#                   'measurement period adjustment\n'
#                   '$\n'
#                   '2.31\n'
#                   '$\n'
#                   '10.46\n'
#                   '$\n'
#                   '9.17\n'
#                   'TCJA measurement period adjustment\n'
#                   '0.07\n'
#                   '(0.29)\n'
#                   '(1.24)\n'
#                   'MN NRD resolution\n'
#                   '(0.11)\n'
#                   '(1.28)\n'
#                   '-\n'
#                   'Current period\n'
#                   '$\n'
#                   '2.27\n'
#                   '$\n'
#                   '8.89\n'
#                   '$\n'
#                   '7.93\n'
#                   '\t\t\n'
#                   'Year 2018 and fourth quarter EPS:\n'
#                   'For the fourth quarter of 2018, net income attributable to 3M was $1.347 '
#                   'billion, or $2.27 per diluted share, compared to $523 million, or $0.85 per '
#                   'diluted share, in the fourth quarter of 2017, an increase of 167 percent on a '
#                   'per diluted share basis. Adjusting for the impacts related to the resolution of '
#                   'the Minnesota natural resource damages (NRD) matter and accounting for the '
#                   'enactment of the Tax Cuts and Jobs Act (TCJA), as further described in the '
#                   'Operating income, operating income margin, income before taxes, net income, '
#                   'earnings per share, and effective tax rate adjusted for impacts of the '
#                   'Minnesota NRD resolution and the measurement period adjustment to the impact of '
#                   'the enactment of the Tax Cuts and Jobs Act (TCJA) - (non-GAAP measures) section '
#                   'below, net income attributable to 3M was $1.366 billion, or $2.31 diluted share '
#                   'for the fourth quarter of 2018, compared to $1.285 billion, or $2.10 per '
#                   'diluted share for the fourth quarter of 2017, an increase of 10.0 percent on a '
#                   'per diluted share basis.\n'
#                   'For full year 2018, net income attributable to 3M was $5.349 billion, or $8.89 '
#                   'per diluted share basis, compared to $4.858 billion, or $7.93 per diluted '
#                   'share, for full year 2017, an increase of 12.1 percent on a per diluted share. '
#                   'Adjusting for the NRD matter and the TCJA as described further below, net '
#                   'income was $6.295 billion, or $10.46 per diluted share for the full year 2018, '
#                   'compared to $5.620 billion, or $9.17 per diluted share for full year 2017, an '
#                   'increase of 14.1 percent on a per diluted share basis.\n'
#                   'These non-GAAP measures are further described and reconciled to the most '
#                   'directly comparable GAAP financial measures in the section that follows.',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 0
# Is the response correct? (1 for True, 0 for False): 0
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 6
# Question: What is the 3M CO's earnings per share and how does it compare to industry benchmarks?
# Response: Based on the provided information, 3M CO's earnings per share (EPS) for the fourth quarter and year 2018 were $0.85 and $7.93, respectively. The company's EPS decreased by $0.54 in 2018 compared to the same period last year.
# To provide context, the industry benchmarks for the diversified industrial goods sector, which includes 3M CO, are as follows:
# * For the fourth quarter of 2018, the sector's EPS was $2.10, according to S&P Capital IQ data.
# * For the full year 2018, the sector's EPS was $10.46, according to S&P Capital IQ data.
# Therefore, based on the provided information, 3M CO's EPS of $0.85 and $7.93 for the fourth quarter and year 2018, respectively, are below the industry benchmarks for the diversified industrial goods sector.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '66740',
#                'company': '3M CO',
#                'filename': '66740_10K_2018_0001558370-19-000470.htm',
#                'filing_date': '2019-02-07',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/66740/000155837019000470/mmm-20181231x10k.htm',
#                'period_of_report': '2018-12-31',
#                'relevance_score': 0.9699929953,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/66740_10K_2018_0001558370-19-000470.json',
#                'state_location': 'MN'},
#   'page_content': 'OVERVIEW\n'
#                   '3M is a diversified global manufacturer, technology innovator and marketer of a '
#                   'wide variety of products and services. As described in Note 18, effective in '
#                   'the first quarter of 2018, 3M improved the alignment of its businesses around '
#                   'markets and customers. Segment information presented herein reflects the impact '
#                   'of these changes for all periods presented. 3M manages its operations in five '
# ...
# Response: Based on the provided annual report, the answer to your question is: Yes, 3M leverages technology for its operations and there are ongoing technological advancements. The company invests in various areas of research and development, including application development, product and manufacturing support, product development, and technology development, aimed at disruptive innovations. Additionally, 3M continues to manage its operations in five operating business segments: Industrial; Safety and Graphics; Health Care; Electronics and Energy; and Consumer, which involves leveraging technology to optimize processes and improve efficiency across these segments.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '66740',
#                'company': '3M CO',
#                'filename': '66740_10K_2018_0001558370-19-000470.htm',
#                'filing_date': '2019-02-07',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/66740/000155837019000470/mmm-20181231x10k.htm',
#                'period_of_report': '2018-12-31',
#                'relevance_score': 0.9679678679,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/66740_10K_2018_0001558370-19-000470.json',
#                'state_location': 'MN'},
#   'page_content': 'OVERVIEW\n'
#                   '3M is a diversified global manufacturer, technology innovator and marketer of a '
#                   'wide variety of products and services. As described in Note 18, effective in '
#                   'the first quarter of 2018, 3M improved the alignment of its businesses around '
#                   'markets and customers. Segment information presented herein reflects the impact '
#                   'of these changes for all periods presented. 3M manages its operations in five '
#                   'operating business segments: Industrial; Safety and Graphics; Health Care; '
#                   'Electronics and Energy; and Consumer. From a geographic perspective, any '
#                   'references to EMEA refer to Europe, Middle East and Africa on a combined '
#                   'basis.\n'
#                   'Earnings per share (EPS) attributable to 3M common shareholders - diluted:\n'
#                   'The following table provides the increase (decrease) in diluted earnings per '
#                   'share for the fourth quarter and year 2018 compared to the same period last '
#                   'year, in addition to 2017 compared to 2016.\n'
#                   'Three months ended\n'
#                   'Year ended December 31,\n'
#                   '(Earnings per diluted share)\n'
#                   'December 31, 2018\n'
#                   'Same period last year\n'
#                   '$\n'
#                   '0.85\n'
#                   '$\n'
#                   '7.93\n'
#                   '$\n'
#                   '8.16\n'
#                   '2017 Enactment of TCJA Impact\n'
#                   '1.25\n'
#                   '1.24\n'
#                   '-\n'
#                   'Same period last year, excluding 2017 Tax Cuts and Jobs Act (TCJA)\n'
#                   '$\n'
#                   '2.10\n'
#                   '$\n'
#                   '9.17\n'
#                   '$\n'
#                   '8.16\n'
#                   'Increase/(decrease) in earnings per share - diluted, due to:\n'
#                   '2017 divestiture of identity management business\n'
#                   '-\n'
#                   '(0.54)\n'
#                   '0.54\n'
#                   'Organic growth/productivity and other\n'
#                   '0.18\n'
#                   '0.92\n'
#                   '0.47\n'
#                   'Acquisitions/other divestiture gains\n'
#                   '(0.15)\n'
#                   '(0.15)\n'
#                   '-\n'
#                   'Foreign exchange impacts\n'
#                   '(0.03)\n'
#                   '(0.05)\n'
#                   '(0.13)\n'
#                   'Legal-related charges\n'
#                   '-\n'
#                   '(0.04)\n'
#                   '-\n'
#                   'Legal - respirator mask actuarial reserve\n'
#                   '-\n'
#                   '-\n'
#                   '(0.07)\n'
#                   'Other expense\n'
#                   '0.06\n'
#                   '(0.14)\n'
#                   '(0.22)\n'
#                   'Income tax rate, excluding Tax Cuts and Jobs Act (TCJA) measurement period '
#                   'adjustment\n'
#                   '0.05\n'
#                   '0.61\n'
#                   '0.34\n'
#                   'Shares of common stock outstanding\n'
#                   '0.08\n'
#                   '0.18\n'
#                   '0.08\n'
#                   '2018 divestiture of Communication Markets Division, net of related '
#                   'restructuring actions\n'
#                   '0.02\n'
#                   '0.50\n'
#                   '-\n'
#                   'Current period, excluding MN Natural Resource Damages (NRD) resolution and TCJA '
#                   'measurement period adjustment\n'
#                   '$\n'
#                   '2.31\n'
#                   '$\n'
#                   '10.46\n'
#                   '$\n'
#                   '9.17\n'
#                   'TCJA measurement period adjustment\n'
#                   '0.07\n'
#                   '(0.29)\n'
#                   '(1.24)',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '66740',
#                'company': '3M CO',
#                'filename': '66740_10K_2022_0000066740-23-000014.htm',
#                'filing_date': '2023-02-08',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/66740/000006674023000014/mmm-20221231.htm',
#                'period_of_report': '2022-12-31',
#                'relevance_score': 0.9651627541000001,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/66740_10K_2022_0000066740-23-000014.json',
#                'state_location': 'MN'},
#   'page_content': 'Selling, General and Administrative Expenses:\n'
#                   'SG&A, measured as a percent of sales, increased in 2022 when compared to the '
#                   'same period last year. SG&A was impacted by increased special item costs for '
#                   'significant litigation primarily related to steps toward resolving Combat Arms '
#                   'Earplugs litigation (discussed in Note 16) resulting in a 2022 second quarter '
#                   'pre-tax charge of approximately $1.2 billion, certain impairment costs related '
#                   'to exiting PFAS manufacturing (see Note 15), costs related to exiting Russia '
#                   '(see Note 15), divestiture-related restructuring charges (see Note 5), and '
#                   'continued investment in key growth initiatives. These increases were partially '
#                   'offset by restructuring benefits and ongoing general 3M cost management.\n'
#                   'Research, Development and Related Expenses:\n'
#                   'R&D, measured as a percent of sales, decreased in 2022 when compared to the '
#                   'same period last year. 3M continues to invest in a range of R&D activities from '
#                   'application development, product and manufacturing support, product development '
#                   'and technology development aimed at disruptive innovations.\n'
#                   'Gain on Business Divestitures:\n'
#                   'In the third quarter of 2022, 3M recorded a pre-tax gain of $2.7 billion ($2.7 '
#                   'billion after tax) related to the split-off and combination of its Food Safety '
#                   'business with Neogen Corporation. Refer to Note 3 for further details.\n'
#                   'Goodwill Impairment Expense:\n'
#                   "As a result of 3M's commitment to exit per- and polyfluoroalkyl substance "
#                   '(PFAS) manufacturing, 3M recorded a goodwill impairment charge related to the '
#                   'Advanced Materials reporting unit (within the Transportation and Electronics '
#                   'business). Refer to Note 15 for further details.\n'
#                   'Other Expense (Income), Net:\n'
#                   'See Note 6 for a detailed breakout of this line item.',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 0
# Is the response correct? (1 for True, 0 for False): 0
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 34
# Question: What does the 3M CO foresee in terms of future growth and challenges and are there any strategic plans outlined for the upcoming years?
# Response: The answer is not in the provided information. The document only provides information on the company's financial performance and investing activities for the year 2022, but does not provide any information on future growth and challenges or strategic plans beyond that year.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '66740',
#                'company': '3M CO',
#                'filename': '66740_10K_2022_0000066740-23-000014.htm',
#                'filing_date': '2023-02-08',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/66740/000006674023000014/mmm-20221231.htm',
#                'period_of_report': '2022-12-31',
#                'relevance_score': 0.9657886028,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/66740_10K_2022_0000066740-23-000014.json',
#                'state_location': 'MN'},
#   'page_content': 'Cash payment from Food Safety business split-off, net of divested cash 478 -\n'
#                   'Other - net 1 31\n'
#                   'Net cash provided by (used in) investing activities $ (1,046) $ (1,317)\n'
#                   'Investments in property, plant and equipment enable growth across many diverse '
#                   'markets, helping to meet product demand and increasing manufacturing '
#                   'efficiency. The Company expects 2023 capital spending to be approximately $1.5 '
#                   'billion to $1.8 billion as 3M continues to invest in growth, productivity and '
#                   'sustainability.\n'
#                   '3M records capital-related government grants earned as reductions to the cost '
#                   'of property, plant and equipment; and associated unpaid liabilities and grant '
#                   'proceeds receivable are considered non-cash changes in such balances for '
#                   'purposes of preparation of statement of cash flows.\n'
#                   '3M invests in renewal and maintenance programs, which pertain to cost '
#                   'reduction, cycle time, maintaining and renewing current capacity, eliminating '
#                   'pollution, and compliance. Costs related to maintenance, ordinary repairs, and '
#                   'certain other items are expensed. 3M also invests in growth, which adds to '
#                   'capacity, driven by new products, both through expansion of current facilities '
#                   'and new facilities. Finally, 3M also invests in other initiatives, such as '
#                   'information technology (IT), laboratory facilities, and a continued focus on '
#                   'investments in sustainability.\n'
#                   'Refer to Note 3 for information on acquisitions and divestitures (including the '
#                   'cash payment from the Food Safety business split-off). The Company is actively '
#                   'considering additional acquisitions, investments and strategic alliances, and '
#                   'from time to time may also divest certain businesses.',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '66740',
#                'company': '3M CO',
#                'filename': '66740_10K_2018_0001558370-19-000470.htm',
#                'filing_date': '2019-02-07',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/66740/000155837019000470/mmm-20181231x10k.htm',
#                'period_of_report': '2018-12-31',
#                'relevance_score': 0.9628043175000001,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/66740_10K_2018_0001558370-19-000470.json',
#                'state_location': 'MN'},
#   'page_content': 'Cash Flows from Investing Activities:\n'
#                   'Years ended December 31\n'
#                   '(Millions)\n'
#                   'Purchases of property, plant and equipment (PP&E)\n'
#                   '$\n'
#                   '(1,577)\n'
#                   '$\n'
#                   '(1,373)\n'
#                   '$\n'
#                   '(1,420)\n'
#                   'Proceeds from sale of PP&E and other assets\n'
#                   'Acquisitions, net of cash acquired\n'
#                   '(2,023)\n'
#                   '(16)\n'
#                   'Purchases and proceeds from maturities and sale of marketable securities and '
#                   'investments, net\n'
#                   '(798)\n'
#                   '(163)\n'
#                   'Proceeds from sale of businesses, net of cash sold\n'
#                   '1,065\n'
#                   'Other - net\n'
#                   '(6)\n'
#                   '(4)\n'
#                   'Net cash provided by (used in) investing activities\n'
#                   '$\n'
#                   '$\n'
#                   '(3,086)\n'
#                   '$\n'
#                   '(1,403)\n'
#                   '\t\t\n'
#                   'Investments in property, plant and equipment enable growth across many diverse '
#                   'markets, helping to meet product demand and increasing manufacturing '
#                   'efficiency. The Company expects 2019 capital spending to be approximately $1.7 '
#                   'billion to $1.9 billion as 3M continues to invest in its businesses.\n'
#                   '3M invests in renewal and maintenance programs, which pertain to cost '
#                   'reduction, cycle time, maintaining and renewing current capacity, eliminating '
#                   'pollution, and compliance. Costs related to maintenance, ordinary repairs, and '
#                   'certain other items are expensed. 3M also invests in growth, which adds to '
#                   'capacity, driven by new products, both through expansion of current facilities '
#                   'and new facilities. Finally, 3M also invests in other initiatives, such as '
#                   'information technology (IT) and laboratory facilities.\n'
#                   'Refer to Note 3 for information on acquisitions and divestitures. The Company '
#                   'is actively considering additional acquisitions, investments and strategic '
#                   'alliances, and from time to time may also divest certain businesses. Proceeds '
#                   'from sale of businesses in 2018 primarily relate to the sale of 3Ms '
#                   'Communication Markets Division and the sale of certain personal safety product '
#                   'offerings primarily focused on noise, environmental, and heat stress monitoring '
#                   'within the Safety and Graphics business segment.',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 0
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 0
# Progress saved.
#
# Evaluation results saved to 'evaluation_results_3M.json'.

# %%
eval = pd.read_json('/content/evaluation_results_3M.json')
eval.mean()[1:]
# Out:
# The context is relevant to the company     1.000000
# The context is relevant to the question    0.371429
# The response is correct                    0.714286
# The response answers the question          0.485714
# dtype: float64
