# %%
import pandas as pd
import json
from pprint import pprint

# Load your dataframe
# Replace 'your_data.csv' with the actual path to your data file
df1 = pd.read_json('results_ADOBE_rerank_6-2_filter.json')

# Initialize dictionary to store results
results = {'index': [],
           'The context is relevant to the company': [],
           'The context is relevant to the question': [],
           'The response is correct': [],
           'The response answers the question': []}

# Check if there's a previous evaluation progress saved
try:
    with open('evaluation_results_ADOBE.json', 'r') as f:
        previous_results = json.load(f)
    start_index = max(previous_results['index']) + 1
    results = previous_results
    print("Resuming evaluation from the last unanswered question.")
except (FileNotFoundError, ValueError, KeyError):
    start_index = 0
    print("Starting evaluation from the beginning.")

# Function to get valid user input (1 or 0)
def get_valid_input(message):
    while True:
        try:
            user_input = int(input(message))
            if user_input not in (0, 1):
                raise ValueError("Input must be 0 or 1.")
            return user_input
        except ValueError:
            print("Invalid input. Please enter 0 or 1.")

# Iterate over each row in the dataframe
for idx, row in df1.iloc[start_index:].iterrows():
    print("\nRow Index:", idx)
    print("Question:", row['question'])
    print("Response:", row['response'])
    print("Context:")
    pprint(row['context'], width=100)

    # Ask questions and get user input
    context_relevant_to_company = get_valid_input("Is the context relevant to the company? (1 for True, 0 for False): ")
    context_relevant_to_question = get_valid_input("Is the context relevant to the question? (1 for True, 0 for False): ")
    response_correct = get_valid_input("Is the response correct? (1 for True, 0 for False): ")
    response_answers_question = get_valid_input("Does the response answer the question? (1 for True, 0 for False): ")

    # Append results to dictionary
    results['index'].append(idx)
    results['The context is relevant to the company'].append(context_relevant_to_company)
    results['The context is relevant to the question'].append(context_relevant_to_question)
    results['The response is correct'].append(response_correct)
    results['The response answers the question'].append(response_answers_question)

    # Convert results dictionary to JSON and save to a file after each row
    json_result = json.dumps(results, indent=4)
    with open('evaluation_results_ADOBE.json', 'w') as f:
        f.write(json_result)

    print("Progress saved.")
0
print("\nEvaluation results saved to 'evaluation_results_ADOBE.json'.")
# Out:
# Streaming output truncated to the last 5000 lines.
#                   ')\n'
#                   '(4,267,715\n'
#                   ')\n'
#                   'Total stockholders equity\n'
#                   '7,424,835\n'
#                   '7,001,580\n'
#                   'Total liabilities and stockholders equity\n'
#                   '$\n'
#                   '12,707,114\n'
#                   '$\n'
#                   '11,726,472\n'
#                   'See accompanying Notes to Consolidated Financial Statements.\n'
#                   'ADOBE SYSTEMS INCORPORATED\n'
#                   'CONSOLIDATED STATEMENTS OF INCOME\n'
#                   '(In thousands, except per share data)\n'
#                   'Years Ended\n'
#                   'December 2,\n'
#                   'November 27,\n'
#                   'November 28,\n'
#                   'Revenue:\n'
#                   'Subscription\n'
#                   '$\n'
#                   '4,584,833\n'
#                   '$\n'
#                   '3,223,904\n'
#                   '$\n'
#                   '2,076,584\n'
#                   'Product\n'
#                   '800,498\n'
#                   '1,125,146\n'
#                   '1,627,803\n'
#                   'Services and support\n'
#                   '469,099\n'
#                   '446,461\n'
#                   '442,678\n'
#                   'Total revenue\n'
#                   '5,854,430\n'
#                   '4,795,511\n'
#                   '4,147,065\n'
#                   'Cost of revenue:\n'
#                   'Subscription\n'
#                   '461,860\n'
#                   '409,194\n'
#                   '335,432\n'
#                   'Product\n'
#                   '68,917\n'
#                   '90,035\n'
#                   '97,099\n'
#                   'Services and support\n'
#                   '289,131\n'
#                   '245,088\n'
#                   '189,549\n'
#                   'Total cost of revenue\n'
#                   '819,908\n'
#                   '744,317\n'
#                   '622,080\n'
#                   'Gross profit\n'
#                   '5,034,522\n'
#                   '4,051,194\n'
#                   '3,524,985\n'
#                   'Operating expenses:\n'
#                   'Research and development\n'
#                   '975,987\n'
#                   '862,730\n'
#                   '844,353\n'
#                   'Sales and marketing\n'
#                   '1,910,197\n'
#                   '1,683,242\n'
#                   '1,652,308\n'
#                   'General and administrative\n'
#                   '577,710\n'
#                   '531,919\n'
#                   '543,332\n'
#                   'Restructuring and other charges\n'
#                   '(1,508\n'
#                   ')\n'
#                   '1,559\n'
#                   '19,883\n'
#                   'Amortization of purchased intangibles\n'
#                   '78,534\n'
#                   '68,649\n'
#                   '52,424\n'
#                   'Total operating expenses\n'
#                   '3,540,920\n'
#                   '3,148,099\n'
#                   '3,112,300\n'
#                   'Operating income\n'
#                   '1,493,602\n'
#                   '903,095\n'
#                   '412,685\n'
#                   'Non-operating income (expense):\n'
#                   'Interest and other income (expense), net\n'
#                   '13,548\n'
#                   '33,909\n'
#                   '7,267\n'
#                   'Interest expense\n'
#                   '(70,442\n'
#                   ')\n'
#                   '(64,184\n'
#                   ')\n'
#                   '(59,732\n'
#                   ')\n'
#                   'Investment gains (losses), net\n'
#                   '(1,570\n'
#                   ')\n'
#                   '1,156\n'
#                   'Total non-operating income (expense), net\n'
#                   '(58,464\n'
#                   ')\n'
#                   '(29,314\n'
#                   ')\n'
#                   '(51,309\n'
#                   ')\n'
#                   'Income before income taxes\n'
#                   '1,435,138',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '796343',
#                'company': 'ADOBE SYSTEMS INC',
#                'filename': '796343_10K_2015_0000796343-16-000224.htm',
#                'filing_date': '2016-01-19',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1130',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/796343/000079634316000224/adbe10kfy15.htm',
#                'period_of_report': '2015-11-27',
#                'relevance_score': 0.9504660368000001,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/796343_10K_2015_0000796343-16-000224.json',
#                'state_location': 'CA'},
#   'page_content': '422,723\n'
#                   'Non-operating income (expense):\n'
#                   'Interest and other income (expense), net\n'
#                   '33,909\n'
#                   '7,267\n'
#                   '4,941\n'
#                   'Interest expense\n'
#                   '(64,184\n'
#                   ')\n'
#                   '(59,732\n'
#                   ')\n'
#                   '(67,508\n'
#                   ')\n'
#                   'Investment gains (losses), net\n'
#                   '1,156\n'
#                   '(4,015\n'
#                   ')\n'
#                   'Total non-operating income (expense), net\n'
#                   '(29,314\n'
#                   ')\n'
#                   '(51,309\n'
#                   ')\n'
#                   '(66,582\n'
#                   ')\n'
#                   'Income before income taxes\n'
#                   '873,781\n'
#                   '361,376\n'
#                   '356,141\n'
#                   'Provision for income taxes\n'
#                   '244,230\n'
#                   '92,981\n'
#                   '66,156\n'
#                   'Net income\n'
#                   '$\n'
#                   '629,551\n'
#                   '$\n'
#                   '268,395\n'
#                   '$\n'
#                   '289,985\n'
#                   'Basic net income per share\n'
#                   '$\n'
#                   '1.26\n'
#                   '$\n'
#                   '0.54\n'
#                   '$\n'
#                   '0.58\n'
#                   'Shares used to compute basic net income per share\n'
#                   '498,764\n'
#                   '497,867\n'
#                   '501,372\n'
#                   'Diluted net income per share\n'
#                   '$\n'
#                   '1.24\n'
#                   '$\n'
#                   '0.53\n'
#                   '$\n'
#                   '0.56\n'
#                   'Shares used to compute diluted net income per share\n'
#                   '507,164\n'
#                   '508,480\n'
#                   '513,476\n'
#                   'See accompanying Notes to Consolidated Financial Statements.\n'
#                   'ADOBE SYSTEMS INCORPORATED\n'
#                   'CONSOLIDATED STATEMENTS OF COMPREHENSIVE INCOME\n'
#                   '(In thousands)\n'
#                   'Years Ended\n'
#                   'November 27,\n'
#                   'November 28,\n'
#                   'November 29,\n'
#                   'Increase/(Decrease)\n'
#                   'Net income\n'
#                   '$\n'
#                   '629,551\n'
#                   '$\n'
#                   '268,395\n'
#                   '$\n'
#                   '289,985\n'
#                   'Other comprehensive income (loss), net of taxes:\n'
#                   'Available-for-sale securities:\n'
#                   'Unrealized gains / losses on available-for-sale securities\n'
#                   '(9,226\n'
#                   ')\n'
#                   '2,315\n'
#                   '(2,185\n'
#                   ')\n'
#                   'Reclassification adjustment for recognized gains / losses on available-for-sale '
#                   'securities\n'
#                   '(2,955\n'
#                   ')\n'
#                   '(3,928\n'
#                   ')\n'
#                   '(3,013\n'
#                   ')\n'
#                   'Net increase (decrease) from available-for-sale securities\n'
#                   '(12,181\n'
#                   ')\n'
#                   '(1,613\n'
#                   ')\n'
#                   '(5,198\n'
#                   ')\n'
#                   'Derivatives designated as hedging instruments:\n'
#                   'Unrealized gains / losses on derivative instruments\n'
#                   '29,795\n'
#                   '41,993\n'
#                   '34,677\n'
#                   'Reclassification adjustment for recognized gains / losses on derivative '
#                   'instruments\n'
#                   '(55,535\n'
#                   ')\n'
#                   '(18,705\n'
#                   ')\n'
#                   '(35,914\n'
#                   ')\n'
#                   'Net increase (decrease) from derivatives designated as hedging instruments\n'
#                   '(25,740\n'
#                   ')\n'
#                   '23,288\n'
#                   '(1,237\n'
#                   ')\n'
#                   'Foreign currency translation adjustments\n'
#                   '(123,065\n'
#                   ')\n'
#                   '(75,872\n'
#                   ')\n'
#                   '21,826\n'
#                   'Other comprehensive income (loss), net of taxes\n'
#                   '(160,986\n'
#                   ')\n'
#                   '(54,197\n'
#                   ')\n'
#                   '15,391\n'
#                   'Total comprehensive income, net of taxes\n'
#                   '$\n'
#                   '468,565\n'
#                   '$\n'
#                   '214,198\n'
#                   '$\n'
#                   '305,376\n'
#                   'See accompanying Notes to Consolidated Financial Statements.\n'
#                   'ADOBE SYSTEMS INCORPORATED\n'
#                   'CONSOLIDATED STATEMENTS OF STOCKHOLDERS EQUITY\n'
#                   '(In thousands)\n'
#                   'Common Stock',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 0
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 6
# Question: What is the ADOBE SYSTEMS INC's earnings per share and how does it compare to industry benchmarks?
# Response: Based on the information provided in the document, Adobe Systems Inc.'s earnings per share (EPS) for the year ending November 27, 2015 was $2.69. This can be calculated by dividing the company's net income by its total number of shares outstanding.
# To compare this to industry benchmarks, we need to look at the EPS of other companies within the same industry. According to a report by Yahoo Finance, the average EPS for companies in the Technology sector was $10.54 for the same period. Therefore, Adobe Systems Inc.'s EPS of $2.69 is lower than the industry average.
# It is important to note that EPS can vary significantly depending on various factors such as revenue growth, profit margins, and the number of shares outstanding. Therefore, it is essential to analyze the company's financial performance in relation to these factors to get a clearer picture of its financial health.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '796343',
#                'company': 'ADOBE SYSTEMS INC',
#                'filename': '796343_10K_2015_0000796343-16-000224.htm',
#                'filing_date': '2016-01-19',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1130',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/796343/000079634316000224/adbe10kfy15.htm',
#                'period_of_report': '2015-11-27',
#                'relevance_score': 0.9621736407,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/796343_10K_2015_0000796343-16-000224.json',
#                'state_location': 'CA'},
#   'page_content': '3,214\n'
#                   '5,194\n'
#                   'Income taxes payable\n'
#                   '256,129\n'
#                   '125,746\n'
#                   'Deferred income taxes\n'
#                   '208,209\n'
#                   '342,315\n'
#                   'Other liabilities\n'
#                   '85,459\n'
#                   '73,747\n'
#                   'Total liabilities\n'
#                   '4,724,892\n'
#                   '4,009,924\n'
#                   'Commitments and contingencies\n'
#                   'Stockholders equity:\n'
#                   'Preferred stock, $0.0001 par value; 2,000 shares authorized; none issued\n'
#                   '-\n'
#                   '-\n'
#                   'Common stock, $0.0001 par value; 900,000 shares authorized; 600,834 shares '
#                   'issued;\n'
#                   '497,809 and 497,484 shares outstanding, respectively\n'
#                   'Additional paid-in-capital\n'
#                   '4,184,883\n'
#                   '3,778,495\n'
#                   'Retained earnings\n'
#                   '7,253,431\n'
#                   '6,924,294\n'
#                   'Accumulated other comprehensive income (loss)\n'
#                   '(169,080\n'
#                   ')\n'
#                   '(8,094\n'
#                   ')\n'
#                   'Treasury stock, at cost (103,025 and 103,350 shares, respectively), net of '
#                   'reissuances\n'
#                   '(4,267,715\n'
#                   ')\n'
#                   '(3,918,851\n'
#                   ')\n'
#                   'Total stockholders equity\n'
#                   '7,001,580\n'
#                   '6,775,905\n'
#                   'Total liabilities and stockholders equity\n'
#                   '$\n'
#                   '11,726,472\n'
#                   '$\n'
#                   '10,785,829\n'
#                   'See accompanying Notes to Consolidated Financial Statements.\n'
#                   'ADOBE SYSTEMS INCORPORATED\n'
#                   'CONSOLIDATED STATEMENTS OF INCOME\n'
#                   '(In thousands, except per share data)\n'
#                   'Years Ended\n'
#                   'November 27,\n'
#                   'November 28,\n'
#                   'November 29,\n'
#                   'Revenue:\n'
#                   'Subscription\n'
#                   '$\n'
#                   '3,223,904\n'
#                   '$\n'
#                   '2,076,584\n'
#                   '$\n'
#                   '1,137,856\n'
#                   'Product\n'
#                   '1,125,146\n'
#                   '1,627,803\n'
#                   '2,470,098\n'
#                   'Services and support\n'
#                   '446,461\n'
#                   '442,678\n'
#                   '447,286\n'
#                   'Total revenue\n'
#                   '4,795,511\n'
#                   '4,147,065\n'
#                   '4,055,240\n'
#                   'Cost of revenue:\n'
#                   'Subscription\n'
#                   '409,194\n'
#                   '335,432\n'
#                   '278,077\n'
#                   'Product\n'
#                   '90,035\n'
#                   '97,099\n'
#                   '138,154\n'
#                   'Services and support\n'
#                   '245,088\n'
#                   '189,549\n'
#                   '170,326\n'
#                   'Total cost of revenue\n'
#                   '744,317\n'
#                   '622,080\n'
#                   '586,557\n'
#                   'Gross profit\n'
#                   '4,051,194\n'
#                   '3,524,985\n'
#                   '3,468,683\n'
#                   'Operating expenses:\n'
#                   'Research and development\n'
#                   '862,730\n'
#                   '844,353\n'
#                   '826,631\n'
#                   'Sales and marketing\n'
#                   '1,683,242\n'
#                   '1,652,308\n'
#                   '1,620,454\n'
#                   'General and administrative\n'
#                   '531,919\n'
#                   '543,332\n'
#                   '520,124\n'
#                   'Restructuring and other charges\n'
#                   '1,559\n'
#                   '19,883\n'
#                   '26,497\n'
#                   'Amortization of purchased intangibles\n'
#                   '68,649\n'
#                   '52,424\n'
#                   '52,254\n'
#                   'Total operating expenses\n'
#                   '3,148,099\n'
#                   '3,112,300\n'
#                   '3,045,960\n'
#                   'Operating income\n'
#                   '903,095\n'
#                   '412,685\n'
#                   '422,723\n'
#                   'Non-operating income (expense):\n'
#                   'Interest and other income (expense), net\n'
#                   '33,909\n'
#                   '7,267\n'
#                   '4,941\n'
#                   'Interest expense\n'
#                   '(64,184\n'
#                   ')\n'
#                   '(59,732\n'
#                   ')\n'
#                   '(67,508\n'
#                   ')\n'
#                   'Investment gains (losses), net\n'
#                   '1,156\n'
#                   '(4,015\n'
#                   ')',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '796343',
#                'company': 'ADOBE SYSTEMS INC',
#                'filename': '796343_10K_2017_0000796343-18-000015.htm',
#                'filing_date': '2018-01-22',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1202',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/796343/000079634318000015/adbe10kfy17.htm',
#                'period_of_report': '2017-12-01',
#                'relevance_score': 0.9573122263,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/796343_10K_2017_0000796343-18-000015.json',
#                'state_location': 'CA'},
#   'page_content': 'Other liabilities\n'
#                   '125,188\n'
#                   '97,404\n'
#                   'Total liabilities\n'
#                   '6,075,687\n'
#                   '5,272,411\n'
#                   'Commitments and contingencies\n'
#                   'Stockholders equity:\n'
#                   'Preferred stock, $0.0001 par value; 2,000 shares authorized; none issued\n'
#                   '-\n'
#                   '-\n'
#                   'Common stock, $0.0001 par value; 900,000 shares authorized; 600,834 shares '
#                   'issued;\n'
#                   '491,262 and 494,254 shares outstanding, respectively\n'
#                   'Additional paid-in-capital\n'
#                   '5,082,195\n'
#                   '4,616,331\n'
#                   'Retained earnings\n'
#                   '9,573,870\n'
#                   '8,114,517\n'
#                   'Accumulated other comprehensive income (loss)\n'
#                   '(111,821\n'
#                   ')\n'
#                   '(173,602\n'
#                   ')\n'
#                   'Treasury stock, at cost (109,572 and 106,580 shares, respectively), net of '
#                   'reissuances\n'
#                   '(6,084,436\n'
#                   ')\n'
#                   '(5,132,472\n'
#                   ')\n'
#                   'Total stockholders equity\n'
#                   '8,459,869\n'
#                   '7,424,835\n'
#                   'Total liabilities and stockholders equity\n'
#                   '$\n'
#                   '14,535,556\n'
#                   '$\n'
#                   '12,697,246\n'
#                   'See accompanying Notes to Consolidated Financial Statements.\n'
#                   'ADOBE SYSTEMS INCORPORATED\n'
#                   'CONSOLIDATED STATEMENTS OF INCOME\n'
#                   '(In thousands, except per share data)\n'
#                   'Years Ended\n'
#                   'December 1,\n'
#                   'December 2,\n'
#                   'November 27,\n'
#                   'Revenue:\n'
#                   'Subscription\n'
#                   '$\n'
#                   '6,133,869\n'
#                   '$\n'
#                   '4,584,833\n'
#                   '$\n'
#                   '3,223,904\n'
#                   'Product\n'
#                   '706,767\n'
#                   '800,498\n'
#                   '1,125,146\n'
#                   'Services and support\n'
#                   '460,869\n'
#                   '469,099\n'
#                   '446,461\n'
#                   'Total revenue\n'
#                   '7,301,505\n'
#                   '5,854,430\n'
#                   '4,795,511\n'
#                   'Cost of revenue:\n'
#                   'Subscription\n'
#                   '623,048\n'
#                   '461,860\n'
#                   '409,194\n'
#                   'Product\n'
#                   '57,082\n'
#                   '68,917\n'
#                   '90,035\n'
#                   'Services and support\n'
#                   '330,361\n'
#                   '289,131\n'
#                   '245,088\n'
#                   'Total cost of revenue\n'
#                   '1,010,491\n'
#                   '819,908\n'
#                   '744,317\n'
#                   'Gross profit\n'
#                   '6,291,014\n'
#                   '5,034,522\n'
#                   '4,051,194\n'
#                   'Operating expenses:\n'
#                   'Research and development\n'
#                   '1,224,059\n'
#                   '975,987\n'
#                   '862,730\n'
#                   'Sales and marketing\n'
#                   '2,197,592\n'
#                   '1,910,197\n'
#                   '1,683,242\n'
#                   'General and administrative\n'
#                   '624,706\n'
#                   '576,202\n'
#                   '533,478\n'
#                   'Amortization of purchased intangibles\n'
#                   '76,562\n'
#                   '78,534\n'
#                   '68,649\n'
#                   'Total operating expenses\n'
#                   '4,122,919\n'
#                   '3,540,920\n'
#                   '3,148,099\n'
#                   'Operating income\n'
#                   '2,168,095\n'
#                   '1,493,602\n'
#                   '903,095\n'
#                   'Non-operating income (expense):\n'
#                   'Interest and other income (expense), net\n'
#                   '36,395\n'
#                   '13,548\n'
#                   '33,909\n'
#                   'Interest expense\n'
#                   '(74,402\n'
#                   ')\n'
#                   '(70,442\n'
#                   ')\n'
#                   '(64,184\n'
#                   ')\n'
#                   'Investment gains (losses), net\n'
#                   '7,553\n'
#                   '(1,570\n'
#                   ')\n'
#                   'Total non-operating income (expense), net\n'
#                   '(30,454\n'
#                   ')\n'
#                   '(58,464\n'
#                   ')\n'
#                   '(29,314\n'
#                   ')\n'
#                   'Income before income taxes\n'
#                   '2,137,641\n'
#                   '1,435,138\n'
#                   '873,781\n'
#                   'Provision for income taxes',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 0
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 7
# Question: What is the ADOBE SYSTEMS INC's cash flow generated from operations and are there any notable trends or fluctuations?
# Response: The answer is in the context. According to the document, ADobe Systems Inc generated $2.91 billion in net cash provided by operating activities in fiscal 2017. Additionally, the document states that the primary sources of cash are receipts from revenue, while the primary uses of cash are payroll-related expenses, general operating expenses, including marketing, travel, and office rent, and cost of revenue. There are also other sources of cash, such as proceeds from participation in the employee stock purchase plan, and other uses of cash, such as stock repurchases and business acquisitions. However, the document does not provide detailed information about any notable trends or fluctuations in the company's cash flow from operations.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '796343',
#                'company': 'ADOBE SYSTEMS INC',
#                'filename': '796343_10K_2017_0000796343-18-000015.htm',
#                'filing_date': '2018-01-22',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1202',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/796343/000079634318000015/adbe10kfy17.htm',
#                'period_of_report': '2017-12-01',
#                'relevance_score': 0.9672127366000001,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/796343_10K_2017_0000796343-18-000015.json',
#                'state_location': 'CA'},
#   'page_content': 'The timing of the resolution of income tax examinations is highly uncertain as '
#                   'are the amounts and timing of tax payments that are part of any audit '
#                   'settlement process. These events could cause large fluctuations in the balance '
#                   'of current and non-current assets, liabilities and income taxes payable. We '
#                   'believe that within the next 12 months, it is reasonably possible that either '
#                   'certain audits will conclude or statutes of limitations on certain income tax '
#                   'examination periods will expire, or both. Given the uncertainties described '
#                   'above, we can only determine a range of estimated potential decreases in '
#                   'underlying unrecognized tax benefits ranging from $0 to approximately $40 '
#                   'million.\n'
#                   'LIQUIDITY AND CAPITAL RESOURCES\n'
#                   'This data should be read in conjunction with our Consolidated Statements of '
#                   'Cash Flows.\n'
#                   'As of\n'
#                   '(in millions)\n'
#                   'December 1, 2017\n'
#                   'December 2, 2016\n'
#                   'Cash and cash equivalents\n'
#                   '$\n'
#                   '2,306.1\n'
#                   '$\n'
#                   '1,011.3\n'
#                   'Short-term investments\n'
#                   '$\n'
#                   '3,513.7\n'
#                   '$\n'
#                   '3,750.0\n'
#                   'Working capital\n'
#                   '$\n'
#                   '3,720.4\n'
#                   '$\n'
#                   '3,028.1\n'
#                   'Stockholders equity\n'
#                   '$\n'
#                   '8,459.9\n'
#                   '$\n'
#                   '7,424.8\n'
#                   'A summary of our cash flows is as follows:\n'
#                   '(in millions)\n'
#                   'Fiscal\n'
#                   'Fiscal\n'
#                   'Fiscal\n'
#                   'Net cash provided by operating activities\n'
#                   '$\n'
#                   '2,912.9\n'
#                   '$\n'
#                   '2,199.7\n'
#                   '$\n'
#                   '1,469.5\n'
#                   'Net cash used for investing activities\n'
#                   '(442.9\n'
#                   ')\n'
#                   '(960.0\n'
#                   ')\n'
#                   '(1,488.4\n'
#                   ')\n'
#                   'Net cash used for financing activities\n'
#                   '(1,183.7\n'
#                   ')\n'
#                   '(1,090.7\n'
#                   ')\n'
#                   '(200.7\n'
#                   ')\n'
#                   'Effect of foreign currency exchange rates on cash and cash equivalents\n'
#                   '8.5\n'
#                   '(14.2\n'
#                   ')\n'
#                   '(21.2\n'
#                   ')\n'
#                   'Net increase (decrease) in cash and cash equivalents\n'
#                   '$\n'
#                   '1,294.8\n'
#                   '$\n'
#                   '134.8\n'
#                   '$\n'
#                   '(240.8\n'
#                   ')\n'
#                   'Our primary source of cash is receipts from revenue. The primary uses of cash '
#                   'are payroll related expenses, general operating expenses including marketing, '
#                   'travel and office rent, and cost of revenue. Other sources of cash are proceeds '
#                   'from participation in the employee stock purchase plan. Other uses of cash '
#                   'include our stock repurchase program, which is described below, business '
#                   'acquisitions and purchases of property and equipment.\n'
#                   'Cash Flows from Operating Activities',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '796343',
#                'company': 'ADOBE SYSTEMS INC',
#                'filename': '796343_10K_2017_0000796343-18-000015.htm',
#                'filing_date': '2018-01-22',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1202',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/796343/000079634318000015/adbe10kfy17.htm',
#                'period_of_report': '2017-12-01',
#                'relevance_score': 0.9581753612,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/796343_10K_2017_0000796343-18-000015.json',
#                'state_location': 'CA'},
#   'page_content': 'Cash Flows from Operating Activities\n'
#                   'For fiscal 2017, net cash provided by operating activities of $2.91 billion was '
#                   'primarily comprised of net income plus the net effect of non-cash items. The '
#                   'primary working capital sources of cash were net income coupled with increases '
#                   'in deferred revenue and accrued expenses. The increase in deferred revenue was '
#                   'primarily due to increased subscriptions for our Creative Cloud offerings and '
#                   'increases in Digital Marketing hosted services. The increase in accrued '
#                   'expenses is primarily due to the increase in accruals for compensation costs '
#                   'and employee benefits driven by headcount growth, and increased accrued media '
#                   'costs associated with our Advertising Cloud offerings, including TubeMogul. The '
#                   'primary working capital uses of cash were increases in trade receivables, '
#                   'payments of trade payables assumed as part of the TubeMogul acquisition, and a '
#                   'decrease in income taxes payable. Trade receivables increased primarily due to '
#                   'revenue linearity, higher revenue levels, and increased media rebill '
#                   'receivables attributable to TubeMogul. Income taxes payable decreased primarily '
#                   'due to taxes paid in excess of the tax provision increase.',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 8
# Question: How much has the ADOBE SYSTEMS INC invested in capital expenditures and are there any significant projects underway?
# Response: The answer is not provided in the given document. The document only provides information on the company's balance sheets, statements of income, and cash flows for the year ended November 27, 2015, as well as notes to the consolidated financial statements and the report of KPMG LLP, independent registered public accounting firm. It does not provide information on the company's capital expenditures or significant projects underway.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '796343',
#                'company': 'ADOBE SYSTEMS INC',
#                'filename': '796343_10K_2015_0000796343-16-000224.htm',
#                'filing_date': '2016-01-19',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1130',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/796343/000079634316000224/adbe10kfy15.htm',
#                'period_of_report': '2015-11-27',
#                'relevance_score': 0.9634170532,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/796343_10K_2015_0000796343-16-000224.json',
#                'state_location': 'CA'},
#   'page_content': 'INDEX TO CONSOLIDATED FINANCIAL STATEMENTS\n'
#                   'Page No.\n'
#                   'Consolidated Balance Sheets\n'
#                   'Consolidated Statements of Income\n'
#                   'Consolidated Statements of Comprehensive Income\n'
#                   "Consolidated Statements of Stockholders' Equity\n"
#                   'Consolidated Statements of Cash Flows\n'
#                   'Notes to Consolidated Financial Statements\n'
#                   'Report of KPMG LLP, Independent Registered Public Accounting Firm\n'
#                   'All financial statement schedules have been omitted, since the required '
#                   'information is not applicable or is not present in amounts sufficient to '
#                   'require submission of the schedule, or because the information required is '
#                   'included in the Consolidated Financial Statements and Notes thereto.\n'
#                   'ADOBE SYSTEMS INCORPORATED\n'
#                   'CONSOLIDATED BALANCE SHEETS\n'
#                   '(In thousands, except par value)\n'
#                   'November 27,\n'
#                   'November 28,\n'
#                   'ASSETS\n'
#                   'Current assets:\n'
#                   'Cash and cash equivalents\n'
#                   '$\n'
#                   '876,560\n'
#                   '$\n'
#                   '1,117,400\n'
#                   'Short-term investments\n'
#                   '3,111,524\n'
#                   '2,622,091\n'
#                   'Trade receivables, net of allowances for doubtful accounts of $7,293 and '
#                   '$7,867, respectively\n'
#                   '672,006\n'
#                   '591,800\n'
#                   'Deferred income taxes\n'
#                   '-\n'
#                   '95,279\n'
#                   'Prepaid expenses and other current assets\n'
#                   '161,802\n'
#                   '175,758\n'
#                   'Total current assets\n'
#                   '4,821,892\n'
#                   '4,602,328\n'
#                   'Property and equipment, net\n'
#                   '787,421\n'
#                   '785,123\n'
#                   'Goodwill\n'
#                   '5,366,881\n'
#                   '4,721,962\n'
#                   'Purchased and other intangibles, net\n'
#                   '510,007\n'
#                   '469,662\n'
#                   'Investment in lease receivable\n'
#                   '80,439\n'
#                   '80,439\n'
#                   'Other assets\n'
#                   '159,832\n'
#                   '126,315\n'
#                   'Total assets\n'
#                   '$\n'
#                   '11,726,472\n'
#                   '$\n'
#                   '10,785,829\n'
#                   'LIABILITIES AND STOCKHOLDERS EQUITY\n'
#                   'Current liabilities:\n'
#                   'Trade payables\n'
#                   '$\n'
#                   '93,307\n'
#                   '$\n'
#                   '68,377\n'
#                   'Accrued expenses\n'
#                   '678,364\n'
#                   '683,866\n'
#                   'Debt and capital lease obligations\n'
#                   '-\n'
#                   '603,229\n'
#                   'Accrued restructuring\n'
#                   '1,520\n'
#                   '17,120\n'
#                   'Income taxes payable\n'
#                   '6,165\n'
#                   '23,920\n'
#                   'Deferred revenue\n'
#                   '1,434,200\n'
#                   '1,097,923\n'
#                   'Total current liabilities\n'
#                   '2,213,556\n'
#                   '2,494,435\n'
#                   'Long-term liabilities:\n'
#                   'Debt and capital lease obligations\n'
#                   '1,907,231\n'
#                   '911,086\n'
#                   'Deferred revenue\n'
#                   '51,094\n'
#                   '57,401\n'
#                   'Accrued restructuring\n'
#                   '3,214\n'
#                   '5,194\n'
#                   'Income taxes payable\n'
#                   '256,129\n'
#                   '125,746\n'
#                   'Deferred income taxes\n'
#                   '208,209\n'
#                   '342,315\n'
#                   'Other liabilities\n'
#                   '85,459\n'
#                   '73,747\n'
#                   'Total liabilities\n'
#                   '4,724,892\n'
#                   '4,009,924\n'
#                   'Commitments and contingencies',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '796343',
#                'company': 'ADOBE SYSTEMS INC',
#                'filename': '796343_10K_2017_0000796343-18-000015.htm',
#                'filing_date': '2018-01-22',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1202',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/796343/000079634318000015/adbe10kfy17.htm',
#                'period_of_report': '2017-12-01',
#                'relevance_score': 0.9630982876,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/796343_10K_2017_0000796343-18-000015.json',
#                'state_location': 'CA'},
#   'page_content': 'INDEX TO CONSOLIDATED FINANCIAL STATEMENTS\n'
#                   'Page No.\n'
#                   'Consolidated Balance Sheets\n'
#                   'Consolidated Statements of Income\n'
#                   'Consolidated Statements of Comprehensive Income\n'
#                   "Consolidated Statements of Stockholders' Equity\n"
#                   'Consolidated Statements of Cash Flows\n'
#                   'Notes to Consolidated Financial Statements\n'
#                   'Report of KPMG LLP, Independent Registered Public Accounting Firm\n'
#                   'All financial statement schedules have been omitted, since the required '
#                   'information is not applicable or is not present in amounts sufficient to '
#                   'require submission of the schedule, or because the information required is '
#                   'included in the Consolidated Financial Statements and Notes thereto.\n'
#                   'ADOBE SYSTEMS INCORPORATED\n'
#                   'CONSOLIDATED BALANCE SHEETS\n'
#                   '(In thousands, except par value)\n'
#                   'December 1,\n'
#                   'December 2,\n'
#                   'ASSETS\n'
#                   'Current assets:\n'
#                   'Cash and cash equivalents\n'
#                   '$\n'
#                   '2,306,072\n'
#                   '$\n'
#                   '1,011,315\n'
#                   'Short-term investments\n'
#                   '3,513,702\n'
#                   '3,749,985\n'
#                   'Trade receivables, net of allowances for doubtful accounts of $9,151 and '
#                   '$6,214, respectively\n'
#                   '1,217,968\n'
#                   '833,033\n'
#                   'Prepaid expenses and other current assets\n'
#                   '210,071\n'
#                   '245,441\n'
#                   'Total current assets\n'
#                   '7,247,813\n'
#                   '5,839,774\n'
#                   'Property and equipment, net\n'
#                   '936,976\n'
#                   '816,264\n'
#                   'Goodwill\n'
#                   '5,821,561\n'
#                   '5,406,474\n'
#                   'Purchased and other intangibles, net\n'
#                   '385,658\n'
#                   '414,405\n'
#                   'Investment in lease receivable\n'
#                   '-\n'
#                   '80,439\n'
#                   'Other assets\n'
#                   '143,548\n'
#                   '139,890\n'
#                   'Total assets\n'
#                   '$\n'
#                   '14,535,556\n'
#                   '$\n'
#                   '12,697,246\n'
#                   'LIABILITIES AND STOCKHOLDERS EQUITY\n'
#                   'Current liabilities:\n'
#                   'Trade payables\n'
#                   '$\n'
#                   '113,538\n'
#                   '$\n'
#                   '88,024\n'
#                   'Accrued expenses\n'
#                   '993,773\n'
#                   '739,630\n'
#                   'Income taxes payable\n'
#                   '14,196\n'
#                   '38,362\n'
#                   'Deferred revenue\n'
#                   '2,405,950\n'
#                   '1,945,619\n'
#                   'Total current liabilities\n'
#                   '3,527,457\n'
#                   '2,811,635\n'
#                   'Long-term liabilities:\n'
#                   'Debt and capital lease obligations\n'
#                   '1,881,421\n'
#                   '1,892,200\n'
#                   'Deferred revenue\n'
#                   '88,592\n'
#                   '69,131\n'
#                   'Income taxes payable\n'
#                   '173,088\n'
#                   '184,381\n'
#                   'Deferred income taxes\n'
#                   '279,941\n'
#                   '217,660\n'
#                   'Other liabilities\n'
#                   '125,188\n'
#                   '97,404\n'
#                   'Total liabilities\n'
#                   '6,075,687\n'
#                   '5,272,411\n'
#                   'Commitments and contingencies\n'
#                   'Stockholders equity:\n'
#                   'Preferred stock, $0.0001 par value; 2,000 shares authorized; none issued\n'
#                   '-\n'
#                   '-',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 0
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 0
# Progress saved.
#
# Row Index: 9
# Question: What is the ADOBE SYSTEMS INC's total outstanding debt, how is the debt structured, and what are the interest rates?
# Response: The answer is in the context. According to the document, ADobe Systems Inc.'s total outstanding debt as of November 27, 2015 was $1,907,231,000, and as of November 28, 2014 it was $1,511,046,000. The debt is structured as follows:
# As of November 27, 2015, the fair value of the interest rate swap was $19,821, and as of November 28, 2014 it was $14,268. The adjusted carrying value of the notes was $1,907,231,000 as of November 27, 2015, and $1,511,046,000 as of November 28, 2014. The capital lease obligations were $3,269 as of November 27, 2015, and $nil as of November 28, 2014.
# The interest rates on the debt are not specified in the provided document.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '796343',
#                'company': 'ADOBE SYSTEMS INC',
#                'filename': '796343_10K_2016_0000796343-17-000031.htm',
#                'filing_date': '2017-01-20',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1202',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/796343/000079634317000031/adbe10kfy16.htm',
#                'period_of_report': '2016-12-02',
#                'relevance_score': 0.9652020931,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/796343_10K_2016_0000796343-17-000031.json',
#                'state_location': 'CA'},
#   'page_content': 'All legal costs associated with litigation are expensed as incurred. Litigation '
#                   'is inherently unpredictable. However, we believe that we have valid defenses '
#                   'with respect to the legal matters pending against us. It is possible, '
#                   'nevertheless, that our consolidated financial position, cash flows or results '
#                   'of operations could be negatively affected by an unfavorable resolution of one '
#                   'or more of such proceedings, claims or investigations.\n'
#                   'In connection with our anti-piracy efforts, conducted both internally and '
#                   'through organizations such as the Business Software Alliance, from time to time '
#                   'we undertake litigation against alleged copyright infringers. Such lawsuits may '
#                   'lead to counter-claims alleging improper use of litigation or violation of '
#                   'other laws. We believe we have valid defenses with respect to such '
#                   'counter-claims; however, it is possible that our consolidated financial '
#                   'position, cash flows or results of operations could be negatively affected in '
#                   'any particular period by the resolution of one or more of these '
#                   'counter-claims.\n'
#                   'ADOBE SYSTEMS INCORPORATED\n'
#                   'NOTES TO CONSOLIDATED FINANCIAL STATEMENTS (Continued)\n'
#                   'NOTE 15. DEBT\n'
#                   'Our long-term debt as of December 2, 2016 and November 27, 2015 consisted of '
#                   'the following (in thousands):\n'
#                   'Notes\n'
#                   '$\n'
#                   '1,888,951\n'
#                   '$\n'
#                   '1,887,410\n'
#                   'Fair value of interest rate swap\n'
#                   '13,117\n'
#                   '19,821\n'
#                   'Adjusted carrying value of Notes\n'
#                   '1,902,068\n'
#                   '1,907,231\n'
#                   'Senior Notes',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '796343',
#                'company': 'ADOBE SYSTEMS INC',
#                'filename': '796343_10K_2015_0000796343-16-000224.htm',
#                'filing_date': '2016-01-19',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1130',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/796343/000079634316000224/adbe10kfy15.htm',
#                'period_of_report': '2015-11-27',
#                'relevance_score': 0.9626252651,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/796343_10K_2015_0000796343-16-000224.json',
#                'state_location': 'CA'},
#   'page_content': 'All legal costs associated with litigation are expensed as incurred. Litigation '
#                   'is inherently unpredictable. However, we believe that we have valid defenses '
#                   'with respect to the legal matters pending against us. It is possible, '
#                   'nevertheless, that our consolidated financial position, cash flows or results '
#                   'of operations could be negatively affected by an unfavorable resolution of one '
#                   'or more of such proceedings, claims or investigations.\n'
#                   'In connection with our anti-piracy efforts, conducted both internally and '
#                   'through organizations such as the Business Software Alliance, from time to time '
#                   'we undertake litigation against alleged copyright infringers. Such lawsuits may '
#                   'lead to counter-claims alleging improper use of litigation or violation of '
#                   'other laws. We believe we have valid defenses with respect to such '
#                   'counter-claims; however, it is possible that our consolidated financial '
#                   'position, cash flows or results of operations could be negatively affected in '
#                   'any particular period by the resolution of one or more of these '
#                   'counter-claims.\n'
#                   'ADOBE SYSTEMS INCORPORATED\n'
#                   'NOTES TO CONSOLIDATED FINANCIAL STATEMENTS (Continued)\n'
#                   'NOTE 16. DEBT\n'
#                   'Our debt as of November 27, 2015 and November 28, 2014 consisted of the '
# ...
#                   'Other assets\n'
#                   '149,758\n'
#                   '159,832\n'
#                   'Total assets\n'
#                   '$\n'
#                   '12,707,114\n'
#                   '$\n'
#                   '11,726,472\n'
#                   'LIABILITIES AND STOCKHOLDERS EQUITY\n'
#                   'Current liabilities:\n'
#                   'Trade payables\n'
#                   '$\n'
#                   '88,024\n'
#                   '$\n'
#                   '93,307\n'
#                   'Accrued expenses\n'
#                   '739,630\n'
#                   '679,884\n'
#                   'Income taxes payable\n'
#                   '38,362\n'
#                   '6,165\n'
#                   'Deferred revenue\n'
#                   '1,945,619\n'
#                   '1,434,200\n'
#                   'Total current liabilities\n'
#                   '2,811,635\n'
#                   '2,213,556\n'
#                   'Long-term liabilities:\n'
#                   'Debt and capital lease obligations\n'
#                   '1,902,068\n'
#                   '1,907,231\n'
#                   'Deferred revenue\n'
#                   '69,131\n'
#                   '51,094\n'
#                   'Income taxes payable\n'
#                   '184,381\n'
#                   '256,129\n'
#                   'Deferred income taxes\n'
#                   '217,660\n'
#                   '208,209\n'
#                   'Other liabilities\n'
#                   '97,404\n'
#                   '88,673\n'
#                   'Total liabilities\n'
#                   '5,282,279\n'
#                   '4,724,892\n'
#                   'Commitments and contingencies\n'
#                   'Stockholders equity:\n'
#                   'Preferred stock, $0.0001 par value; 2,000 shares authorized; none issued\n'
#                   '-\n'
#                   '-',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 0
# Is the response correct? (1 for True, 0 for False): 0
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 33
# Question: How does the ADOBE SYSTEMS INC leverage technology for its operations and are there ongoing technological advancements?
# Response: The answer is not in the provided context. The document only discusses Adobe's business segments, market opportunity, and revenue recognition policies without mentioning any specific technological advancements or leveraging of technology for operations.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '796343',
#                'company': 'ADOBE SYSTEMS INC',
#                'filename': '796343_10K_2017_0000796343-18-000015.htm',
#                'filing_date': '2018-01-22',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1202',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/796343/000079634318000015/adbe10kfy17.htm',
#                'period_of_report': '2017-12-01',
#                'relevance_score': 0.9686425328,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/796343_10K_2017_0000796343-18-000015.json',
#                'state_location': 'CA'},
#   'page_content': 'SEGMENTS\n'
#                   'Effective in fiscal 2018, our business is organized into three reportable '
#                   'segments: Digital Media, Digital Experience (formerly Digital Marketing), and '
#                   'Publishing (formerly Print and Publishing). These segments provide Adobes '
#                   'senior management with a comprehensive financial view of our key businesses. '
#                   'Our segments are aligned around our two strategic growth opportunities '
#                   'described above, placing our Publishing business in a third segment that '
#                   'contains some of our mature products and solutions.\n'
#                   'This overview provides an explanation of our markets and a discussion of '
#                   'strategic opportunities in fiscal 2018 and beyond for each of our segments. See '
#                   'Results of Operations within Part II, Item 7 titled Managements Discussion and '
#                   'Analysis of Financial Condition and Results of Operations and Note 17 of our '
#                   'Notes to Consolidated Financial Statements for further segment information.\n'
#                   'MARKET OVERVIEW\n'
#                   'Digital Media\n'
#                   'Digital Media Opportunity\n'
#                   'Recent technology trends in digital communications continue to provide a '
#                   'significant market opportunity for Adobe in digital media. In todays world '
#                   'where the velocity of creation and consumption of digital content is ever '
#                   'increasing, customers are looking for a way to meet demand with engaging online '
#                   'experiences. Adobe is in a strong position to capitalize on this opportunity by '
#                   'driving modernization and innovation that will accelerate the creative process '
#                   'across all platforms and devices, deepen engagement with communities, and '
#                   'accelerate long-term revenue growth by focusing on cloud-based offerings, which '
#                   'are licensed on a subscription basis.',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '796343',
#                'company': 'ADOBE SYSTEMS INC',
#                'filename': '796343_10K_2015_0000796343-16-000224.htm',
#                'filing_date': '2016-01-19',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1130',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/796343/000079634316000224/adbe10kfy15.htm',
#                'period_of_report': '2015-11-27',
#                'relevance_score': 0.9683266282,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/796343_10K_2015_0000796343-16-000224.json',
#                'state_location': 'CA'},
#   'page_content': 'We offer rebates to our distributors, resellers and/or end user customers. The '
#                   'amount of revenue that is reduced for distributor and reseller rebates is based '
#                   'on actual performance against objectives set forth by us for a particular '
#                   'reporting period (volume, timely reporting, etc.). If mail-in or other '
#                   'promotional rebates are offered, the amount of revenue reduced is based on the '
#                   'dollar amount of the rebate, taking into consideration an estimated redemption '
#                   'rate calculated using historical trends.\n'
#                   'From time to time, we may offer price protection to our distributors that allow '
#                   'for the right to a credit if we permanently reduce the price of a software '
#                   'product. The amount of revenue that is reduced for price protection is '
#                   'calculated as the difference between the old and new price of a software '
#                   'product on inventory held by the distributor immediately prior to the effective '
#                   'date of the decrease.\n'
#                   'Although our subscription contracts are generally non-cancellable, a limited '
#                   'number of customers have the right to cancel their contracts by providing prior '
#                   'written notice to us of their intent to cancel the remainder of the contract '
#                   'term. In the event a customer cancels its contract, they are not entitled to a '
#                   'refund for prior services we have provided to them.\n'
#                   'On a quarterly basis, the amount of revenue that is reserved for future returns '
#                   'is calculated based on our historical trends and data specific to each '
#                   'reporting period. We review the actual returns evidenced in prior quarters as a '
#                   'percent of revenue to determine a historical returns rate. We then apply the '
#                   'historical rate to the current period revenue as a basis for estimating future '
#                   'returns. When necessary, we also provide a specific returns reserve for product '
#                   'in the distribution channel in excess of estimated requirements. This estimate '
#                   'can be affected by the amount of a particular product in the channel, the rate '
#                   'of sell-through, product plans and other factors.\n'
#                   'ADOBE SYSTEMS INCORPORATED',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 0
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 0
# Progress saved.
#
# Row Index: 34
# Question: What does the ADOBE SYSTEMS INC foresee in terms of future growth and challenges and are there any strategic plans outlined for the upcoming years?
# Response: The answer is not in the provided context. The document provides information about Adobe Systems Incorporated's business, financial performance, and operations for the fiscal year ended December 1, 2017, but it does not contain any information about the company's future growth and challenges or strategic plans beyond that year.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '796343',
#                'company': 'ADOBE SYSTEMS INC',
#                'filename': '796343_10K_2017_0000796343-18-000015.htm',
#                'filing_date': '2018-01-22',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1202',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/796343/000079634318000015/adbe10kfy17.htm',
#                'period_of_report': '2017-12-01',
#                'relevance_score': 0.966851294,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/796343_10K_2017_0000796343-18-000015.json',
#                'state_location': 'CA'},
#   'page_content': 'ITEM 1. BUSINESS\n'
#                   'Founded in 1982, Adobe Systems Incorporated is one of the largest and most '
#                   'diversified software companies in the world. We offer a line of products and '
#                   'services used by creative professionals, marketers, knowledge workers, '
#                   'application developers, enterprises and consumers for creating, managing, '
#                   'delivering, measuring, optimizing and engaging with compelling content and '
#                   'experiences across personal computers, devices and media. We market our '
#                   'products and services directly to enterprise customers through our sales force '
#                   'and certain local field offices. We license our products to end users through '
#                   'app stores and our own website at www.adobe.com. We offer many of our products '
#                   'via a Software-as-a-Service (SaaS) model or a managed services model (both of '
#                   'which are referred to as hosted or cloud-based) as well as through term '
#                   'subscription and pay-per-use models. We also distribute certain products and '
#                   'services through a network of distributors, value-added resellers (VARs), '
#                   'systems integrators (SIs), independent software vendors (ISVs), retailers, '
#                   'software developers and original equipment manufacturers (OEMs). In addition, '
#                   'we license our technology to hardware manufacturers, software developers and '
#                   'service providers for use in their products and solutions. Our products run on '
#                   'personal and server-based computers, as well as on smartphones, tablets and '
#                   'other devices, depending on the product. We have operations in the Americas, '
#                   'Europe, Middle East and Africa (EMEA) and Asia-Pacific (APAC). See Note 17 of '
#                   'our Notes to Consolidated Financial Statements for further geographical '
#                   'information.',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '796343',
#                'company': 'ADOBE SYSTEMS INC',
#                'filename': '796343_10K_2015_0000796343-16-000224.htm',
#                'filing_date': '2016-01-19',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1130',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/796343/000079634316000224/adbe10kfy15.htm',
#                'period_of_report': '2015-11-27',
#                'relevance_score': 0.9649571776,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/796343_10K_2015_0000796343-16-000224.json',
#                'state_location': 'CA'},
#   'page_content': 'We offer rebates to our distributors, resellers and/or end user customers. The '
#                   'amount of revenue that is reduced for distributor and reseller rebates is based '
#                   'on actual performance against objectives set forth by us for a particular '
#                   'reporting period (volume, timely reporting, etc.). If mail-in or other '
#                   'promotional rebates are offered, the amount of revenue reduced is based on the '
#                   'dollar amount of the rebate, taking into consideration an estimated redemption '
#                   'rate calculated using historical trends.\n'
#                   'From time to time, we may offer price protection to our distributors that allow '
#                   'for the right to a credit if we permanently reduce the price of a software '
#                   'product. The amount of revenue that is reduced for price protection is '
#                   'calculated as the difference between the old and new price of a software '
#                   'product on inventory held by the distributor immediately prior to the effective '
#                   'date of the decrease.\n'
#                   'Although our subscription contracts are generally non-cancellable, a limited '
#                   'number of customers have the right to cancel their contracts by providing prior '
#                   'written notice to us of their intent to cancel the remainder of the contract '
#                   'term. In the event a customer cancels its contract, they are not entitled to a '
#                   'refund for prior services we have provided to them.\n'
#                   'On a quarterly basis, the amount of revenue that is reserved for future returns '
#                   'is calculated based on our historical trends and data specific to each '
#                   'reporting period. We review the actual returns evidenced in prior quarters as a '
#                   'percent of revenue to determine a historical returns rate. We then apply the '
#                   'historical rate to the current period revenue as a basis for estimating future '
#                   'returns. When necessary, we also provide a specific returns reserve for product '
#                   'in the distribution channel in excess of estimated requirements. This estimate '
#                   'can be affected by the amount of a particular product in the channel, the rate '
#                   'of sell-through, product plans and other factors.\n'
#                   'ADOBE SYSTEMS INCORPORATED',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 0
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 0
# Progress saved.
#
# Evaluation results saved to 'evaluation_results_ADOBE.json'.

# %%
eval = pd.read_json('/content/evaluation_results_ADOBE.json')
eval.mean()[1:]
# Out:
# The context is relevant to the company     1.000000
# The context is relevant to the question    0.485714
# The response is correct                    0.742857
# The response answers the question          0.571429
# dtype: float64
