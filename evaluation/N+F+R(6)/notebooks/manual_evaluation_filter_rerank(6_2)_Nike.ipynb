# %%
import pandas as pd
import json
from pprint import pprint

# Load your dataframe
# Replace 'your_data.csv' with the actual path to your data file
df1 = pd.read_json('/content/results_NIKE_rerank_6-2_filter.json')

# Initialize dictionary to store results
results = {'index': [],
           'The context is relevant to the company': [],
           'The context is relevant to the question': [],
           'The response is correct': [],
           'The response answers the question': []}

# Check if there's a previous evaluation progress saved
try:
    with open('evaluation_results_Nike.json', 'r') as f:
        previous_results = json.load(f)
    start_index = max(previous_results['index']) + 1
    results = previous_results
    print("Resuming evaluation from the last unanswered question.")
except (FileNotFoundError, ValueError, KeyError):
    start_index = 0
    print("Starting evaluation from the beginning.")

# Function to get valid user input (1 or 0)
def get_valid_input(message):
    while True:
        try:
            user_input = int(input(message))
            if user_input not in (0, 1):
                raise ValueError("Input must be 0 or 1.")
            return user_input
        except ValueError:
            print("Invalid input. Please enter 0 or 1.")

# Iterate over each row in the dataframe
for idx, row in df1.iloc[start_index:].iterrows():
    print("\nRow Index:", idx)
    print("Question:", row['question'])
    print("Response:", row['response'])
    print("Context:")
    pprint(row['context'], width=100)

    # Ask questions and get user input
    context_relevant_to_company = get_valid_input("Is the context relevant to the company? (1 for True, 0 for False): ")
    context_relevant_to_question = get_valid_input("Is the context relevant to the question? (1 for True, 0 for False): ")
    response_correct = get_valid_input("Is the response correct? (1 for True, 0 for False): ")
    response_answers_question = get_valid_input("Does the response answer the question? (1 for True, 0 for False): ")

    # Append results to dictionary
    results['index'].append(idx)
    results['The context is relevant to the company'].append(context_relevant_to_company)
    results['The context is relevant to the question'].append(context_relevant_to_question)
    results['The response is correct'].append(response_correct)
    results['The response answers the question'].append(response_answers_question)

    # Convert results dictionary to JSON and save to a file after each row
    json_result = json.dumps(results, indent=4)
    with open('evaluation_results_Nike.json', 'w') as f:
        f.write(json_result)

    print("Progress saved.")

print("\nEvaluation results saved to 'evaluation_results_Nike.json'.")
# Out:
# Starting evaluation from the beginning.
#
# Row Index: 0
# Question: What is the total revenue generated by the NIKE and how has the revenue changed over the past few years?
# Response: According to the document, the total revenue generated by NIKE was $44,538 million in 2021, $37,403 million in 2020, and $39,117 million in 2019. There is no context provided beyond this information, so the answer is not in the context.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '320187',
#                'company': 'NIKE, Inc.',
#                'filename': '320187_10K_2021_0000320187-21-000028.htm',
#                'filing_date': '2021-07-20',
#                'filing_type': '10-K',
#                'fiscal_year_end': '0531',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/320187/000032018721000028/nke-20210531.htm',
#                'period_of_report': '2021-05-31',
#                'relevance_score': 0.9559406638000001,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/320187_10K_2021_0000320187-21-000028.json',
#                'state_location': 'OR'},
#   'page_content': 'Asia Pacific & Latin America(1)\n'
#                   '304 296\n'
#                   'Global Brand Divisions 780 830\n'
#                   'Total NIKE Brand 2,971 2,870\n'
#                   'Converse 63 80\n'
#                   'Corporate 1,870 1,916\n'
#                   'TOTAL PROPERTY, PLANT AND EQUIPMENT, NET $ 4,904 $ 4,866\n'
#                   '(1)Excludes assets held-for-sale as of May 31, 2021. See Note 20 - Acquisitions '
#                   'and Divestitures for additional information.\n'
#                   'REVENUES AND LONG-LIVED ASSETS BY GEOGRAPHIC AREA\n'
#                   'After allocation of revenues for Global Brand Divisions, Converse and Corporate '
#                   'to geographical areas based on the location where the sales originated, '
#                   'revenues by geographical area are essentially the same as reported above for '
#                   'the NIKE Brand operating segments with the exception of the United States. '
#                   'Revenues derived in the United States were $17,363 million, $14,625 million and '
#                   '$16,091 million for the fiscal years ended May 31, 2021, 2020 and 2019, '
#                   'respectively.\n'
#                   "The Company's largest concentrations of long-lived assets primarily consist of "
#                   "the Company's corporate headquarters, retail locations and distribution "
#                   'facilities in the United States and China, as well as distribution facilities '
#                   'in Belgium. Long-lived assets attributable to operations in these countries, '
#                   'which primarily consists of property, plant and equipment, net and operating '
#                   'lease ROU assets, net, were as follows:\n'
#                   'MAY 31,\n'
#                   '(Dollars in millions)\n'
#                   '2021 2020\n'
#                   'United States $ 4,927 $ 5,114\n'
#                   'Belgium 676 606\n'
#                   'China 518 457\n'
#                   '2021 FORM 10-K 90\n'
#                   'NOTE 18 - COMMITMENTS AND CONTINGENCIES\n'
#                   'As of May 31, 2021 and 2020, the Company had bank guarantees and letters of '
#                   'credit outstanding totaling $275 million and $239 million, respectively, issued '
#                   'primarily for real estate agreements, self-insurance programs and other general '
#                   'business obligations.',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '320187',
#                'company': 'NIKE, Inc.',
#                'filename': '320187_10K_2021_0000320187-21-000028.htm',
#                'filing_date': '2021-07-20',
#                'filing_type': '10-K',
#                'fiscal_year_end': '0531',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/320187/000032018721000028/nke-20210531.htm',
#                'period_of_report': '2021-05-31',
#                'relevance_score': 0.9503466487000001,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/320187_10K_2021_0000320187-21-000028.json',
#                'state_location': 'OR'},
#   'page_content': 'As part of our centrally managed foreign exchange risk management program, '
#                   'standard foreign currency exchange rates are assigned twice per year to each '
#                   'NIKE Brand entity in our geographic operating segments and Converse. These '
#                   'rates are set approximately nine and twelve months in advance of the future '
#                   'selling seasons to which they relate (specifically, for each currency, one '
#                   'standard rate applies to the fall and holiday selling seasons and one standard '
#                   'rate applies to the spring and summer selling seasons) based on average market '
#                   'spot rates in the calendar month preceding the date they are established. '
#                   'Inventories and Cost of sales for geographic operating segments and Converse '
#                   'reflect the use of these standard rates to record non-functional currency '
#                   "product purchases into the entity's functional currency. Differences between "
#                   'assigned standard foreign currency exchange rates and actual market rates are '
#                   'included in Corporate, together with foreign currency hedge gains and losses '
#                   'generated from our centrally managed foreign exchange risk management program '
#                   'and other conversion gains and losses.\n'
#                   '2021 FORM 10-K 35\n'
#                   'The breakdown of Revenues is as follows:\n'
#                   '(Dollars in millions)\n'
#                   'FISCAL 2021 FISCAL 2020 % CHANGE % CHANGE EXCLUDING CURRENCY CHANGES(1)\n'
#                   'FISCAL 2019 % CHANGE % CHANGE EXCLUDING CURRENCY CHANGES(1)\n'
#                   'North America $ 17,179 $ 14,484 19 % 19 % $ 15,902 -9 % -9 %\n'
#                   'Europe, Middle East & Africa 11,456 9,347 23 % 17 % 9,812 -5 % -1 %\n'
#                   'Greater China 8,290 6,679 24 % 19 % 6,208 8 % 11 %\n'
#                   'Asia Pacific & Latin America(2)\n'
#                   '5,343 5,028 6 % 8 % 5,254 -4 % 1 %\n'
#                   'Global Brand Divisions(3)\n'
#                   '25 30 -17 % -17 % 42 -29 % -26 %\n'
#                   'TOTAL NIKE BRAND 42,293 35,568 19 % 17 % 37,218 -4 % -2 %\n'
#                   'Converse 2,205 1,846 19 % 16 % 1,906 -3 % -1 %\n'
#                   'Corporate(4)\n'
#                   '40 (11) - - (7) - -\n'
#                   'TOTAL NIKE, INC. REVENUES $ 44,538 $ 37,403 19 % 17 % $ 39,117 -4 % -2 %\n'
#                   '(1) The percent change excluding currency changes represents a non-GAAP '
#                   'financial measure. See "Use of Non-GAAP Financial Measures" for further '
#                   'information.',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 1
# Question: What is the NIKE's cost of goods sold (COGS) and how does the COGS compare to the total revenue?
# Response: According to the provided document, NIKE's total revenue for fiscal year 2021 was $35.77 billion, while their cost of goods sold (COGS) was $25.898 billion, which represents about 71% of their total revenue.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '320187',
#                'company': 'NIKE, Inc.',
#                'filename': '320187_10K_2021_0000320187-21-000028.htm',
#                'filing_date': '2021-07-20',
#                'filing_type': '10-K',
#                'fiscal_year_end': '0531',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/320187/000032018721000028/nke-20210531.htm',
#                'period_of_report': '2021-05-31',
#                'relevance_score': 0.9614701867000001,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/320187_10K_2021_0000320187-21-000028.json',
#                'state_location': 'OR'},
#   'page_content': 'Sportswear 15,053 12,285 23 % 20 % 12,442 -1 % 1 %\n'
#                   'Others(5)\n'
#                   '5,738 5,113 12 % 11 % 5,854 -13 % -10 %\n'
#                   'TOTAL NIKE BRAND WHOLESALE EQUIVALENT REVENUES $ 35,770 $ 30,608 17 % 15 % $ '
#                   '32,550 -6 % -4 %\n'
#                   '(1)The percent change excluding currency changes and the presentation of '
#                   'wholesale equivalent revenues represent non-GAAP financial measures. See "Use '
#                   'of Non-GAAP Financial Measures" for further information.\n'
#                   '(2)Global Brand Divisions revenues include NIKE Brand licensing and other '
#                   'miscellaneous revenues that are not part of a geographic operating segment.\n'
#                   '(3)Corporate revenues primarily consist of foreign currency hedge gains and '
#                   'losses related to revenues generated by entities within the NIKE Brand '
#                   'geographic operating segments and Converse, but managed through our central '
#                   'foreign exchange risk management program.\n'
#                   '(4)Others include all unisex products, equipment and other products not '
#                   "allocated to Men's, Women's and NIKE Kids', as well as certain adjustments that "
#                   'are not allocated to products designated by gender or age.\n'
#                   '(5)Others include all other categories and certain adjustments that are not '
#                   'allocated at the category level.\n'
#                   '2021 FORM 10-K 32\n'
#                   'FISCAL 2021 NIKE BRAND REVENUE HIGHLIGHTS\n'
#                   'The following tables present NIKE Brand revenues disaggregated by reportable '
#                   'operating segment, distribution channel and major product line:\n'
#                   'FISCAL 2021 COMPARED TO FISCAL 2020\n'
#                   'On a currency-neutral basis, NIKE, Inc. Revenues increased 17% for fiscal 2021, '
#                   'driven by growth in both the NIKE Brand and Converse. Higher revenues in North '
#                   'America contributed approximately 7 percentage points to NIKE, Inc. Revenues, '
#                   'with EMEA and Greater China each contributing approximately 4 percentage points '
#                   'of growth and APLA and Converse each contributing approximately 1 percentage '
#                   'point of growth.',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '320187',
#                'company': 'NIKE, Inc.',
#                'filename': '320187_10K_2021_0000320187-21-000028.htm',
#                'filing_date': '2021-07-20',
#                'filing_type': '10-K',
#                'fiscal_year_end': '0531',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/320187/000032018721000028/nke-20210531.htm',
#                'period_of_report': '2021-05-31',
#                'relevance_score': 0.9552987218000001,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/320187_10K_2021_0000320187-21-000028.json',
#                'state_location': 'OR'},
#   'page_content': 'NIKE, Inc. Revenues:\n'
#                   'NIKE Brand Revenues by:\n'
#                   'Footwear $ 28,021 $ 23,305 20 % 18 % $ 24,222 -4 % -2 %\n'
#                   'Apparel 12,865 10,953 17 % 15 % 11,550 -5 % -3 %\n'
#                   'Equipment 1,382 1,280 8 % 7 % 1,404 -9 % -6 %\n'
#                   'Global Brand Divisions(2)\n'
#                   '25 30 -17 % -17 % 42 -29 % -26 %\n'
#                   'Total NIKE Brand Revenues 42,293 35,568 19 % 17 % 37,218 -4 % -2 %\n'
#                   'Converse 2,205 1,846 19 % 16 % 1,906 -3 % -1 %\n'
#                   'Corporate(3)\n'
#                   '40 (11) - - (7) - -\n'
#                   'TOTAL NIKE, INC. REVENUES $ 44,538 $ 37,403 19 % 17 % $ 39,117 -4 % -2 %\n'
#                   'Supplemental NIKE Brand Revenues Details:\n'
#                   'NIKE Brand Revenues by:\n'
#                   'Sales to Wholesale Customers $ 25,898 $ 23,156 12 % 10 % $ 25,423 -9 % -7 %\n'
#                   'Sales through NIKE Direct 16,370 12,382 32 % 30 % 11,753 5 % 8 %\n'
#                   'Global Brand Divisions(2)\n'
#                   '25 30 -17 % -17 % 42 -29 % -26 %\n'
#                   'TOTAL NIKE BRAND REVENUES $ 42,293 $ 35,568 19 % 17 % $ 37,218 -4 % -2 %\n'
#                   'NIKE Brand Revenues on a Wholesale Equivalent Basis:(1)\n'
#                   'Sales to Wholesale Customers $ 25,898 $ 23,156 12 % 10 % $ 25,423 -9 % -7 %\n'
#                   'Sales from our Wholesale Operations to NIKE Direct Operations 9,872 7,452 32 % '
#                   '30 % 7,127 5 % 7 %\n'
#                   'TOTAL NIKE BRAND WHOLESALE EQUIVALENT REVENUES $ 35,770 $ 30,608 17 % 15 % $ '
#                   '32,550 -6 % -4 %\n'
#                   'NIKE Brand Wholesale Equivalent Revenues by:(1)\n'
#                   "Men's $ 18,883 $ 16,694 13 % 11 % $ 17,737 -6 % -4 %\n"
#                   "Women's 8,555 6,999 22 % 20 % 7,380 -5 % -3 %\n"
#                   "NIKE Kids' 5,884 5,033 17 % 15 % 5,283 -5 % -3 %\n"
#                   'Others(4)\n'
#                   '2,448 1,882 30 % 26 % 2,150 -12 % -10 %\n'
#                   'TOTAL NIKE BRAND WHOLESALE EQUIVALENT REVENUES $ 35,770 $ 30,608 17 % 15 % $ '
#                   '32,550 -6 % -4 %\n'
#                   'NIKE Brand Wholesale Equivalent Revenues by:(1)\n'
#                   'Running $ 3,987 $ 3,830 4 % 3 % $ 4,488 -15 % -12 %\n'
#                   'NIKE Basketball 1,692 1,508 12 % 10 % 1,597 -6 % -4 %\n'
#                   'Jordan Brand 4,711 3,609 31 % 28 % 3,138 15 % 16 %\n'
#                   'Football (Soccer) 1,682 1,575 7 % 4 % 1,894 -17 % -14 %\n'
#                   'Training 2,907 2,688 8 % 7 % 3,137 -14 % -13 %\n'
#                   'Sportswear 15,053 12,285 23 % 20 % 12,442 -1 % 1 %\n'
#                   'Others(5)\n'
#                   '5,738 5,113 12 % 11 % 5,854 -13 % -10 %\n'
#                   'TOTAL NIKE BRAND WHOLESALE EQUIVALENT REVENUES $ 35,770 $ 30,608 17 % 15 % $ '
#                   '32,550 -6 % -4 %',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 0
# Is the response correct? (1 for True, 0 for False): 0
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 2
# Question: What is the NIKE's gross profit margin, and how has it evolved?
# Response: The answer is in the context. According to the provided information, NIKE's gross profit margin for fiscal 2021 was 44.8%, which represents a 140 basis point increase compared to the previous year. This means that for every dollar of revenue, NIKE generated 44.8 cents of gross profit, up from 43.4% in the previous year.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '320187',
#                'company': 'NIKE, Inc.',
#                'filename': '320187_10K_2021_0000320187-21-000028.htm',
#                'filing_date': '2021-07-20',
#                'filing_type': '10-K',
#                'fiscal_year_end': '0531',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/320187/000032018721000028/nke-20210531.htm',
#                'period_of_report': '2021-05-31',
#                'relevance_score': 0.9645162225,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/320187_10K_2021_0000320187-21-000028.json',
#                'state_location': 'OR'},
#   'page_content': 'Income (loss) before income taxes increased 131% for fiscal 2021, primarily due '
#                   'to higher revenues, gross margin expansion and selling and administrative '
#                   'expense leverage. NIKE, Inc. gross margin increased 140 basis points primarily '
#                   'due to annualizing the impacts of COVID-19 including lower factory cancellation '
#                   'charges, lower inventory obsolescence reserves as well as the favorable rate '
#                   'impact of fixed supply chain costs on a higher volume of wholesale shipments. '
#                   'The increase in gross margin also reflects higher full-price product margins '
#                   'across wholesale and NIKE Direct. Selling and administrative expense decreased '
#                   'due to lower Demand creation expense, partially offset by higher Operating '
#                   'overhead expense. Demand creation expense decreased primarily due to lower '
#                   'marketing and advertising expenses for our brand events and retail operations, '
#                   'as well as lower sports marketing expenses as sporting events were postponed '
#                   'due to COVID-19. These decreases were partially offset by higher digital '
#                   'marketing investments. Operating overhead expense increased primarily due to an '
#                   'increase in strategic technology investments, higher NIKE Direct variable costs '
#                   'and $255 million in restructuring-related costs, partially offset by lower bad '
#                   'debt expense and travel and related expenses. ROIC as of May 31, 2021, was '
#                   '48.8% compared to 21.5% as of May 31, 2020. ROIC is considered a non-GAAP '
#                   'financial measure, see "Use of Non-GAAP Financial Measures" for further '
#                   'information.',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '320187',
#                'company': 'NIKE, Inc.',
#                'filename': '320187_10K_2021_0000320187-21-000028.htm',
#                'filing_date': '2021-07-20',
#                'filing_type': '10-K',
#                'fiscal_year_end': '0531',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/320187/000032018721000028/nke-20210531.htm',
#                'period_of_report': '2021-05-31',
#                'relevance_score': 0.9577530026000001,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/320187_10K_2021_0000320187-21-000028.json',
#                'state_location': 'OR'},
#   'page_content': '2021 FORM 10-K 33\n'
#                   'GROSS MARGIN\n'
#                   'FISCAL 2021 COMPARED TO FISCAL 2020\n'
#                   'For fiscal 2021, our consolidated gross profit increased 23% to $19,962 million '
#                   'compared to $16,241 million for fiscal 2020, as the prior fiscal year was '
#                   'significantly impacted by lower shipments to our wholesale customers and store '
#                   'closures within our NIKE Direct operations due to COVID-19. Gross margin '
#                   'increased 140 basis points to 44.8% for fiscal 2021 compared to 43.4% for '
#                   'fiscal 2020 due to the following:\n'
#                   '*Wholesale equivalent\n'
#                   'Favorable NIKE Brand full-price product margins across both our wholesale and '
#                   'NIKE Direct businesses primarily reflect higher full-price ASP, net of '
#                   'discounts. Additionally, the favorable impact of growth in our higher margin '
#                   'NIKE Direct business, led by NIKE owned Digital, was more than offset by higher '
#                   'promotions in our factory stores during the first half of fiscal 2021 to reduce '
#                   'excess inventory as a result of COVID-19. Lower other costs are due to '
#                   'annualizing certain impacts of COVID-19 from fiscal 2020, including lower '
#                   'factory cancellation charges, lower inventory obsolescence reserves as well as '
#                   'the favorable rate impact of fixed supply chain costs on a higher volume of '
#                   'wholesale shipments.\n'
#                   'TOTAL SELLING AND ADMINISTRATIVE EXPENSE\n'
#                   '(Dollars in millions)\n'
#                   'FISCAL 2021 FISCAL 2020 % CHANGE FISCAL 2019 % CHANGE\n'
#                   'Demand creation expense(1)\n'
#                   '$ 3,114 $ 3,592 -13 % $ 3,753 -4 %\n'
#                   'Operating overhead expense 9,911 9,534 4 % 8,949 7 %\n'
#                   'Total selling and administrative expense $ 13,025 $ 13,126 -1 % $ 12,702 3 %\n'
#                   '% of revenues 29.2 % 35.1 % (590) bps 32.5 % 260 bps\n'
#                   '(1)Demand creation expense consists of advertising and promotion costs, '
#                   'including costs of endorsement contracts, complimentary product, television, '
#                   'digital and print advertising and media costs, brand events and retail brand '
#                   'presentation.\n'
#                   'FISCAL 2021 COMPARED TO FISCAL 2020',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 3
# Question: What are the NIKE's major operating expenses and how have these expenses changed over time?
# Response: Based on the provided document, NIKE's major operating expenses include:
# 1. Selling and administrative expenses: This category includes expenses related to marketing, advertising, and promotional activities, as well as general administrative costs. In fiscal 2021, selling and administrative expenses increased by 10% to $5.3 billion.
# 2. Research and development expenses: This category includes expenses related to designing, testing, and improving products. In fiscal 2021, research and development expenses increased by 11% to $1.1 billion.
# 3. Cost of sales: This category includes the cost of raw materials, labor, and manufacturing overhead for NIKE's products. In fiscal 2021, cost of sales increased by 6% to $3.7 billion.
# 4. Restructuring-related costs: This category includes expenses related to restructuring initiatives, such as severance and facility closures. In fiscal 2021, restructuring-related costs increased by 21% to $255 million.
# Overall, NIKE's major operating expenses have increased over time, particularly in selling and administrative expenses and research and development expenses. However, the growth rate of these expenses has slowed down in recent years, with a 10% increase in selling and administrative expenses in fiscal 2021 compared to a 19% increase in fiscal 2020.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '320187',
#                'company': 'NIKE, Inc.',
#                'filename': '320187_10K_2021_0000320187-21-000028.htm',
#                'filing_date': '2021-07-20',
#                'filing_type': '10-K',
#                'fiscal_year_end': '0531',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/320187/000032018721000028/nke-20210531.htm',
#                'period_of_report': '2021-05-31',
#                'relevance_score': 0.9540311694,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/320187_10K_2021_0000320187-21-000028.json',
#                'state_location': 'OR'},
#   'page_content': 'Income (loss) before income taxes increased 131% for fiscal 2021, primarily due '
#                   'to higher revenues, gross margin expansion and selling and administrative '
#                   'expense leverage. NIKE, Inc. gross margin increased 140 basis points primarily '
#                   'due to annualizing the impacts of COVID-19 including lower factory cancellation '
#                   'charges, lower inventory obsolescence reserves as well as the favorable rate '
#                   'impact of fixed supply chain costs on a higher volume of wholesale shipments. '
#                   'The increase in gross margin also reflects higher full-price product margins '
#                   'across wholesale and NIKE Direct. Selling and administrative expense decreased '
#                   'due to lower Demand creation expense, partially offset by higher Operating '
#                   'overhead expense. Demand creation expense decreased primarily due to lower '
#                   'marketing and advertising expenses for our brand events and retail operations, '
#                   'as well as lower sports marketing expenses as sporting events were postponed '
#                   'due to COVID-19. These decreases were partially offset by higher digital '
#                   'marketing investments. Operating overhead expense increased primarily due to an '
#                   'increase in strategic technology investments, higher NIKE Direct variable costs '
#                   'and $255 million in restructuring-related costs, partially offset by lower bad '
#                   'debt expense and travel and related expenses. ROIC as of May 31, 2021, was '
#                   '48.8% compared to 21.5% as of May 31, 2020. ROIC is considered a non-GAAP '
#                   'financial measure, see "Use of Non-GAAP Financial Measures" for further '
#                   'information.',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '320187',
#                'company': 'NIKE, Inc.',
#                'filename': '320187_10K_2021_0000320187-21-000028.htm',
#                'filing_date': '2021-07-20',
#                'filing_type': '10-K',
#                'fiscal_year_end': '0531',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/320187/000032018721000028/nke-20210531.htm',
#                'period_of_report': '2021-05-31',
#                'relevance_score': 0.9491647482000001,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/320187_10K_2021_0000320187-21-000028.json',
#                'state_location': 'OR'},
#   'page_content': 'Reported EBIT increased 30% as higher revenues and lower selling and '
#                   'administrative expense more than offset a decline in gross margin. Gross margin '
#                   'decreased approximately 200 basis points primarily due to unfavorable changes '
#                   'in standard foreign currency exchange rates and higher product costs. Selling '
#                   'and administrative expense decreased due to lower demand creation expense, '
#                   'partially offset by higher operating overhead expense. Demand creation expense '
#                   'decreased primarily due to lower advertising and marketing, as well as digital '
#                   'marketing expenses. Growth in operating overhead expense was driven by higher '
#                   'investments within our NIKE Direct operations.\n'
#                   '2021 FORM 10-K 39\n'
#                   'ASIA PACIFIC & LATIN AMERICA\n'
#                   '(Dollars in millions)\n'
#                   'FISCAL 2021 FISCAL 2020 % CHANGE % CHANGE EXCLUDING CURRENCY CHANGES FISCAL '
#                   '2019 % CHANGE % CHANGE EXCLUDING CURRENCY CHANGES\n'
#                   'Revenues by:\n'
#                   'Footwear $ 3,659 $ 3,449 6 % 8 % $ 3,622 -5 % 0 %\n'
#                   'Apparel 1,494 1,365 9 % 10 % 1,395 -2 % 3 %\n'
#                   'Equipment 190 214 -11 % -9 % 237 -10 % -4 %\n'
#                   'TOTAL REVENUES $ 5,343 $ 5,028 6 % 8 % $ 5,254 -4 % 1 %\n'
#                   'Revenues by:\n'
#                   'Sales to Wholesale Customers $ 3,387 $ 3,408 -1 % 2 % $ 3,746 -9 % -4 %\n'
#                   'Sales through NIKE Direct 1,956 1,620 21 % 22 % 1,508 7 % 12 %\n'
#                   'TOTAL REVENUES $ 5,343 $ 5,028 6 % 8 % $ 5,254 -4 % 1 %\n'
#                   'EARNINGS BEFORE INTEREST AND TAXES $ 1,530 $ 1,184 29 % $ 1,323 -11 %\n'
#                   'As discussed previously, our NIKE Brand business in Brazil transitioned to a '
#                   'distributor operating model during the third quarter of fiscal 2021 and our '
#                   'NIKE Brand businesses in Argentina, Chile and Uruguay have remained classified '
#                   'as held-for-sale. The impacts of closing the Brazil transaction as well as '
#                   'entering into agreements to transition these entities in the prior year are '
#                   'included within Corporate and are not reflected in the APLA operating segment '
#                   'results. For more information see Note 20 - Acquisitions and Divestitures '
#                   'within the accompanying Notes to the Consolidated Financial Statements.\n'
#                   'FISCAL 2021 COMPARED TO FISCAL 2020',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 0
# Is the response correct? (1 for True, 0 for False): 0
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 4
# Question: What is the NIKE's operating income and how does it compare to the previous years?
# Response: Based on the provided document, NIKE's operating income for the year ended May 31, 2023 was $6,201 million. This represents a decrease of $1,055 million compared to the previous year.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '320187',
#                'company': 'NIKE, Inc.',
#                'filename': '320187_10K_2023_0000320187-23-000039.htm',
#                'filing_date': '2023-07-20',
#                'filing_type': '10-K',
#                'fiscal_year_end': '0531',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/320187/000032018723000039/nke-20230531.htm',
#                'period_of_report': '2023-05-31',
#                'relevance_score': 0.9642068148,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/320187_10K_2023_0000320187-23-000039.json',
#                'state_location': 'OR'},
#   'page_content': 'Addressing the matter involved performing procedures and evaluating audit '
#                   'evidence in connection with forming our overall opinion on the consolidated '
#                   'financial statements. These procedures included testing the effectiveness of '
#                   'controls relating to income taxes, evaluating changes in and compliance with '
#                   'tax laws, and testing the calculation of the provision of income taxes. '
#                   'Professionals with specialized skill and knowledge were used to assist in '
#                   'evaluating changes in and compliance with the tax laws and regulations and the '
#                   'provision for income taxes.\n'
#                   '/s/ PricewaterhouseCoopers LLP\n'
#                   'Portland, Oregon\n'
#                   'July 20, 2023\n'
#                   "We have served as the Company's auditor since 1974.\n"
#                   '2023 FORM 10-K 54\n'
#                   'NIKE, INC.\n'
#                   'CONSOLIDATED STATEMENTS OF INCOME\n'
#                   'YEAR ENDED MAY 31,\n'
#                   '(In millions, except per share data)\n'
#                   '2023 2022 2021\n'
#                   'Revenues $ 51,217 $ 46,710 $ 44,538\n'
#                   'Cost of sales 28,925 25,231 24,576\n'
#                   'Gross profit 22,292 21,479 19,962\n'
#                   'Demand creation expense 4,060 3,850 3,114\n'
#                   'Operating overhead expense 12,317 10,954 9,911\n'
#                   'Total selling and administrative expense 16,377 14,804 13,025\n'
#                   'Interest expense (income), net (6) 205 262\n'
#                   'Other (income) expense, net (280) (181) 14\n'
#                   'Income before income taxes 6,201 6,651 6,661\n'
#                   'Income tax expense 1,131 605 934\n'
#                   'NET INCOME $ 5,070 $ 6,046 $ 5,727\n'
#                   'Earnings per common share:\n'
#                   'Basic $ 3.27 $ 3.83 $ 3.64\n'
#                   'Diluted $ 3.23 $ 3.75 $ 3.56\n'
#                   'Weighted average common shares outstanding:\n'
#                   'Basic 1,551.6 1,578.8 1,573.0\n'
#                   'Diluted 1,569.8 1,610.8 1,609.4\n'
#                   'The accompanying Notes to the Consolidated Financial Statements are an integral '
#                   'part of this statement.\n'
#                   '2023 FORM 10-K 55\n'
#                   'NIKE, INC.\n'
#                   'CONSOLIDATED STATEMENTS OF COMPREHENSIVE INCOME\n'
#                   'YEAR ENDED MAY 31,\n'
#                   '(Dollars in millions)\n'
#                   '2023 2022 2021\n'
#                   'Net income $ 5,070 $ 6,046 $ 5,727\n'
#                   'Other comprehensive income (loss), net of tax:\n'
#                   'Change in net foreign currency translation adjustment 267 (522) 496\n'
#                   'Change in net gains (losses) on cash flow hedges (348) 1,214 (825)\n'
#                   'Change in net gains (losses) on other (6) 6 5',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '320187',
#                'company': 'NIKE, Inc.',
#                'filename': '320187_10K_2021_0000320187-21-000028.htm',
#                'filing_date': '2021-07-20',
#                'filing_type': '10-K',
#                'fiscal_year_end': '0531',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/320187/000032018721000028/nke-20210531.htm',
#                'period_of_report': '2021-05-31',
#                'relevance_score': 0.9508665204000001,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/320187_10K_2021_0000320187-21-000028.json',
#                'state_location': 'OR'},
#   'page_content': 'Asia Pacific & Latin America(1)\n'
#                   '304 296\n'
#                   'Global Brand Divisions 780 830\n'
#                   'Total NIKE Brand 2,971 2,870\n'
#                   'Converse 63 80\n'
#                   'Corporate 1,870 1,916\n'
#                   'TOTAL PROPERTY, PLANT AND EQUIPMENT, NET $ 4,904 $ 4,866\n'
#                   '(1)Excludes assets held-for-sale as of May 31, 2021. See Note 20 - Acquisitions '
#                   'and Divestitures for additional information.\n'
#                   'REVENUES AND LONG-LIVED ASSETS BY GEOGRAPHIC AREA\n'
#                   'After allocation of revenues for Global Brand Divisions, Converse and Corporate '
#                   'to geographical areas based on the location where the sales originated, '
#                   'revenues by geographical area are essentially the same as reported above for '
#                   'the NIKE Brand operating segments with the exception of the United States. '
#                   'Revenues derived in the United States were $17,363 million, $14,625 million and '
#                   '$16,091 million for the fiscal years ended May 31, 2021, 2020 and 2019, '
#                   'respectively.\n'
#                   "The Company's largest concentrations of long-lived assets primarily consist of "
#                   "the Company's corporate headquarters, retail locations and distribution "
#                   'facilities in the United States and China, as well as distribution facilities '
#                   'in Belgium. Long-lived assets attributable to operations in these countries, '
#                   'which primarily consists of property, plant and equipment, net and operating '
#                   'lease ROU assets, net, were as follows:\n'
#                   'MAY 31,\n'
#                   '(Dollars in millions)\n'
#                   '2021 2020\n'
#                   'United States $ 4,927 $ 5,114\n'
#                   'Belgium 676 606\n'
#                   'China 518 457\n'
#                   '2021 FORM 10-K 90\n'
#                   'NOTE 18 - COMMITMENTS AND CONTINGENCIES\n'
#                   'As of May 31, 2021 and 2020, the Company had bank guarantees and letters of '
#                   'credit outstanding totaling $275 million and $239 million, respectively, issued '
#                   'primarily for real estate agreements, self-insurance programs and other general '
#                   'business obligations.',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 0
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 5
# Question: What is the NIKE's net income for the current fiscal year and how has net income trended over the past few years?
# Response: According to the provided document, NIKE's net income for the current fiscal year (2023) is $5,070 million. Over the past few years, net income has trended upward, increasing from $6,046 million in 2022 to $5,727 million in 2021, and then to $5,070 million in 2023.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '320187',
#                'company': 'NIKE, Inc.',
#                'filename': '320187_10K_2023_0000320187-23-000039.htm',
#                'filing_date': '2023-07-20',
#                'filing_type': '10-K',
#                'fiscal_year_end': '0531',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/320187/000032018723000039/nke-20230531.htm',
#                'period_of_report': '2023-05-31',
#                'relevance_score': 0.9628452063,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/320187_10K_2023_0000320187-23-000039.json',
#                'state_location': 'OR'},
#   'page_content': 'Addressing the matter involved performing procedures and evaluating audit '
#                   'evidence in connection with forming our overall opinion on the consolidated '
#                   'financial statements. These procedures included testing the effectiveness of '
#                   'controls relating to income taxes, evaluating changes in and compliance with '
#                   'tax laws, and testing the calculation of the provision of income taxes. '
#                   'Professionals with specialized skill and knowledge were used to assist in '
#                   'evaluating changes in and compliance with the tax laws and regulations and the '
#                   'provision for income taxes.\n'
#                   '/s/ PricewaterhouseCoopers LLP\n'
#                   'Portland, Oregon\n'
#                   'July 20, 2023\n'
#                   "We have served as the Company's auditor since 1974.\n"
#                   '2023 FORM 10-K 54\n'
#                   'NIKE, INC.\n'
#                   'CONSOLIDATED STATEMENTS OF INCOME\n'
#                   'YEAR ENDED MAY 31,\n'
#                   '(In millions, except per share data)\n'
#                   '2023 2022 2021\n'
#                   'Revenues $ 51,217 $ 46,710 $ 44,538\n'
#                   'Cost of sales 28,925 25,231 24,576\n'
#                   'Gross profit 22,292 21,479 19,962\n'
#                   'Demand creation expense 4,060 3,850 3,114\n'
#                   'Operating overhead expense 12,317 10,954 9,911\n'
#                   'Total selling and administrative expense 16,377 14,804 13,025\n'
#                   'Interest expense (income), net (6) 205 262\n'
#                   'Other (income) expense, net (280) (181) 14\n'
#                   'Income before income taxes 6,201 6,651 6,661\n'
#                   'Income tax expense 1,131 605 934\n'
#                   'NET INCOME $ 5,070 $ 6,046 $ 5,727\n'
#                   'Earnings per common share:\n'
#                   'Basic $ 3.27 $ 3.83 $ 3.64\n'
#                   'Diluted $ 3.23 $ 3.75 $ 3.56\n'
#                   'Weighted average common shares outstanding:\n'
#                   'Basic 1,551.6 1,578.8 1,573.0\n'
#                   'Diluted 1,569.8 1,610.8 1,609.4\n'
#                   'The accompanying Notes to the Consolidated Financial Statements are an integral '
#                   'part of this statement.\n'
#                   '2023 FORM 10-K 55\n'
#                   'NIKE, INC.\n'
#                   'CONSOLIDATED STATEMENTS OF COMPREHENSIVE INCOME\n'
#                   'YEAR ENDED MAY 31,\n'
#                   '(Dollars in millions)\n'
#                   '2023 2022 2021\n'
#                   'Net income $ 5,070 $ 6,046 $ 5,727\n'
#                   'Other comprehensive income (loss), net of tax:\n'
#                   'Change in net foreign currency translation adjustment 267 (522) 496\n'
#                   'Change in net gains (losses) on cash flow hedges (348) 1,214 (825)\n'
#                   'Change in net gains (losses) on other (6) 6 5',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '320187',
#                'company': 'NIKE, Inc.',
#                'filename': '320187_10K_2021_0000320187-21-000028.htm',
#                'filing_date': '2021-07-20',
#                'filing_type': '10-K',
#                'fiscal_year_end': '0531',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/320187/000032018721000028/nke-20210531.htm',
#                'period_of_report': '2021-05-31',
#                'relevance_score': 0.9540842175,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/320187_10K_2021_0000320187-21-000028.json',
#                'state_location': 'OR'},
#   'page_content': '/s/ PricewaterhouseCoopers LLP\n'
#                   'Portland, Oregon\n'
#                   'July 20, 2021\n'
#                   "We have served as the Company's auditor since 1974.\n"
#                   '2021 FORM 10-K 56\n'
#                   'NIKE, INC.\n'
#                   'CONSOLIDATED STATEMENTS OF INCOME\n'
#                   'YEAR ENDED MAY 31,\n'
#                   '(In millions, except per share data)\n'
#                   '2021 2020 2019\n'
#                   'Revenues $ 44,538 $ 37,403 $ 39,117\n'
#                   'Cost of sales 24,576 21,162 21,643\n'
#                   'Gross profit 19,962 16,241 17,474\n'
#                   'Demand creation expense 3,114 3,592 3,753\n'
#                   'Operating overhead expense 9,911 9,534 8,949\n'
#                   'Total selling and administrative expense 13,025 13,126 12,702\n'
#                   'Interest expense (income), net 262 89 49\n'
#                   'Other (income) expense, net 14 139 (78)\n'
#                   'Income before income taxes 6,661 2,887 4,801\n'
#                   'Income tax expense 934 348 772\n'
#                   'NET INCOME $ 5,727 $ 2,539 $ 4,029\n'
#                   'Earnings per common share:\n'
#                   'Basic $ 3.64 $ 1.63 $ 2.55\n'
#                   'Diluted $ 3.56 $ 1.60 $ 2.49\n'
#                   'Weighted average common shares outstanding:\n'
#                   'Basic 1,573.0 1,558.8 1,579.7\n'
#                   'Diluted 1,609.4 1,591.6 1,618.4\n'
#                   'The accompanying Notes to the Consolidated Financial Statements are an integral '
#                   'part of this statement.\n'
#                   '2021 FORM 10-K 57\n'
#                   'NIKE, INC.\n'
#                   'CONSOLIDATED STATEMENTS OF COMPREHENSIVE INCOME\n'
#                   'YEAR ENDED MAY 31,\n'
#                   '(Dollars in millions)\n'
#                   '2021 2020 2019\n'
#                   'Net income $ 5,727 $ 2,539 $ 4,029\n'
#                   'Other comprehensive income (loss), net of tax:\n'
#                   'Change in net foreign currency translation adjustment 496 (148) (173)\n'
#                   'Change in net gains (losses) on cash flow hedges (825) (130) 503\n'
#                   'Change in net gains (losses) on other 5 (9) (7)\n'
#                   'Total other comprehensive income (loss), net of tax (324) (287) 323\n'
#                   'TOTAL COMPREHENSIVE INCOME $ 5,403 $ 2,252 $ 4,352\n'
#                   'The accompanying Notes to the Consolidated Financial Statements are an integral '
#                   'part of this statement.\n'
#                   '2021 FORM 10-K 58\n'
#                   'NIKE, INC.\n'
#                   'CONSOLIDATED BALANCE SHEETS\n'
#                   'MAY 31,\n'
#                   '(In millions)\n'
#                   '2021 2020\n'
#                   'ASSETS\n'
#                   'Current assets:\n'
#                   'Cash and equivalents $ 9,889 $ 8,348\n'
#                   'Short-term investments 3,587 439\n'
#                   'Accounts receivable, net 4,463 2,749\n'
#                   'Inventories 6,854 7,367\n'
#                   'Prepaid expenses and other current assets 1,498 1,653\n'
#                   'Total current assets 26,291 20,556\n'
#                   'Property, plant and equipment, net 4,904 4,866',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 0
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 6
# Question: What is the NIKE's earnings per share and how does it compare to industry benchmarks?
# Response: Based on the information provided in the document, NIKE's earnings per share for fiscal 2021 was $8.64 billion, while its earnings per share for fiscal 2023 was $8.359 billion, representing a decrease of 3%. This information can be found in the second paragraph under the heading "The Primary Financial Measure Used by the Company to Evaluate Performance is Earnings Before Interest and Taxes (EBIT)."
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '320187',
#                'company': 'NIKE, Inc.',
#                'filename': '320187_10K_2021_0000320187-21-000028.htm',
#                'filing_date': '2021-07-20',
#                'filing_type': '10-K',
#                'fiscal_year_end': '0531',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/320187/000032018721000028/nke-20210531.htm',
#                'period_of_report': '2021-05-31',
#                'relevance_score': 0.9623281956,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/320187_10K_2021_0000320187-21-000028.json',
#                'state_location': 'OR'},
#   'page_content': '(1) The percent change excluding currency changes represents a non-GAAP '
#                   'financial measure. See "Use of Non-GAAP Financial Measures" for further '
#                   'information.\n'
#                   '(2) Refer to Note 20 - Acquisitions and Divestitures within the accompanying '
#                   'Notes to the Consolidated Financial Statements for additional information on '
#                   'the transition of our NIKE Brand business in Brazil to a third-party '
#                   'distributor.\n'
#                   '(3) Global Brand Divisions revenues include NIKE Brand licensing and other '
#                   'miscellaneous revenues that are not part of a geographic operating segment.\n'
#                   '(4) Corporate revenues primarily consist of foreign currency hedge gains and '
#                   'losses related to revenues generated by entities within the NIKE Brand '
#                   'geographic operating segments and Converse, but managed through our central '
#                   'foreign exchange risk management program.\n'
#                   'The primary financial measure used by the Company to evaluate performance of '
#                   'individual operating segments is EBIT, which represents Net income before '
#                   'Interest expense (income), net and Income tax expense in the Consolidated '
#                   'Statements of Income. As discussed in Note 17 - Operating Segments and Related '
#                   'Information in the accompanying Notes to the Consolidated Financial Statements, '
# ...
#                   'Other comprehensive income (loss) (287) (287)\n'
#                   'Adoption of ASC Topic 842 (Note 1) (1) (1)\n'
#                   'Balance at May 31, 2020 315 $ - 1,243 $ 3 $ 8,299 $ (56) $ (191) $ 8,055\n'
#                   'Stock options exercised 21 954 954\n'
#                   'Conversion to Class B Common Stock (10) 10 -\n'
#                   'Repurchase of Class B Common Stock (5) (28) (622) (650)\n'
#                   'Dividends on common stock ($1.070 per share) and preferred stock ($0.10 per '
#                   'share)',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 0
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 33
# Question: How does the NIKE leverage technology for its operations and are there ongoing technological advancements?
# Response: The answer is in the context. According to the provided documents, NIKE relies heavily on Information Technology Systems across various aspects of its operations, including product design, production, forecasting, ordering, manufacturing, transportation, sales, and distribution. The company has implemented IT systems in all geographical regions where it operates and continues to invest in enhancing and securing these systems. However, NIKE acknowledges that these systems may be negatively impacted by service interruptions or shutdowns, and it cannot provide assurance that the measures taken to secure and enhance these systems will be sufficient to prevent cyber-attacks, system failures, or data loss. Additionally, the company is leveraging employee-owned devices for communications and implementing hybrid work arrangements, which may pose challenges in maintaining and protecting these systems.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '320187',
#                'company': 'NIKE, Inc.',
#                'filename': '320187_10K_2023_0000320187-23-000039.htm',
#                'filing_date': '2023-07-20',
#                'filing_type': '10-K',
#                'fiscal_year_end': '0531',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/320187/000032018723000039/nke-20230531.htm',
#                'period_of_report': '2023-05-31',
#                'relevance_score': 0.9680566788,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/320187_10K_2023_0000320187-23-000039.json',
#                'state_location': 'OR'},
#   'page_content': 'We are heavily dependent on Information Technology Systems, across our supply '
#                   'chain, including product design, production, forecasting, ordering, '
#                   'manufacturing, transportation, sales and distribution, as well as for '
#                   'processing financial information for external and internal reporting purposes, '
#                   'retail operations and other business activities. Information Technology Systems '
#                   'are critical to many of our operating activities and our business processes and '
#                   'may be negatively impacted by any service interruption or shutdown. For '
#                   'example, our ability to effectively manage and maintain our inventory and to '
#                   'ship products to customers on a timely basis depends significantly on the '
#                   'reliability of these Information Technology Systems. Over a number of years, we '
#                   'have implemented Information Technology Systems in all of the geographical '
#                   'regions in which we operate. Our work to integrate, secure and enhance these '
#                   'systems and related processes in our global operations is ongoing and NIKE will '
#                   'continue to invest in these efforts. We cannot provide assurance, however, that '
#                   'the measures we take to secure and enhance these systems will be sufficient to '
#                   'protect our Information Technology Systems and prevent cyber-attacks, system '
#                   'failures or data or information loss. The failure of these systems to operate '
#                   'effectively, including as a result of security breaches, viruses, hackers, '
#                   'malware, natural disasters, vendor business interruptions or other causes, '
#                   'failure to properly maintain, protect, repair or upgrade systems, or problems '
#                   'with transitioning to upgraded or replacement systems could cause delays in '
#                   'product fulfillment and reduced efficiency of our operations, could require '
#                   'significant capital investments to remediate the problem which may not be '
#                   'sufficient to cover all eventualities, and may have an adverse effect on our '
#                   'reputation, results of operations and financial condition. In addition, the use '
#                   'of employee-owned devices for communications as well as hybrid work '
#                   'arrangements,',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '320187',
#                'company': 'NIKE, Inc.',
#                'filename': '320187_10K_2021_0000320187-21-000028.htm',
#                'filing_date': '2021-07-20',
#                'filing_type': '10-K',
#                'fiscal_year_end': '0531',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/320187/000032018721000028/nke-20210531.htm',
#                'period_of_report': '2021-05-31',
#                'relevance_score': 0.9659535289000001,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/320187_10K_2021_0000320187-21-000028.json',
#                'state_location': 'OR'},
#   'page_content': 'We are heavily dependent on Information Technology Systems, across our supply '
#                   'chain, including product design, production, forecasting, ordering, '
#                   'manufacturing, transportation, sales and distribution, as well as for '
#                   'processing financial information for external and internal reporting purposes, '
#                   'retail operations and other business activities. Information Technology Systems '
#                   'are critical to many of our operating activities and our business processes and '
#                   'may be negatively impacted by any service interruption or shutdown. For '
#                   'example, our ability to effectively manage and maintain our inventory and to '
#                   'ship products to customers on a timely basis depends significantly on the '
#                   'reliability of these Information Technology Systems. Over a number of years, we '
#                   'have implemented Information Technology Systems in all of the geographical '
#                   'regions in which we operate. Our work to integrate, secure and enhance these '
#                   'systems and related processes in our global operations is ongoing and NIKE will '
#                   'continue to invest in these efforts. We cannot provide assurance, however, that '
#                   'the measures we take to secure and enhance these systems will be sufficient to '
#                   'protect our Information Technology Systems and prevent cyber-attacks, system '
#                   'failures or data or information loss. The failure of these systems to operate '
#                   'effectively, including as a result of security breaches, viruses, hackers, '
#                   'malware, natural disasters, vendor business interruptions or other causes, '
#                   'failure to properly maintain, protect, repair or upgrade systems, or problems '
#                   'with transitioning to upgraded or replacement systems could cause delays in '
#                   'product fulfillment and reduced efficiency of our operations, could require '
#                   'significant capital investments to remediate the problem which may not be '
#                   'sufficient to cover all eventualities, and may have an adverse effect on our '
#                   'reputation, results of operations and financial condition. In addition, the '
#                   'increased use of employee-owned devices for communications as well as '
#                   'work-from-home',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 34
# Question: What does the NIKE foresee in terms of future growth and challenges and are there any strategic plans outlined for the upcoming years?
# Response: The answer is not in the context. The document you provided only contains information about NIKE's financial performance and risk factors for the fiscal year 2021, but does not provide any information about the company's future growth and challenges or strategic plans beyond that year.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '320187',
#                'company': 'NIKE, Inc.',
#                'filename': '320187_10K_2021_0000320187-21-000028.htm',
#                'filing_date': '2021-07-20',
#                'filing_type': '10-K',
#                'fiscal_year_end': '0531',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/320187/000032018721000028/nke-20210531.htm',
#                'period_of_report': '2021-05-31',
#                'relevance_score': 0.9684403539,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/320187_10K_2021_0000320187-21-000028.json',
#                'state_location': 'OR'},
#   'page_content': 'and sports; seasonal and geographic demand for NIKE products; difficulties in '
#                   'anticipating or forecasting changes in consumer preferences, consumer demand '
#                   'for NIKE products and the various market factors described above; difficulties '
#                   "in implementing, operating and maintaining NIKE's increasingly complex "
#                   'information technology systems and controls, including, without limitation, the '
#                   'systems related to demand and supply planning and inventory control; '
#                   'interruptions in data and information technology systems; consumer data '
#                   'security; fluctuations and difficulty in forecasting operating results, '
#                   'including, without limitation, the fact that advance orders may not be '
#                   'indicative of future revenues due to changes in shipment timing, the changing '
#                   'mix of orders with shorter lead times, and discounts, order cancellations and '
#                   'returns; the ability of NIKE to sustain, manage or forecast its growth and '
#                   "inventories; the size, timing and mix of purchases of NIKE's products; "
#                   'increases in the cost of materials, labor and energy used to manufacture '
#                   'products; new product development and introduction; the ability to secure and '
#                   'protect trademarks, patents and other intellectual property; product '
#                   'performance and quality; customer service; adverse publicity, including without '
#                   'limitation, through social media or in connection with brand damaging events; '
#                   'the loss of significant customers or suppliers; dependence on distributors and '
#                   'licensees; business disruptions; increased costs of freight and transportation '
#                   'to meet delivery deadlines; increases in borrowing costs due to any decline in '
#                   "NIKE's debt ratings; changes in business strategy or development plans; general "
#                   'risks associated with doing business outside of the United States, including, '
#                   'without limitation, exchange rate fluctuations, inflation, import duties, '
#                   'tariffs, quotas, political and economic instability and terrorism; the '
#                   'potential impact of new laws, regulations or policy, including, without '
#                   'limitation, tariffs, import/export,',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '320187',
#                'company': 'NIKE, Inc.',
#                'filename': '320187_10K_2023_0000320187-23-000039.htm',
#                'filing_date': '2023-07-20',
#                'filing_type': '10-K',
#                'fiscal_year_end': '0531',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/320187/000032018723000039/nke-20230531.htm',
#                'period_of_report': '2023-05-31',
#                'relevance_score': 0.9669592977,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/320187_10K_2023_0000320187-23-000039.json',
#                'state_location': 'OR'},
#   'page_content': 'In addition, we have made significant investments in digital technologies and '
#                   'information systems for the digital aspect of our NIKE Direct operations, and '
#                   'our digital offerings will require continued investment in the development and '
#                   'upgrading of our technology platforms. In order to deliver high-quality digital '
#                   'experiences, our digital platforms must be designed effectively and work well '
#                   'with a range of other technologies, systems, networks, and standards that we do '
#                   'not control. We may not be successful in developing platforms that operate '
#                   'effectively with these technologies, systems, networks or standards. A growing '
#                   'portion of consumers access our NIKE Direct digital platforms, but in the event '
#                   'that it is more difficult for consumers to access and use our digital '
#                   'platforms, consumers find that our digital platforms do not effectively meet '
#                   'their needs or expectations or consumers choose not to access or use our '
#                   'digital platforms or use devices that do not offer access to our platforms, the '
#                   'success of our NIKE Direct operations could be adversely impacted. Our '
#                   'competitors may develop, or have already developed, digital experiences, '
#                   'features, content, services or technologies that are similar to ours or that '
#                   'achieve greater acceptance.\n'
#                   'We may not realize a satisfactory return on our investment in our NIKE Direct '
#                   "operations and management's attention from our other business opportunities "
#                   'could be diverted, which could have an adverse effect on our business, '
#                   'financial condition or results of operations.\n'
#                   'If the technology-based systems that give our consumers the ability to shop or '
#                   'interact with us online do not function effectively, our operating results, as '
#                   'well as our ability to grow our digital commerce business globally or to retain '
#                   'our customer base, could be materially adversely affected.',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 0
# Progress saved.
#
# Evaluation results saved to 'evaluation_results_Nike.json'.

# %%
eval = pd.read_json('/content/evaluation_results_Nike.json')
eval.mean()[1:]
# Out:
# The context is relevant to the company     1.000000
# The context is relevant to the question    0.457143
# The response is correct                    0.400000
# The response answers the question          0.742857
# dtype: float64
