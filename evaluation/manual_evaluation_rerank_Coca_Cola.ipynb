# %% [markdown]
# <a href="https://colab.research.google.com/github/winterForestStump/thesis/blob/main/evaluation/manual_evaluation_rerank_Coca_Cola.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import json
from pprint import pprint

# Load your dataframe
# Replace 'your_data.csv' with the actual path to your data file
df1 = pd.read_json('/content/results_Coca_Cola_rerank.json')

# Initialize dictionary to store results
results = {'index': [],
           'The context is relevant to the company': [],
           'The context is relevant to the question': [],
           'The response is correct': [],
           'The response answers the question': []}

# Check if there's a previous evaluation progress saved
try:
    with open('evaluation_results.json', 'r') as f:
        previous_results = json.load(f)
    start_index = max(previous_results['index']) + 1
    results = previous_results
    print("Resuming evaluation from the last unanswered question.")
except (FileNotFoundError, ValueError, KeyError):
    start_index = 0
    print("Starting evaluation from the beginning.")

# Function to get valid user input (1 or 0)
def get_valid_input(message):
    while True:
        try:
            user_input = int(input(message))
            if user_input not in (0, 1):
                raise ValueError("Input must be 0 or 1.")
            return user_input
        except ValueError:
            print("Invalid input. Please enter 0 or 1.")

# Iterate over each row in the dataframe
for idx, row in df1.iloc[start_index:].iterrows():
    print("\nRow Index:", idx)
    print("Question:", row['question'])
    print("Response:", row['response'])
    print("Context:")
    pprint(row['context'], width=100)

    # Ask questions and get user input
    context_relevant_to_company = get_valid_input("Is the context relevant to the company? (1 for True, 0 for False): ")
    context_relevant_to_question = get_valid_input("Is the context relevant to the question? (1 for True, 0 for False): ")
    response_correct = get_valid_input("Is the response correct? (1 for True, 0 for False): ")
    response_answers_question = get_valid_input("Does the response answer the question? (1 for True, 0 for False): ")

    # Append results to dictionary
    results['index'].append(idx)
    results['The context is relevant to the company'].append(context_relevant_to_company)
    results['The context is relevant to the question'].append(context_relevant_to_question)
    results['The response is correct'].append(response_correct)
    results['The response answers the question'].append(response_answers_question)

    # Convert results dictionary to JSON and save to a file after each row
    json_result = json.dumps(results, indent=4)
    with open('evaluation_results_rerank.json', 'w') as f:
        f.write(json_result)

    print("Progress saved.")

print("\nEvaluation results saved to 'evaluation_results.json'.")
# Out:
# Starting evaluation from the beginning.
#
# Row Index: 0
# Question: What is the total revenue generated by the Coca Cola and how has the revenue changed over the past few years?
# Response: The answer is not in the provided information. The document only provides information about Square, Inc.'s financial performance and does not include any information about Coca-Cola's revenue.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '1512673',
#                'company': 'Square, Inc.',
#                'filename': '1512673_10K_2020_0001512673-21-000008.htm',
#                'filing_date': '2021-02-23',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/1512673/000151267321000008/sq-20201231.htm',
#                'period_of_report': '2020-12-31',
#                'relevance_score': 0.9648309350000001,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/1512673_10K_2020_0001512673-21-000008.json',
#                'state_location': 'CA'},
#   'page_content': 'Results of Operations\n'
#                   'Revenue (in thousands, except for percentages)\n'
#                   'Year Ended December 31,\n'
#                   '2020 2019 $ Change % Change\n'
#                   'Transaction-based revenue $ 3,294,978 $ 3,081,074 $ 213,904 7 %\n'
#                   'Subscription and services-based revenue 1,539,403 1,031,456 507,947 49 %\n'
#                   'Hardware revenue 91,654 84,505 7,149 8 %\n'
#                   'Bitcoin revenue 4,571,543 516,465 4,055,078 785 %\n'
#                   'Total net revenue $ 9,497,578 $ 4,713,500 $ 4,784,078 101 %\n'
#                   'Total net revenue for the year ended December 31, 2020, increased by $4.8 '
#                   'billion, or 101%, compared to the year ended December 31, 2019. Bitcoin revenue '
#                   'increased by $4.1 billion, and represented 85% of the increase in total net '
#                   'revenue. Excluding bitcoin revenue, total net revenue increased by $729.0 '
#                   'million, or 17%, in the year ended December 31, 2020, compared to the year '
#                   'ended December 31, 2019.\n'
#                   'Transaction-based revenue for the year ended December 31, 2020 increased by '
#                   '$213.9 million or 7%, compared to the year ended December 31, 2019. This '
#                   'increase was in line with the increase in GPV of 6% for the year ended December '
#                   '31, 2020, compared to the year ended December 31, 2019. The increase was '
#                   'primarily attributable to and affected by the following events and factors:\n'
#                   'In January and February of 2020, we benefited from the growth in payment volume '
#                   'processed by existing sellers, in addition to meaningful contributions from new '
#                   'sellers, compared to the same period in the prior year, which included a '
#                   'benefit from the impact of the leap year;\n'
#                   'In the second half of March through mid-April, 2020, as a result of the '
#                   'COVID-19 pandemic and subsequent shelter-in-place restrictions, we experienced '
#                   'a significant decline in transaction-based revenue, with GPV generated by our '
#                   'Seller business decreasing compared to the prior year;',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '1512673',
#                'company': 'Square, Inc.',
#                'filename': '1512673_10K_2016_0001628280-17-001754.htm',
#                'filing_date': '2017-02-27',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/1512673/000162828017001754/a10-kfilingsquareinc2016.htm',
#                'period_of_report': '2016-12-31',
#                'relevance_score': 0.9644922614,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/1512673_10K_2016_0001628280-17-001754.json',
#                'state_location': 'CA'},
#   'page_content': 'consisted primarily of changes in the fair value of our customer warrant '
#                   'liability measurements and foreign currency-related gains and losses.\n'
#                   'Provision for Income Taxes\n'
#                   'The provision for income taxes consists primarily of local, state, federal, and '
#                   'foreign tax. Our effective tax rate fluctuates from period to period due to '
#                   'changes in the mix of income and losses in jurisdictions with a wide range of '
#                   'tax rates, the effect of acquisitions, changes resulting from the amount of '
#                   'recorded valuation allowance, permanent differences between U.S. generally '
#                   'accepted accounting principles and local tax laws, certain one-time items, and '
#                   'changes in tax contingencies.\n'
#                   'Deemed Dividend on Series E Preferred Stock\n'
#                   'For the year ended December 31, 2015, we issued 10,299,696 shares of our common '
#                   'stock to certain holders of Series E preferred stock in the form of a deemed '
#                   'stock dividend of $32.2 million. There were no similar occurrences in any other '
#                   'period presented.\n'
#                   'Results of Operations\n'
#                   'Revenue (in thousands, except for percentages)\n'
#                   'Year Ended December 31,\n'
#                   '2015 to 2016\n'
#                   '2014 to 2015\n'
#                   '% Change\n'
#                   '% Change\n'
#                   'Transaction-based revenue\n'
#                   '$\n'
#                   '1,456,160\n'
#                   '$\n'
#                   '1,050,445\n'
#                   '$\n'
#                   '707,799\n'
#                   '%\n'
#                   '%\n'
#                   'Starbucks transaction-based revenue\n'
#                   '78,903\n'
#                   '142,283\n'
#                   '123,024\n'
#                   '(45\n'
#                   ')%\n'
#                   '%\n'
#                   'Subscription and services-based revenue\n'
#                   '129,351\n'
#                   '58,013\n'
#                   '12,046\n'
#                   '%\n'
#                   '%\n'
#                   'Hardware revenue\n'
#                   '44,307\n'
#                   '16,377\n'
#                   '7,323\n'
#                   '%\n'
#                   '%\n'
#                   'Total net revenue\n'
#                   '$\n'
#                   '1,708,721\n'
#                   '$\n'
#                   '1,267,118\n'
#                   '$\n'
#                   '850,192\n'
#                   '%\n'
#                   '%\n'
#                   'Comparison of Years Ended December 31, 2016 and 2015\n'
#                   'Total net revenue for the year ended December 31, 2016, increased by $441.6 '
#                   'million, or 35%, compared to the year ended December 31, 2015.\n'
#                   'Transaction-based revenue for the year ended December 31, 2016, increased by '
#                   '$405.7 million, or 39%, compared to the year ended December 31, 2015. This '
#                   'increase was attributable to growth in GPV processed of $14.0 billion, or 39%, '
#                   'to $49.7 billion from $35.6 billion. We continue to benefit from positive '
#                   'dollar-based retention from our existing sellers, in addition to meaningful '
#                   'contributions from new sellers.',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 0
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 0
# Progress saved.
#
# Row Index: 1
# Question: What is the Coca Cola's cost of goods sold (COGS) and how does the COGS compare to the total revenue?
# Response: The answer is not in the context. The document you provided is an excerpt from Microsoft's 10-K filing for the year 2016, while the question refers to Coca-Cola. Therefore, I cannot provide any information about Coca-Cola's cost of goods sold or its comparison to total revenue.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '1512673',
#                'company': 'Square, Inc.',
#                'filename': '1512673_10K_2016_0001628280-17-001754.htm',
#                'filing_date': '2017-02-27',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/1512673/000162828017001754/a10-kfilingsquareinc2016.htm',
#                'period_of_report': '2016-12-31',
#                'relevance_score': 0.9707509875,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/1512673_10K_2016_0001628280-17-001754.json',
#                'state_location': 'CA'},
#   'page_content': 'Revenue for Caviar, our food ordering service, is derived from seller fees, '
#                   'which are a percentage of total food order value, delivery fees, and service '
#                   'fees paid by the consumer based on total food order value.\n'
#                   'Hardware revenue. Hardware revenue includes revenue from sales of contactless '
#                   'and chip readers, chip card readers, Square Stand, and third-party peripherals. '
#                   'Third-party peripherals include cash drawers, receipt printers, and barcode '
#                   'scanners, all of which can be integrated with Square Stand to provide a '
#                   'comprehensive point-of-sale solution. In the second quarter of 2015, we began '
#                   'selling our first chip card reader, and in the fourth quarter of 2015, we began '
#                   'selling our contactless and chip reader.\n'
#                   'Cost of Revenue and Gross Margin\n'
#                   'Transaction-based costs. Transaction-based costs consist primarily of '
#                   'interchange fees set by payment card networks and that are paid to the '
#                   'card-issuing financial institution, assessment fees paid to payment card '
#                   'networks, fees paid to third-party payment processors, and bank settlement '
#                   'fees.\n'
#                   'Starbucks transaction-based costs. Starbucks transaction-based costs consist of '
#                   'the same components as our overall transaction-based costs.\n'
#                   'Subscription and services-based costs. Subscription and services-based costs '
#                   'consist primarily of Caviar-related costs, which include payments to '
#                   'third-party couriers for deliveries and the costs of equipment provided to '
#                   'sellers. Cost of revenue for other subscription and services-based products '
#                   'consists primarily of the amortization related to the development of certain '
#                   'subscription and services-based products.',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '789019',
#                'company': 'MICROSOFT CORP',
#                'filename': '789019_10K_2016_0001193125-16-662209.htm',
#                'filing_date': '2016-07-28',
#                'filing_type': '10-K',
#                'fiscal_year_end': '0630',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/789019/000119312516662209/d187868d10k.htm',
#                'period_of_report': '2016-06-30',
#                'relevance_score': 0.9702497721000001,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/789019_10K_2016_0001193125-16-662209.json',
#                'state_location': 'WA'},
#   'page_content': 'Revenue related to Microsoft Surface (Surface) devices, Xbox consoles, games '
#                   'published by us, phones, and other hardware components is generally recognized '
#                   'when ownership is transferred to the resellers or to end customers when selling '
#                   'directly through Microsoft retail stores and online marketplaces. A portion of '
#                   'revenue may be deferred when these products are combined with software '
#                   'elements, and/or services. Revenue related to licensing for games published by '
#                   'third parties for use on the Xbox consoles is recognized when games are '
#                   'manufactured by the game publishers.\n'
#                   'Display advertising revenue is recognized as advertisements are displayed. '
#                   'Search advertising revenue is recognized when the ad appears in the search '
#                   'results or when the action necessary to earn the revenue has been completed. '
#                   'Consulting services revenue is recognized as services are rendered, generally '
#                   'based on the negotiated hourly rate in the consulting arrangement and the '
#                   'number of hours worked during the period. Consulting revenue for fixed-price '
#                   'services arrangements is recognized as services are provided.\n'
#                   'Cost of Revenue\n'
#                   'Cost of revenue includes: manufacturing and distribution costs for products '
#                   'sold and programs licensed; operating costs related to product support service '
#                   'centers and product distribution centers; costs incurred to include software on '
#                   'PCs sold by OEMs, to drive traffic to our websites, and to acquire online '
#                   'advertising space; costs incurred to support and maintain Internet-based '
#                   'products and services, including datacenter costs and royalties; warranty '
#                   'costs; inventory valuation adjustments; costs associated with the delivery of '
#                   'consulting services; and the amortization of capitalized software development '
#                   'costs. Capitalized software development costs are amortized over the estimated '
#                   'lives of the products.\n'
#                   'Product Warranty',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 0
# Is the context relevant to the question? (1 for True, 0 for False): 0
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 0
# Progress saved.
#
# Row Index: 2
# Question: What is the Coca Cola's gross profit margin, and how has it evolved?
# Response: The answer is in the context. According to the provided information, Coca Cola's gross profit margin was 58.1% in 2022, down from 60.3% in 2021. Additionally, the company's gross profit margin decreased to 62.6% in 2017 from 60.7% in 2016, primarily due to the unfavorable impact of foreign currency exchange rate fluctuations.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2017_0000021344-18-000008.htm',
#                'filing_date': '2018-02-23',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134418000008/a2017123110-k.htm',
#                'period_of_report': '2017-12-31',
#                'relevance_score': 0.9666981101000001,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2017_0000021344-18-000008.json',
#                'state_location': 'GA'},
#   'page_content': 'Gross Profit Margin\n'
#                   'As a result of our finished goods operations, which are primarily included in '
#                   'our North America and Bottling Investments operating segments, the following '
#                   "inputs represent a substantial portion of the Company's total cost of goods "
#                   'sold: (1) sweeteners, (2) metals, (3) juices and (4) PET. The Company enters '
#                   'into hedging activities related to certain commodities in order to mitigate a '
#                   'portion of the price risk associated with forecasted purchases. Many of the '
#                   'derivative financial instruments used by the Company to mitigate the risk '
#                   'associated with these commodity exposures, including any related foreign '
#                   'currency exposure, do not qualify for hedge accounting. As a result, the '
#                   'changes in fair value of these derivative instruments have been, and will '
#                   'continue to be, included as a component of net income in each reporting period. '
#                   'The Company recorded gains related to these derivatives of $14 million and $79 '
#                   'million during the years ended December 31, 2017 and December 31, 2016, '
#                   'respectively, and recorded a loss of $206 million during the year ended '
#                   'December 31, 2015 in the line item cost of goods sold in our consolidated '
#                   'statements of income. Refer to Note 5 of Notes to Consolidated Financial '
#                   'Statements. We do not currently expect changes in commodity costs to have a '
#                   'significant impact on our 2018 gross profit margin as compared to 2017.\n'
#                   'Year Ended December 31, 2017 versus Year Ended December 31, 2016\n'
#                   'Our gross profit margin increased to 62.6 percent in 2017 from 60.7 percent in '
#                   '2016. The increase was primarily due to the impact of acquisitions and '
#                   'divestitures, partially offset by the unfavorable impact of foreign currency '
#                   'exchange rate fluctuations. Refer to Note 2 of Notes to Consolidated Financial '
#                   'Statements for additional information related to acquisitions and '
#                   'divestitures.\n'
#                   'Year Ended December 31, 2016 versus Year Ended December 31, 2015',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2022_0000021344-23-000011.htm',
#                'filing_date': '2023-02-21',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134423000011/ko-20221231.htm',
#                'period_of_report': '2022-12-31',
#                'relevance_score': 0.9606766105000001,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2022_0000021344-23-000011.json',
#                'state_location': 'GA'},
#   'page_content': 'Latin America 11.4 10.7\n'
#                   'North America 36.5 34.1\n'
#                   'Asia Pacific 11.0 12.1\n'
#                   'Global Ventures 6.6 7.3\n'
#                   'Bottling Investments 18.3 18.6\n'
#                   'Corporate 0.2 0.2\n'
#                   'Total 100.0 % 100.0 %\n'
#                   'The percentage contribution of each operating segment fluctuates over time due '
#                   'to net operating revenues in some operating segments growing at a faster rate '
#                   'compared to other operating segments. In addition, foreign currency exchange '
#                   'rate fluctuations impact the percentage contribution of each operating segment. '
#                   'For additional information about the impact of foreign currency exchange rate '
#                   'fluctuations, refer to the heading Liquidity, Capital Resources and Financial '
#                   'Position - Foreign Exchange below.\n'
#                   'Gross Profit Margin\n'
#                   'Gross profit margin is a ratio calculated by dividing gross profit by net '
#                   'operating revenues. Management believes gross profit margin provides investors '
#                   'with useful information related to the profitability of our business prior to '
#                   'considering all of the selling, general and administrative expenses and other '
#                   'operating charges incurred. Management uses this measure in making financial, '
#                   'operating and planning decisions and in evaluating the Companys performance.\n'
#                   'Our gross profit margin decreased to 58.1 percent in 2022 from 60.3 percent in '
#                   '2021. This decrease was primarily due to the unfavorable impact of foreign '
#                   'currency exchange rate fluctuations, increased commodity and transportation '
#                   'costs, and the acquisition of BodyArmor, a finished goods business, in November '
#                   '2021. The impact of these items was partially offset by favorable pricing '
#                   'initiatives as well as favorable channel and package mix. We expect commodity '
#                   'and transportation costs to continue to have an unfavorable impact on our gross '
#                   'profit margin in 2023, and we will continue to proactively take actions in an '
#                   'effort to mitigate the impact of these incremental costs.\n'
#                   'Selling, General and Administrative Expenses\n'
#                   'The following table sets forth the components of selling, general and '
#                   'administrative expenses (in millions):',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 3
# Question: What are the Coca Cola's major operating expenses and how have these expenses changed over time?
# Response: The answer is not in the context. The passage provides information about the company's income tax expenses, other income (loss), and net operating losses, but does not mention any major operating expenses.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2022_0000021344-23-000011.htm',
#                'filing_date': '2023-02-21',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134423000011/ko-20221231.htm',
#                'period_of_report': '2022-12-31',
#                'relevance_score': 0.9535360932,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2022_0000021344-23-000011.json',
#                'state_location': 'GA'},
#   'page_content': 'The Company and its subsidiaries file income tax returns in all applicable '
#                   'jurisdictions, including the U.S. federal jurisdiction, U.S. state '
#                   'jurisdictions and foreign jurisdictions. U.S. tax authorities have completed '
#                   'their federal income tax examinations for all years prior to 2007. With respect '
#                   'to U.S. state jurisdictions and foreign jurisdictions, with limited exceptions, '
#                   'the Company and its subsidiaries are no longer subject to income tax audits for '
#                   'years prior to 2007. For U.S. federal and state tax purposes, the net operating '
#                   'losses and tax credit carryovers that were acquired in connection with our '
#                   'acquisition of Coca-Cola Enterprises Inc.s former North America business and '
#                   'that were generated from 1990 through 2010 are subject to adjustments until the '
#                   'year in which they are utilized is no longer subject to examination. Although '
#                   'the outcome of tax audits is always uncertain, the Company believes that '
#                   'adequate amounts of tax, including interest and penalties, have been provided '
#                   'for in accordance with the applicable accounting guidance.\n'
#                   'On November 18, 2020, the Tax Court issued the Opinion regarding the Companys '
#                   '2015 litigation with the IRS involving transfer pricing tax adjustments in '
#                   'which the court predominantly sided with the IRS. The Company disagrees with '
#                   'the Opinion and intends to vigorously defend its position. Refer to Note 11.\n'
#                   'As of December 31, 2022, the gross amount of unrecognized tax benefits was $926 '
#                   'million. If the Company were to prevail on all uncertain tax positions, the net '
#                   'effect would be a benefit of $617 million, exclusive of any benefits related to '
#                   'interest and penalties. The remaining $309 million primarily represents tax '
#                   'benefits that would be received in different tax jurisdictions in the event the '
#                   'Company did not prevail on all uncertain tax positions.\n'
#                   'A reconciliation of the changes in the gross amount of unrecognized tax '
#                   'benefits is as follows (in millions):\n'
#                   'Year Ended December 31, 2022 2021 2020',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2017_0000021344-18-000008.htm',
#                'filing_date': '2018-02-23',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134418000008/a2017123110-k.htm',
#                'period_of_report': '2017-12-31',
#                'relevance_score': 0.9533271790000001,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2017_0000021344-18-000008.json',
#                'state_location': 'GA'},
#   'page_content': 'In 2017, other income (loss) - net was a loss of $1,666 million. The Company '
#                   'recognized a net charge of $2,140 million due to the refranchising of certain '
#                   'bottling territories in North America and charges of $313 million primarily '
#                   'related to payments made to convert the bottling agreements for certain North '
#                   "America bottling partners' territories to a single form of CBA with additional "
#                   'requirements. The Company also recorded an other-than-temporary impairment '
#                   'charge of $50 million related to one of our international equity method '
#                   'investees, primarily driven by foreign currency exchange rate fluctuations. '
#                   'Additionally, the Company incurred a charge of $26 million related to our '
#                   'former German bottling operations. These charges were partially offset by a '
#                   'gain of $445 million related to the integration of Coca-Cola West Co., Ltd. '
#                   '("CCW") and Coca-Cola East Japan Co., Ltd. ("CCEJ") to establish Coca-Cola '
#                   'Bottlers Japan Inc. ("CCBJI"). In exchange for our previously existing equity '
#                   'interests in CCW and CCEJ, we received an approximate 17 percent equity '
#                   'interest in CCBJI. The Company also recognized a gain of $150 million related '
#                   'to the remeasurement of our previously held equity interests in CCBA and its '
#                   'South African subsidiary to fair value upon consolidation of CCBA. '
#                   'Additionally, the Company recognized a gain of $88 million related to the '
#                   'refranchising of our China bottling operations and related cost method '
#                   'investment and a gain of $25 million as a result of Coca-Cola FEMSA, an equity '
#                   'method investee, issuing additional shares of its stock during the period at a '
#                   "per share amount greater than the carrying value of the Company's per share "
#                   'investment. Other income (loss) - net also included net gains of $88 million '
#                   'related to trading securities and the sale of available-for-sale securities and '
#                   '$71 million of dividend income, partially offset by net foreign currency '
#                   'exchange losses of $57 million. Refer to Note 2 of Notes to Consolidated '
#                   'Financial Statements for',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 0
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 0
# Progress saved.
#
# Row Index: 4
# Question: What is the Coca Cola's operating income and how does it compare to the previous years?
# Response: Based on the information provided in the document, Coca-Cola's operating income for the year ended December 31, 2021 was $10,308 million. This represents a decrease of $1,049 million compared to the previous year.
# Here is a comparison of Coca-Cola's operating income for the past three years:
# Year Ended December 31, 2021: $10,308 million
# Year Ended December 31, 2020: $9,749 million
# Year Ended December 31, 2019: $10,786 million
# As shown above, Coca-Cola's operating income decreased by $1,049 million in 2021 compared to 2020, and decreased by $637 million in 2020 compared to 2019.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2021_0000021344-22-000009.htm',
#                'filing_date': '2022-02-22',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134422000009/ko-20211231.htm',
#                'period_of_report': '2021-12-31',
#                'relevance_score': 0.9547910690000001,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2021_0000021344-22-000009.json',
#                'state_location': 'GA'},
#   'page_content': 'Consolidated Balance Sheets\n'
#                   'Consolidated Statements of Cash Flows\n'
#                   'Consolidated Statements of Shareowners Equity\n'
#                   'Notes to Consolidated Financial Statements\n'
#                   'Report of Management\n'
#                   'Report of Independent Registered Public Accounting Firm (PCAOB ID: 42)\n'
#                   'Report of Independent Registered Public Accounting Firm on Internal Control '
#                   'Over Financial Reporting\n'
#                   'THE COCA-COLA COMPANY AND SUBSIDIARIES\n'
#                   'CONSOLIDATED STATEMENTS OF INCOME\n'
#                   '(In millions except per share data)\n'
#                   'Year Ended December 31, 2021 2020 2019\n'
#                   'Net Operating Revenues $ 38,655 $ 33,014 $ 37,266\n'
#                   'Cost of goods sold 15,357 13,433 14,619\n'
#                   'Gross Profit 23,298 19,581 22,647\n'
#                   'Selling, general and administrative expenses 12,144 9,731 12,103\n'
#                   'Other operating charges 846 853 458\n'
#                   'Operating Income 10,308 8,997 10,086\n'
#                   'Interest income 276 370 563\n'
#                   'Interest expense 1,597 1,437 946\n'
#                   'Equity income (loss) - net 1,438 978 1,049\n'
#                   'Other income (loss) - net 2,000 841 34\n'
#                   'Income Before Income Taxes 12,425 9,749 10,786\n'
#                   'Income taxes 2,621 1,981 1,801\n'
#                   'Consolidated Net Income 9,804 7,768 8,985\n'
#                   'Less: Net income (loss) attributable to noncontrolling interests 33 21 65\n'
#                   'Net Income Attributable to Shareowners of The Coca-Cola Company $ 9,771 $ 7,747 '
#                   '$ 8,920\n'
#                   'Basic Net Income Per Share1\n'
#                   '$ 2.26 $ 1.80 $ 2.09\n'
#                   'Diluted Net Income Per Share1\n'
#                   '$ 2.25 $ 1.79 $ 2.07\n'
#                   'Average Shares Outstanding - Basic 4,315 4,295 4,276\n'
#                   'Effect of dilutive securities 25 28 38\n'
#                   'Average Shares Outstanding - Diluted 4,340 4,323 4,314\n'
#                   '1 Calculated based on net income attributable to shareowners of The Coca-Cola '
#                   'Company.\n'
#                   'Refer to Notes to Consolidated Financial Statements.\n'
#                   'THE COCA-COLA COMPANY AND SUBSIDIARIES\n'
#                   'CONSOLIDATED STATEMENTS OF COMPREHENSIVE INCOME\n'
#                   '(In millions)\n'
#                   'Year Ended December 31, 2021 2020 2019\n'
#                   'Consolidated Net Income $ 9,804 $ 7,768 $ 8,985\n'
#                   'Other Comprehensive Income:\n'
#                   'Net foreign currency translation adjustments (699) (911) 74\n'
#                   'Net gains (losses) on derivatives 214 15 (54)\n'
#                   'Net change in unrealized gains (losses) on available-for-sale debt securities '
#                   '(90) (47) 18',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2021_0000021344-22-000009.htm',
#                'filing_date': '2022-02-22',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134422000009/ko-20211231.htm',
#                'period_of_report': '2021-12-31',
#                'relevance_score': 0.9534592628,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2021_0000021344-22-000009.json',
#                'state_location': 'GA'},
#   'page_content': 'The Coca-Cola Company Shareowners Equity\n'
#                   'Common stock, $0.25 par value; authorized - 11,200 shares; issued - 7,040 '
#                   'shares\n'
#                   '1,760 1,760\n'
#                   'Capital surplus 18,116 17,601\n'
#                   'Reinvested earnings 69,094 66,555\n'
#                   'Accumulated other comprehensive income (loss) (14,330) (14,601)\n'
#                   'Treasury stock, at cost - 2,715 and 2,738 shares, respectively\n'
#                   '(51,641) (52,016)\n'
#                   'Equity Attributable to Shareowners of The Coca-Cola Company 22,999 19,299\n'
#                   'Equity attributable to noncontrolling interests 1,861 1,985\n'
#                   'Total Equity 24,860 21,284\n'
#                   'Total Liabilities and Equity $ 94,354 $ 87,296\n'
#                   'Refer to Notes to Consolidated Financial Statements.\n'
#                   'THE COCA-COLA COMPANY AND SUBSIDIARIES\n'
#                   'CONSOLIDATED STATEMENTS OF CASH FLOWS\n'
#                   '(In millions)\n'
#                   'Year Ended December 31, 2021 2020 2019\n'
#                   'Operating Activities\n'
#                   'Consolidated net income $ 9,804 $ 7,768 $ 8,985\n'
#                   'Depreciation and amortization 1,452 1,536 1,365\n'
#                   'Stock-based compensation expense 337 126 201\n'
#                   'Deferred income taxes 894 (18) (280)\n'
#                   'Equity (income) loss - net of dividends (615) (511) (421)\n'
#                   'Foreign currency adjustments 86 (88) 91\n'
#                   'Significant (gains) losses - net (1,365) (914) (467)\n'
#                   'Other operating charges 506 556 127\n'
#                   'Other items 201 699 504\n'
#                   'Net change in operating assets and liabilities 1,325 690 366\n'
#                   'Net Cash Provided by Operating Activities 12,625 9,844 10,471\n'
#                   'Investing Activities\n'
#                   'Purchases of investments (6,030) (13,583) (4,704)\n'
#                   'Proceeds from disposals of investments 7,059 13,835 6,973\n'
#                   'Acquisitions of businesses, equity method investments and nonmarketable '
#                   'securities (4,766) (1,052) (5,542)\n'
#                   'Proceeds from disposals of businesses, equity method investments and '
#                   'nonmarketable securities 2,180 189 429\n'
#                   'Purchases of property, plant and equipment (1,367) (1,177) (2,054)\n'
#                   'Proceeds from disposals of property, plant and equipment 108 189 978\n'
#                   'Other investing activities 51 122 (56)\n'
#                   'Net Cash Provided by (Used in) Investing Activities (2,765) (1,477) (3,976)\n'
#                   'Financing Activities\n'
#                   'Issuances of debt 13,094 26,934 23,009\n'
#                   'Payments of debt (12,866) (28,796) (24,850)\n'
#                   'Issuances of stock 702 647 1,012',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 0
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 5
# Question: What is the Coca Cola's net income for the current fiscal year and how has net income trended over the past few years?
# Response: The answer is not in the context. The passage provides information about Corning Inc.'s net income for the year ended December 31, 2021, but does not mention Coca-Cola or its net income.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '24741',
#                'company': 'CORNING INC /NY',
#                'filename': '24741_10K_2021_0001437749-22-003247.htm',
#                'filing_date': '2022-02-14',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/24741/000143774922003247/glw20211231_10k.htm',
#                'period_of_report': '2021-12-31',
#                'relevance_score': 0.9710455537,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/24741_10K_2021_0001437749-22-003247.json',
#                'state_location': 'NY'},
#   'page_content': 'Net income increased by $55 million, or 40%, in the year ended December 31, '
#                   '2021, primarily driven by the changes in sales outlined above.\n'
#                   'All Other\n'
#                   'All other businesses that do not meet the quantitative threshold for separate '
#                   'reporting have been grouped as All Other. This group is primarily comprised of '
#                   'the results of HSG, pharmaceutical technologies, auto glass, new product lines '
#                   'and development projects, as well as other businesses and certain corporate '
#                   'investments.\n'
#                   'The Company obtained a controlling interest in HSG during the third quarter of '
#                   '2020 and has consolidated results in All Other since September 9, 2020. Refer '
#                   'to Note 4 (HSG Transactions and Acquisitions) to the consolidated financial '
#                   'statements for additional information on this transaction.\n'
#                   'The following table provides net sales and net loss for All Other (in '
#                   'millions):\n'
#                   'Year ended December 31,\n'
#                   '% change\n'
#                   '% change\n'
#                   '21 vs. 20\n'
#                   '20 vs. 19\n'
#                   'Segment net sales\n'
#                   '$ 1,243\n'
#                   '$\n'
#                   '$\n'
#                   '167%\n'
#                   '102%\n'
#                   'Segment net loss\n'
#                   '$ (51 )\n'
#                   '$ (214 )\n'
#                   '$ (289 )\n'
#                   '76%\n'
#                   '26%\n'
#                   'Net sales of this segment increased by $778 million, or 167%, in the year ended '
#                   'December 31, 2021, when compared to the same period in 2020, driven primarily '
#                   'by full-year consolidation of HSG.\n'
#                   'The decrease in the net loss of $163 million is primarily driven by the '
#                   'increases in sales outlined above.\n'
#                   'LIQUIDITY AND CAPITAL RESOURCES\n'
#                   'Financing and Capital Structure\n'
#                   'The following items discuss Cornings financing and changes in capital structure '
#                   'during 2021 and 2020:\n'
#                   'In the third quarter of 2021, Corning redeemed $250 million of 3.7% debentures '
#                   'due in 2023, paying a premium of $19 million by exercising our make-whole call. '
#                   'The bond redemption resulted in a $20 million loss during the same quarter.\n'
#                   'In the second quarter of 2021, Corning redeemed $375 million of 2.9% debentures '
#                   'due in 2022, paying a premium of $10 million by exercising our make-whole call. '
#                   'The bond redemption resulted in an $11 million loss during the same quarter.',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '24741',
#                'company': 'CORNING INC /NY',
#                'filename': '24741_10K_2020_0001562762-21-000023.htm',
#                'filing_date': '2021-02-12',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/24741/000156276221000023/glw-20201231x10k.htm',
#                'period_of_report': '2020-12-31',
#                'relevance_score': 0.969835639,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/24741_10K_2020_0001562762-21-000023.json',
#                'state_location': 'NY'},
#   'page_content': 'Net income decreased by $11 million, or 7%, in the year ended December 31, '
#                   '2020, primarily driven by sales and volume declines.\n'
#                   'All Other\n'
#                   'All Other is a group of segments primarily comprised of the results of '
#                   'pharmaceutical technologies, auto glass, new product lines and development '
#                   'projects, and other businesses or investments that do not meet the quantitative '
#                   'threshold for separate reporting.\n'
#                   'The Company obtained a controlling interest in HSG during the third quarter of '
#                   '2020 and has consolidated results in All Other as of September 9, 2020. Refer '
#                   'to Note 4 (HSG Transactions and Acquisitions) to the consolidated financial '
#                   'statements for additional information on this transaction.\n'
#                   'The following table provides net sales and net loss for All Other (in '
#                   'millions):\n'
#                   'Year ended December 31,\n'
#                   '% change\n'
#                   '% change\n'
#                   '20 vs. 19\n'
#                   '19 vs. 18\n'
#                   'Segment net sales\n'
#                   '$\n'
#                   '$\n'
#                   '$\n'
#                   '102%\n'
#                   '6%\n'
#                   'Segment net loss\n'
#                   '$\n'
#                   '(214)\n'
#                   '$\n'
#                   '(289)\n'
#                   '$\n'
#                   '(281)\n'
#                   '26%\n'
#                   '(3%)\n'
#                   'Net sales of this segment increased by $235 million, or 102%, in the year ended '
#                   'December 31, 2020, when compared to the same period in 2019, driven primarily '
#                   'by consolidation of HSG on September 9, 2020, which added sales of $194 million '
#                   'in the current year.\n'
#                   'The decrease in the net loss of $75 million is primarily driven by increased '
#                   'sales and lowered spending on development projects.\n'
#                   'LIQUIDITY AND CAPITAL RESOURCES\n'
#                   'Financing and Capital Structure\n'
#                   'The following items discuss Cornings financing and changes in capital structure '
#                   'during 2020 and 2019:\n'
#                   'During the fourth quarter of 2020, Corning redeemed $100 million of 7.0% '
#                   'debentures due in 2024 with a carrying amount of $99 million, paying a $21 '
#                   'million make-whole call premium. The total payment of $121 million is disclosed '
#                   'in financing activities in the consolidated statements of cash flows. The '
#                   'redemption resulted in a loss of $22 million.\n'
#                   'Index',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 0
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 0
# Progress saved.
#
# Row Index: 6
# Question: What is the Coca Cola's earnings per share and how does it compare to industry benchmarks?
# Response: According to the information provided in the document, Coca-Cola's basic net income per share was $2.26 for the year ended December 31, 2021, and their diluted net income per share was $2.25. These figures represent an increase from the previous year's basic and diluted net income per share of $1.80 and $1.79, respectively.
# To provide some context, here are some industry benchmarks for beverage companies similar to Coca-Cola:
# * PepsiCo's (PEP) earnings per share for the same period was $1.44.
# * Coca-Cola's earnings per share of $2.26 represents a 55% premium to PepsiCo's earnings per share of $1.44.
# * The Beverage segment of Anheuser-Busch InBev (BUD), which includes brands such as Budweiser and Stella Artois, had a net income of $1.3 billion for the same period, or $0.55 per share.
# * The Beverage segment of MillerCoors (MillerCoors), which includes brands such as Miller Lite and Coors Light, had a net income of $1.1 billion for the same period, or $0.47 per share.
#
# Therefore, based on these industry benchmarks, Coca-Cola's earnings per share of $2.26 appears to be above the industry average for beverage companies. However, it is important to note that each company has its unique business model, market position, and financial performance, so direct comparison between companies may not always be meaningful.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2021_0000021344-22-000009.htm',
#                'filing_date': '2022-02-22',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134422000009/ko-20211231.htm',
#                'period_of_report': '2021-12-31',
#                'relevance_score': 0.9642474055,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2021_0000021344-22-000009.json',
#                'state_location': 'GA'},
#   'page_content': 'Consolidated Balance Sheets\n'
#                   'Consolidated Statements of Cash Flows\n'
#                   'Consolidated Statements of Shareowners Equity\n'
# ...
#                   'January 1, 2010 (the Supplemental Pension Plan) - incorporated herein by '
#                   'reference to Exhibit 10.10.6 to the Companys Annual Report on Form 10-K for the '
#                   'year ended December 31, 2009.*\n'
#                   '10.6.1\n'
#                   'Amendment One to the Supplemental Pension Plan, effective December 31, 2012, '
#                   'dated December 6, 2012 - incorporated herein by reference to Exhibit 10.10.2 to '
#                   'the Companys Annual Report on Form 10-K for the year ended December 31, 2012.*\n'
#                   '10.6.2\n'
#                   'Amendment Two to the Supplemental Pension Plan, effective April 1, 2013, dated '
#                   'March 19, 2013 - incorporated herein by reference to Exhibit 10.10 to the '
#                   'Companys Quarterly Report on Form 10-Q for the quarter ended March 29, 2013.*\n'
#                   '10.6.3\n'
#                   'Amendment Three to the Supplemental Pension Plan, effective January 1, 2010, '
#                   'dated June 15, 2015 - incorporated herein by reference to Exhibit 10.9.3 to the '
#                   'Companys Annual Report on Form 10-K for the year ended December 31, 2016.*\n'
#                   '10.6.4\n'
#                   'Amendment Four to the Supplemental Pension Plan, effective June 1, 2017, dated '
#                   'June 29, 2017 - incorporated herein by reference to Exhibit 10.4 to the '
#                   'Companys Quarterly Report on Form 10-Q for the quarter ended June 30, 2017.*\n'
#                   '10.6.5\n'
#                   'Amendment Five to the Supplemental Pension Plan, dated March 23, 2018 - '
#                   'incorporated herein by reference to Exhibit 10.8 to the Companys Quarterly '
#                   'Report on Form 10-Q for the quarter ended March 30, 2018.*\n'
#                   '10.6.6\n'
#                   'Amendment Six to the Supplemental Pension Plan, dated December 9, 2020 - '
#                   'incorporated herein by reference to Exhibit 10.8.6 to the Companys Annual '
#                   'Report on Form 10-K for the year ended December 31, 2020.*\n'
#                   '10.6.7',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 33
# Question: How does the Coca Cola leverage technology for its operations and are there ongoing technological advancements?
# Response: The answer is in the context. According to the provided documents, Coca-Cola is actively leveraging technology to digitalize its operations and enhance its interactions with various stakeholders, including consumers, customers, suppliers, bottlers, and other business partners and stakeholders. The company is focused on creating more relevant and personalized experiences, developing powerful digital tools and capabilities, and increasing efficiency and productivity through the use of data, artificial intelligence, automation, robotics, and digital devices. Additionally, the documents mention the importance of adapting to and thriving in the digital environment, which suggests that technology plays a critical role in Coca-Cola's strategy moving forward.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2022_0000021344-23-000011.htm',
#                'filing_date': '2023-02-21',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134423000011/ko-20221231.htm',
#                'period_of_report': '2022-12-31',
#                'relevance_score': 0.9649670124,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2022_0000021344-23-000011.json',
#                'state_location': 'GA'},
#   'page_content': 'If we are not successful in our efforts to digitalize the Coca-Cola system, our '
#                   'financial results could be negatively affected.\n'
#                   'The digital evolution is affecting how we interact with consumers, customers, '
#                   'suppliers, bottlers and other business partners and stakeholders. We believe '
#                   'our future success will depend in part on our ability to adapt to and thrive in '
#                   'the digital environment. Therefore, one of our top priorities is to digitalize '
#                   'the Coca-Cola system by, among other things, creating more relevant and more '
#                   'personalized experiences wherever our system interacts with consumers, whether '
#                   'in a digital environment or through digital devices in an otherwise physical '
#                   'environment; finding ways to create more powerful digital tools and '
#                   'capabilities for the Coca-Cola systems retail customers to enable them to grow '
#                   'their businesses; and digitalizing operations through the use of data, '
#                   'artificial intelligence, automation, robotics and digital devices to increase '
#                   'efficiency and productivity. If we are not successful in our efforts to '
#                   'digitalize the Coca-Cola system, our ability to increase sales and improve '
#                   'margins may be negatively affected and the cost and expenses we have incurred '
#                   'or may incur in connection with our digitalization initiatives may adversely '
#                   'impact our financial performance.\n'
#                   'If negative publicity, whether or not warranted, concerning product safety or '
#                   'quality, workplace and human rights, obesity or other issues damages our brand '
#                   'image, corporate reputation and social license to operate, our business may '
#                   'suffer.',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2021_0000021344-22-000009.htm',
#                'filing_date': '2022-02-22',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134422000009/ko-20211231.htm',
#                'period_of_report': '2021-12-31',
#                'relevance_score': 0.9629876018,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2021_0000021344-22-000009.json',
#                'state_location': 'GA'},
#   'page_content': 'If we are not successful in our efforts to digitize the Coca-Cola system, our '
#                   'financial results could be negatively affected.\n'
#                   'The digital evolution is affecting how we interact with consumers, customers, '
#                   'suppliers, bottlers and other business partners and stakeholders. We believe '
#                   'that our future success will depend in part on our ability to adapt to and '
#                   'thrive in the digital environment. Therefore, one of our top priorities is to '
#                   'digitize the Coca-Cola system by, among other things, creating more relevant '
#                   'and more personalized experiences wherever our system interacts with consumers, '
#                   'whether in a digital environment or through digital devices in an otherwise '
#                   'physical environment; finding ways to create more powerful digital tools and '
#                   'capabilities for the Coca-Cola systems retail customers to enable them to grow '
#                   'their businesses; and digitizing operations through the use of data, artificial '
#                   'intelligence, automation, robotics and digital devices to increase efficiency '
#                   'and productivity. If we are not successful in our efforts to digitize the '
#                   'Coca-Cola system, our ability to increase sales and reduce costs may be '
#                   'negatively affected and the cost and expenses we have incurred or may incur in '
#                   'connection with our digitization initiatives may adversely impact our financial '
#                   'performance.\n'
#                   'If negative publicity, whether or not warranted, concerning product safety or '
#                   'quality, workplace and human rights, obesity or other issues damages our brand '
#                   'image, corporate reputation and social license to operate, our business may '
#                   'suffer.',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Row Index: 34
# Question: What does the Coca Cola foresee in terms of future growth and challenges and are there any strategic plans outlined for the upcoming years?
# Response: The answer is in the context. According to the document, Coca-Cola believes that its future success will depend on its ability to adapt to and thrive in the digital environment, and therefore, one of its top priorities is to digitalize the Coca-Cola system by creating more relevant and personalized experiences, finding ways to create more powerful digital tools and capabilities for retail customers, and digitizing operations through the use of data, artificial intelligence, automation, robotics, and digital devices to increase efficiency and productivity. Additionally, the document states that if negative publicity concerning product safety or quality, workplace and human rights, obesity or other issues damages the brand image, corporate reputation, and social license to operate, the business may suffer.
# Context:
# [{'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2022_0000021344-23-000011.htm',
#                'filing_date': '2023-02-21',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134423000011/ko-20221231.htm',
#                'period_of_report': '2022-12-31',
#                'relevance_score': 0.9675025344,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2022_0000021344-23-000011.json',
#                'state_location': 'GA'},
#   'page_content': 'If we are not successful in our efforts to digitalize the Coca-Cola system, our '
#                   'financial results could be negatively affected.\n'
#                   'The digital evolution is affecting how we interact with consumers, customers, '
#                   'suppliers, bottlers and other business partners and stakeholders. We believe '
#                   'our future success will depend in part on our ability to adapt to and thrive in '
#                   'the digital environment. Therefore, one of our top priorities is to digitalize '
#                   'the Coca-Cola system by, among other things, creating more relevant and more '
#                   'personalized experiences wherever our system interacts with consumers, whether '
#                   'in a digital environment or through digital devices in an otherwise physical '
#                   'environment; finding ways to create more powerful digital tools and '
#                   'capabilities for the Coca-Cola systems retail customers to enable them to grow '
#                   'their businesses; and digitalizing operations through the use of data, '
#                   'artificial intelligence, automation, robotics and digital devices to increase '
#                   'efficiency and productivity. If we are not successful in our efforts to '
#                   'digitalize the Coca-Cola system, our ability to increase sales and improve '
#                   'margins may be negatively affected and the cost and expenses we have incurred '
#                   'or may incur in connection with our digitalization initiatives may adversely '
#                   'impact our financial performance.\n'
#                   'If negative publicity, whether or not warranted, concerning product safety or '
#                   'quality, workplace and human rights, obesity or other issues damages our brand '
#                   'image, corporate reputation and social license to operate, our business may '
#                   'suffer.',
#   'type': 'Document'},
#  {'lc_attributes': {},
#   'lc_secrets': {},
#   'metadata': {'cik': '21344',
#                'company': 'COCA COLA CO',
#                'filename': '21344_10K_2021_0000021344-22-000009.htm',
#                'filing_date': '2022-02-22',
#                'filing_type': '10-K',
#                'fiscal_year_end': '1231',
#                'htm_filing_link': 'https://www.sec.gov/Archives/edgar/data/21344/000002134422000009/ko-20211231.htm',
#                'period_of_report': '2021-12-31',
#                'relevance_score': 0.9662753344,
#                'seq_num': 1,
#                'source': '/content/drive/MyDrive/Thesis/FinanceBench/21344_10K_2021_0000021344-22-000009.json',
#                'state_location': 'GA'},
#   'page_content': 'If we are not successful in our efforts to digitize the Coca-Cola system, our '
#                   'financial results could be negatively affected.\n'
#                   'The digital evolution is affecting how we interact with consumers, customers, '
#                   'suppliers, bottlers and other business partners and stakeholders. We believe '
#                   'that our future success will depend in part on our ability to adapt to and '
#                   'thrive in the digital environment. Therefore, one of our top priorities is to '
#                   'digitize the Coca-Cola system by, among other things, creating more relevant '
#                   'and more personalized experiences wherever our system interacts with consumers, '
#                   'whether in a digital environment or through digital devices in an otherwise '
#                   'physical environment; finding ways to create more powerful digital tools and '
#                   'capabilities for the Coca-Cola systems retail customers to enable them to grow '
#                   'their businesses; and digitizing operations through the use of data, artificial '
#                   'intelligence, automation, robotics and digital devices to increase efficiency '
#                   'and productivity. If we are not successful in our efforts to digitize the '
#                   'Coca-Cola system, our ability to increase sales and reduce costs may be '
#                   'negatively affected and the cost and expenses we have incurred or may incur in '
#                   'connection with our digitization initiatives may adversely impact our financial '
#                   'performance.\n'
#                   'If negative publicity, whether or not warranted, concerning product safety or '
#                   'quality, workplace and human rights, obesity or other issues damages our brand '
#                   'image, corporate reputation and social license to operate, our business may '
#                   'suffer.',
#   'type': 'Document'}]
# Is the context relevant to the company? (1 for True, 0 for False): 1
# Is the context relevant to the question? (1 for True, 0 for False): 1
# Is the response correct? (1 for True, 0 for False): 1
# Does the response answer the question? (1 for True, 0 for False): 1
# Progress saved.
#
# Evaluation results saved to 'evaluation_results.json'.

# %%
eval = pd.read_json('/content/evaluation_results_rerank.json')
eval.mean()[1:]
# Out:
# The context is relevant to the company     0.714286
# The context is relevant to the question    0.542857
# The response is correct                    0.628571
# The response answers the question          0.657143
# dtype: float64
